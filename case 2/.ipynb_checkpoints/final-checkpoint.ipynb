# %%
from __future__ import print_function

from keras import backend as K
K.set_image_dim_ordering('th') # ensure our dimension notation matches

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.convolutional import Convolution2D, AveragePooling2D
from keras.layers.core import Flatten
from keras.optimizers import SGD, Adam
from keras.datasets import mnist
from keras import utils
import numpy as np
from PIL import Image, ImageOps
import argparse
import math

import os
import os.path

import glob
# Out:
# Using Theano backend.

# %%
def generator_model():
    model = Sequential()
    model.add(Dense(input_dim=100, output_dim=1024))
    model.add(Activation('tanh'))
    model.add(Dense(128*8*8))
    model.add(BatchNormalization())
    model.add(Activation('tanh'))
    model.add(Reshape((128, 8, 8), input_shape=(128*8*8,)))
    model.add(UpSampling2D(size=(4, 4)))
    model.add(Convolution2D(64, 5, 5, border_mode='same'))
    model.add(Activation('tanh'))
    model.add(UpSampling2D(size=(4, 4)))
    model.add(Convolution2D(1, 5, 5, border_mode='same'))
    model.add(Activation('tanh'))
    return model


def discriminator_model():
    model = Sequential()
    model.add(Convolution2D(
                        64, 5, 5,
                        border_mode='same',
                        input_shape=(1, 128, 128)))
    model.add(Activation('tanh'))
    model.add(AveragePooling2D(pool_size=(4, 4)))
    model.add(Convolution2D(128, 5, 5))
    model.add(Activation('tanh'))
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(256))
    model.add(Activation('tanh'))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    return model


def generator_containing_discriminator(generator, discriminator):
    model = Sequential()
    model.add(generator)
    discriminator.trainable = False
    model.add(discriminator)
    return model


def combine_images(generated_images):
    num = generated_images.shape[0]
    width = int(math.sqrt(num))
    height = int(math.ceil(float(num)/width))
    shape = generated_images.shape[2:]
    image = np.zeros((height*shape[0], width*shape[1]),
                     dtype=generated_images.dtype)
    for index, img in enumerate(generated_images):
        i = int(index/width)
        j = index % width
        image[i*shape[0]:(i+1)*shape[0], j*shape[1]:(j+1)*shape[1]] = \
            img[0, :, :]
    return image

# %%
model = generator_model()
print(model.summary())
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# dense_1 (Dense)                  (None, 1024)          103424      dense_input_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 1024)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 8192)          8396800     activation_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNorma (None, 8192)          32768       dense_2[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 8192)          0           batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# reshape_1 (Reshape)              (None, 128, 8, 8)     0           activation_2[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)    (None, 128, 32, 32)   0           reshape_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 64, 32, 32)    204864      upsampling2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 64, 32, 32)    0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)    (None, 64, 128, 128)  0           activation_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 1, 128, 128)   1601        upsampling2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 1, 128, 128)   0           convolution2d_2[0][0]
# ====================================================================================================
# Total params: 8,739,457
# Trainable params: 8,723,073
# Non-trainable params: 16,384
# ____________________________________________________________________________________________________
# None

# %%
def load_data(pixels=128, verbose=False):
    print("Loading data")
    X_train = []
    paths = glob.glob(os.path.normpath(os.getcwd() + '/celeba/train/*.jpg'))
    for path in paths:
        if verbose: print(path)
        im = Image.open(path)
        im = ImageOps.fit(im, (pixels, pixels), Image.ANTIALIAS)
        im = ImageOps.grayscale(im)
        #im.show()
        im = np.asarray(im)
        X_train.append(im)
    print("Finished loading data")
    return np.array(X_train)

def train(epochs, BATCH_SIZE, weights=False):
    """
    :param epochs: Train for this many epochs
    :param BATCH_SIZE: Size of minibatch
    :param weights: If True, load weights from file, otherwise train the model from scratch. 
    Use this if you have already saved state of the network and want to train it further.
    """
    X_train = load_data()
    X_train = (X_train.astype(np.float32) - 127.5)/127.5
    X_train = X_train.reshape((X_train.shape[0], 1) + X_train.shape[1:])
    discriminator = discriminator_model()
    generator = generator_model()
    if weights:
        generator.load_weights('goodgenerator.h5')
        discriminator.load_weights('gooddiscriminator.h5')
    discriminator_on_generator = \
        generator_containing_discriminator(generator, discriminator)
    d_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    g_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    generator.compile(loss='binary_crossentropy', optimizer="SGD")
    discriminator_on_generator.compile(
        loss='binary_crossentropy', optimizer=g_optim)
    discriminator.trainable = True
    discriminator.compile(loss='binary_crossentropy', optimizer=d_optim)
    noise = np.zeros((BATCH_SIZE, 100))
    for epoch in range(epochs):
        print("Epoch is", epoch)
        print("Number of batches", int(X_train.shape[0]/BATCH_SIZE))
        for index in range(int(X_train.shape[0]/BATCH_SIZE)):
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            image_batch = X_train[index*BATCH_SIZE:(index+1)*BATCH_SIZE]
            generated_images = generator.predict(noise, verbose=0)
            #print(generated_images.shape)
            if index % 20 == 0 and epoch % 10 == 0:
                image = combine_images(generated_images)
                image = image*127.5+127.5
                destpath = os.path.normpath(os.getcwd()+ "/face-generated-images/"+str(epoch)+"_"+str(index)+".png")
                Image.fromarray(image.astype(np.uint8)).save(destpath)
            X = np.concatenate((image_batch, generated_images))
            y = [1] * BATCH_SIZE + [0] * BATCH_SIZE
            d_loss = discriminator.train_on_batch(X, y)
            print("batch %d d_loss : %f" % (index, d_loss))
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            discriminator.trainable = False
            g_loss = discriminator_on_generator.train_on_batch(
                noise, [1] * BATCH_SIZE)
            discriminator.trainable = True
            print("batch %d g_loss : %f" % (index, g_loss))
            if epoch % 10 == 9:
                generator.save_weights('goodgenerator.h5', True)
                discriminator.save_weights('gooddiscriminator.h5', True)

def clean(image):
    for i in range(1, image.shape[0] - 1):
        for j in range(1, image.shape[1] - 1):
            if image[i][j] + image[i+1][j] + image[i][j+1] + image[i-1][j] + image[i][j-1] > 127 * 5:
                image[i][j] = 255
    return image

def generate(BATCH_SIZE):
    generator = generator_model()
    generator.compile(loss='binary_crossentropy', optimizer="SGD")
    generator.load_weights('goodgenerator.h5')
    noise = np.zeros((BATCH_SIZE, 100))
    a = np.random.uniform(-1, 1, 100)
    b = np.random.uniform(-1, 1, 100)
    grad = (b - a) / BATCH_SIZE
    for i in range(BATCH_SIZE):
        noise[i, :] = np.random.uniform(-1, 1, 100)
    generated_images = generator.predict(noise, verbose=1)
    #image = combine_images(generated_images)
    print(generated_images.shape)
    for image in generated_images:
        image = image[0]
        image = image*127.5+127.5
        Image.fromarray(image.astype(np.uint8)).save("dirty.png")
        Image.fromarray(image.astype(np.uint8)).show()
        clean(image)
        image = Image.fromarray(image.astype(np.uint8))
        image.show()        
        image.save("clean.png")


def get_args():
    parser = argparse.ArgumentParser()
    parser.add_argument("--mode", type=str)
    parser.add_argument("--batch_size", type=int, default=128)
    parser.add_argument("--nice", dest="nice", action="store_true")
    parser.set_defaults(nice=False)
    args = parser.parse_args()
    return args

# %%
train(5000, 100, False)
# Out:
# Loading data
# Finished loading data
# Epoch is 0
# Number of batches 7
# batch 0 d_loss : 0.687361
# batch 0 g_loss : 0.693113
# batch 1 d_loss : 0.686155
# batch 1 g_loss : 0.696182
# batch 2 d_loss : 0.683124
# batch 2 g_loss : 0.693884
# batch 3 d_loss : 0.671856
# batch 3 g_loss : 0.695498
# batch 4 d_loss : 0.671997
# batch 4 g_loss : 0.694584
# batch 5 d_loss : 0.667536
# batch 5 g_loss : 0.700457
# batch 6 d_loss : 0.650713
# batch 6 g_loss : 0.695043
# Epoch is 1
# Number of batches 7
# batch 0 d_loss : 0.656777
# batch 0 g_loss : 0.696748
# batch 1 d_loss : 0.651903
# batch 1 g_loss : 0.693882
# batch 2 d_loss : 0.640862
# batch 2 g_loss : 0.696765
# batch 3 d_loss : 0.622887
# batch 3 g_loss : 0.699061
# batch 4 d_loss : 0.626681
# batch 4 g_loss : 0.694558
# batch 5 d_loss : 0.633554
# batch 5 g_loss : 0.695789
# batch 6 d_loss : 0.598435
# batch 6 g_loss : 0.691476
# Epoch is 2
# Number of batches 7
# batch 0 d_loss : 0.622408
# batch 0 g_loss : 0.697025
# batch 1 d_loss : 0.618171
# batch 1 g_loss : 0.695379
# batch 2 d_loss : 0.607725
# batch 2 g_loss : 0.690449
# batch 3 d_loss : 0.582840
# batch 3 g_loss : 0.697955
# batch 4 d_loss : 0.592009
# batch 4 g_loss : 0.702568
# batch 5 d_loss : 0.606696
# batch 5 g_loss : 0.689159
# batch 6 d_loss : 0.566642
# batch 6 g_loss : 0.690141
# Epoch is 3
# Number of batches 7
# batch 0 d_loss : 0.600385
# batch 0 g_loss : 0.691914
# batch 1 d_loss : 0.592911
# batch 1 g_loss : 0.696791
# batch 2 d_loss : 0.584305
# batch 2 g_loss : 0.699283
# batch 3 d_loss : 0.558888
# batch 3 g_loss : 0.694222
# batch 4 d_loss : 0.566284
# batch 4 g_loss : 0.695908
# batch 5 d_loss : 0.592039
# batch 5 g_loss : 0.693400
# batch 6 d_loss : 0.548505
# batch 6 g_loss : 0.696659
# Epoch is 4
# Number of batches 7
# batch 0 d_loss : 0.581180
# batch 0 g_loss : 0.699862
# batch 1 d_loss : 0.576494
# batch 1 g_loss : 0.692537
# batch 2 d_loss : 0.570174
# batch 2 g_loss : 0.698756
# batch 3 d_loss : 0.545560
# batch 3 g_loss : 0.707273
# batch 4 d_loss : 0.548033
# batch 4 g_loss : 0.703462
# batch 5 d_loss : 0.570997
# batch 5 g_loss : 0.697484
# batch 6 d_loss : 0.528396
# batch 6 g_loss : 0.715156
# Epoch is 5
# Number of batches 7
# batch 0 d_loss : 0.546794
# batch 0 g_loss : 0.720571
# batch 1 d_loss : 0.548616
# batch 1 g_loss : 0.724358
# batch 2 d_loss : 0.527522
# batch 2 g_loss : 0.725986
# batch 3 d_loss : 0.513019
# batch 3 g_loss : 0.757515
# batch 4 d_loss : 0.500630
# batch 4 g_loss : 0.753057
# batch 5 d_loss : 0.531893
# batch 5 g_loss : 0.764351
# batch 6 d_loss : 0.491054
# batch 6 g_loss : 0.775743
# Epoch is 6
# Number of batches 7
# batch 0 d_loss : 0.499382
# batch 0 g_loss : 0.772150
# batch 1 d_loss : 0.498550
# batch 1 g_loss : 0.790791
# batch 2 d_loss : 0.493696
# batch 2 g_loss : 0.796082
# batch 3 d_loss : 0.475309
# batch 3 g_loss : 0.801334
# batch 4 d_loss : 0.458875
# batch 4 g_loss : 0.813536
# batch 5 d_loss : 0.489537
# batch 5 g_loss : 0.833896
# batch 6 d_loss : 0.453916
# batch 6 g_loss : 0.835459
# Epoch is 7
# Number of batches 7
# batch 0 d_loss : 0.449660
# batch 0 g_loss : 0.850571
# batch 1 d_loss : 0.456126
# batch 1 g_loss : 0.865454
# batch 2 d_loss : 0.454824
# batch 2 g_loss : 0.875149
# batch 3 d_loss : 0.449909
# batch 3 g_loss : 0.872235
# batch 4 d_loss : 0.425122
# batch 4 g_loss : 0.890944
# batch 5 d_loss : 0.464428
# batch 5 g_loss : 0.881131
# batch 6 d_loss : 0.446754
# batch 6 g_loss : 0.894359
# Epoch is 8
# Number of batches 7
# batch 0 d_loss : 0.421164
# batch 0 g_loss : 0.882885
# batch 1 d_loss : 0.452957
# batch 1 g_loss : 0.903096
# batch 2 d_loss : 0.446047
# batch 2 g_loss : 0.878460
# batch 3 d_loss : 0.444169
# batch 3 g_loss : 0.880024
# batch 4 d_loss : 0.429061
# batch 4 g_loss : 0.883782
# batch 5 d_loss : 0.473248
# batch 5 g_loss : 0.857231
# batch 6 d_loss : 0.453463
# batch 6 g_loss : 0.862747
# Epoch is 9
# Number of batches 7
# batch 0 d_loss : 0.438176
# batch 0 g_loss : 0.832119
# batch 1 d_loss : 0.479771
# batch 1 g_loss : 0.829176
# batch 2 d_loss : 0.484916
# batch 2 g_loss : 0.850142
# batch 3 d_loss : 0.471223
# batch 3 g_loss : 0.804239
# batch 4 d_loss : 0.461685
# batch 4 g_loss : 0.808473
# batch 5 d_loss : 0.528277
# batch 5 g_loss : 0.792990
# batch 6 d_loss : 0.493495
# batch 6 g_loss : 0.792521
# Epoch is 10
# Number of batches 7
# batch 0 d_loss : 0.480880
# batch 0 g_loss : 0.789165
# batch 1 d_loss : 0.507752
# batch 1 g_loss : 0.767665
# batch 2 d_loss : 0.509163
# batch 2 g_loss : 0.779624
# batch 3 d_loss : 0.491579
# batch 3 g_loss : 0.759050
# batch 4 d_loss : 0.472011
# batch 4 g_loss : 0.797211
# batch 5 d_loss : 0.519727
# batch 5 g_loss : 0.818475
# batch 6 d_loss : 0.468048
# batch 6 g_loss : 0.811772
# Epoch is 11
# Number of batches 7
# batch 0 d_loss : 0.464708
# batch 0 g_loss : 0.832862
# batch 1 d_loss : 0.470901
# batch 1 g_loss : 0.829618
# batch 2 d_loss : 0.461189
# batch 2 g_loss : 0.842537
# batch 3 d_loss : 0.420002
# batch 3 g_loss : 0.881369
# batch 4 d_loss : 0.398277
# batch 4 g_loss : 0.919208
# batch 5 d_loss : 0.441776
# batch 5 g_loss : 0.951077
# batch 6 d_loss : 0.369359
# batch 6 g_loss : 0.976482
# Epoch is 12
# Number of batches 7
# batch 0 d_loss : 0.401213
# batch 0 g_loss : 1.005584
# batch 1 d_loss : 0.385831
# batch 1 g_loss : 1.033586
# batch 2 d_loss : 0.380754
# batch 2 g_loss : 1.073060
# batch 3 d_loss : 0.332465
# batch 3 g_loss : 1.066722
# batch 4 d_loss : 0.327772
# batch 4 g_loss : 1.115204
# batch 5 d_loss : 0.381798
# batch 5 g_loss : 1.143963
# batch 6 d_loss : 0.315834
# batch 6 g_loss : 1.154215
# Epoch is 13
# Number of batches 7
# batch 0 d_loss : 0.400554
# batch 0 g_loss : 1.147410
# batch 1 d_loss : 0.376579
# batch 1 g_loss : 1.132280
# batch 2 d_loss : 0.385473
# batch 2 g_loss : 1.131189
# batch 3 d_loss : 0.339103
# batch 3 g_loss : 1.130296
# batch 4 d_loss : 0.360460
# batch 4 g_loss : 1.079014
# batch 5 d_loss : 0.445088
# batch 5 g_loss : 1.043292
# batch 6 d_loss : 0.387471
# batch 6 g_loss : 1.057411
# Epoch is 14
# Number of batches 7
# batch 0 d_loss : 0.512581
# batch 0 g_loss : 1.010453
# batch 1 d_loss : 0.499736
# batch 1 g_loss : 0.929163
# batch 2 d_loss : 0.529358
# batch 2 g_loss : 0.907113
# batch 3 d_loss : 0.492242
# batch 3 g_loss : 0.893984
# batch 4 d_loss : 0.527147
# batch 4 g_loss : 0.836592
# batch 5 d_loss : 0.619785
# batch 5 g_loss : 0.837471
# batch 6 d_loss : 0.570531
# batch 6 g_loss : 0.796925
# Epoch is 15
# Number of batches 7
# batch 0 d_loss : 0.665375
# batch 0 g_loss : 0.801742
# batch 1 d_loss : 0.626095
# batch 1 g_loss : 0.827812
# batch 2 d_loss : 0.619903
# batch 2 g_loss : 0.819582
# batch 3 d_loss : 0.552733
# batch 3 g_loss : 0.878655
# batch 4 d_loss : 0.519701
# batch 4 g_loss : 0.912923
# batch 5 d_loss : 0.550258
# batch 5 g_loss : 0.985904
# batch 6 d_loss : 0.446795
# batch 6 g_loss : 1.086203
# Epoch is 16
# Number of batches 7
# batch 0 d_loss : 0.438105
# batch 0 g_loss : 1.150978
# batch 1 d_loss : 0.410396
# batch 1 g_loss : 1.269620
# batch 2 d_loss : 0.380740
# batch 2 g_loss : 1.367295
# batch 3 d_loss : 0.347062
# batch 3 g_loss : 1.469089
# batch 4 d_loss : 0.309865
# batch 4 g_loss : 1.592427
# batch 5 d_loss : 0.361831
# batch 5 g_loss : 1.675063
# batch 6 d_loss : 0.339665
# batch 6 g_loss : 1.751444
# Epoch is 17
# Number of batches 7
# batch 0 d_loss : 0.298096
# batch 0 g_loss : 1.824071
# batch 1 d_loss : 0.332049
# batch 1 g_loss : 1.860169
# batch 2 d_loss : 0.335661
# batch 2 g_loss : 1.882334
# batch 3 d_loss : 0.344697
# batch 3 g_loss : 1.878497
# batch 4 d_loss : 0.299821
# batch 4 g_loss : 1.840831
# batch 5 d_loss : 0.374604
# batch 5 g_loss : 1.774221
# batch 6 d_loss : 0.380476
# batch 6 g_loss : 1.724941
# Epoch is 18
# Number of batches 7
# batch 0 d_loss : 0.308752
# batch 0 g_loss : 1.690457
# batch 1 d_loss : 0.350882
# batch 1 g_loss : 1.643870
# batch 2 d_loss : 0.359688
# batch 2 g_loss : 1.577280
# batch 3 d_loss : 0.365752
# batch 3 g_loss : 1.478915
# batch 4 d_loss : 0.337090
# batch 4 g_loss : 1.416316
# batch 5 d_loss : 0.421999
# batch 5 g_loss : 1.386601
# batch 6 d_loss : 0.433409
# batch 6 g_loss : 1.277143
# Epoch is 19
# Number of batches 7
# batch 0 d_loss : 0.396167
# batch 0 g_loss : 1.214928
# batch 1 d_loss : 0.441733
# batch 1 g_loss : 1.186038
# batch 2 d_loss : 0.489652
# batch 2 g_loss : 1.109474
# batch 3 d_loss : 0.502841
# batch 3 g_loss : 1.062829
# batch 4 d_loss : 0.500392
# batch 4 g_loss : 1.018684
# batch 5 d_loss : 0.585868
# batch 5 g_loss : 1.028675
# batch 6 d_loss : 0.573830
# batch 6 g_loss : 0.991601
# Epoch is 20
# Number of batches 7
# batch 0 d_loss : 0.556365
# batch 0 g_loss : 0.947871
# batch 1 d_loss : 0.602549
# batch 1 g_loss : 0.955980
# batch 2 d_loss : 0.607503
# batch 2 g_loss : 0.992802
# batch 3 d_loss : 0.574366
# batch 3 g_loss : 1.094871
# batch 4 d_loss : 0.538701
# batch 4 g_loss : 1.019443
# batch 5 d_loss : 0.564328
# batch 5 g_loss : 1.120278
# batch 6 d_loss : 0.502301
# batch 6 g_loss : 1.115766
# Epoch is 21
# Number of batches 7
# batch 0 d_loss : 0.483541
# batch 0 g_loss : 1.222943
# batch 1 d_loss : 0.465741
# batch 1 g_loss : 1.328762
# batch 2 d_loss : 0.447801
# batch 2 g_loss : 1.397314
# batch 3 d_loss : 0.379657
# batch 3 g_loss : 1.525482
# batch 4 d_loss : 0.351962
# batch 4 g_loss : 1.594888
# batch 5 d_loss : 0.403529
# batch 5 g_loss : 1.653289
# batch 6 d_loss : 0.313070
# batch 6 g_loss : 1.682846
# Epoch is 22
# Number of batches 7
# batch 0 d_loss : 0.389152
# batch 0 g_loss : 1.757658
# batch 1 d_loss : 0.360590
# batch 1 g_loss : 1.882397
# batch 2 d_loss : 0.372427
# batch 2 g_loss : 1.906161
# batch 3 d_loss : 0.313833
# batch 3 g_loss : 1.930597
# batch 4 d_loss : 0.335516
# batch 4 g_loss : 1.903760
# batch 5 d_loss : 0.416597
# batch 5 g_loss : 1.834417
# batch 6 d_loss : 0.332139
# batch 6 g_loss : 1.880554
# Epoch is 23
# Number of batches 7
# batch 0 d_loss : 0.476394
# batch 0 g_loss : 1.814377
# batch 1 d_loss : 0.445449
# batch 1 g_loss : 1.740262
# batch 2 d_loss : 0.455834
# batch 2 g_loss : 1.690313
# batch 3 d_loss : 0.429295
# batch 3 g_loss : 1.694180
# batch 4 d_loss : 0.490546
# batch 4 g_loss : 1.535307
# batch 5 d_loss : 0.609867
# batch 5 g_loss : 1.388484
# batch 6 d_loss : 0.543944
# batch 6 g_loss : 1.430324
# Epoch is 24
# Number of batches 7
# batch 0 d_loss : 0.737171
# batch 0 g_loss : 1.401309
# batch 1 d_loss : 0.723709
# batch 1 g_loss : 1.251726
# batch 2 d_loss : 0.755775
# batch 2 g_loss : 1.240582
# batch 3 d_loss : 0.702153
# batch 3 g_loss : 1.272588
# batch 4 d_loss : 0.731482
# batch 4 g_loss : 1.259390
# batch 5 d_loss : 0.806706
# batch 5 g_loss : 1.294709
# batch 6 d_loss : 0.677129
# batch 6 g_loss : 1.377721
# Epoch is 25
# Number of batches 7
# batch 0 d_loss : 0.739893
# batch 0 g_loss : 1.391406
# batch 1 d_loss : 0.658614
# batch 1 g_loss : 1.474486
# batch 2 d_loss : 0.632657
# batch 2 g_loss : 1.609368
# batch 3 d_loss : 0.557758
# batch 3 g_loss : 1.775639
# batch 4 d_loss : 0.529501
# batch 4 g_loss : 1.782149
# batch 5 d_loss : 0.586671
# batch 5 g_loss : 1.922607
# batch 6 d_loss : 0.519683
# batch 6 g_loss : 2.002055
# Epoch is 26
# Number of batches 7
# batch 0 d_loss : 0.491148
# batch 0 g_loss : 2.080851
# batch 1 d_loss : 0.516300
# batch 1 g_loss : 2.123452
# batch 2 d_loss : 0.509730
# batch 2 g_loss : 2.148567
# batch 3 d_loss : 0.529656
# batch 3 g_loss : 2.134186
# batch 4 d_loss : 0.454827
# batch 4 g_loss : 2.200401
# batch 5 d_loss : 0.524138
# batch 5 g_loss : 2.078360
# batch 6 d_loss : 0.508944
# batch 6 g_loss : 2.054276
# Epoch is 27
# Number of batches 7
# batch 0 d_loss : 0.418552
# batch 0 g_loss : 1.919258
# batch 1 d_loss : 0.447913
# batch 1 g_loss : 1.817316
# batch 2 d_loss : 0.450667
# batch 2 g_loss : 1.747034
# batch 3 d_loss : 0.457975
# batch 3 g_loss : 1.708071
# batch 4 d_loss : 0.396974
# batch 4 g_loss : 1.643794
# batch 5 d_loss : 0.484124
# batch 5 g_loss : 1.621406
# batch 6 d_loss : 0.481637
# batch 6 g_loss : 1.542095
# Epoch is 28
# Number of batches 7
# batch 0 d_loss : 0.419340
# batch 0 g_loss : 1.486659
# batch 1 d_loss : 0.459508
# batch 1 g_loss : 1.533072
# batch 2 d_loss : 0.501948
# batch 2 g_loss : 1.441643
# batch 3 d_loss : 0.503684
# batch 3 g_loss : 1.369334
# batch 4 d_loss : 0.478513
# batch 4 g_loss : 1.412656
# batch 5 d_loss : 0.555885
# batch 5 g_loss : 1.339073
# batch 6 d_loss : 0.571471
# batch 6 g_loss : 1.309955
# Epoch is 29
# Number of batches 7
# batch 0 d_loss : 0.523964
# batch 0 g_loss : 1.334106
# batch 1 d_loss : 0.584906
# batch 1 g_loss : 1.362957
# batch 2 d_loss : 0.573905
# batch 2 g_loss : 1.342302
# batch 3 d_loss : 0.617997
# batch 3 g_loss : 1.360107
# batch 4 d_loss : 0.582038
# batch 4 g_loss : 1.214978
# batch 5 d_loss : 0.669804
# batch 5 g_loss : 1.321823
# batch 6 d_loss : 0.750482
# batch 6 g_loss : 1.267984
# Epoch is 30
# Number of batches 7
# batch 0 d_loss : 0.636187
# batch 0 g_loss : 1.225515
# batch 1 d_loss : 0.696913
# batch 1 g_loss : 1.231393
# batch 2 d_loss : 0.728384
# batch 2 g_loss : 1.291710
# batch 3 d_loss : 0.768329
# batch 3 g_loss : 1.285786
# batch 4 d_loss : 0.736062
# batch 4 g_loss : 1.143696
# batch 5 d_loss : 0.820977
# batch 5 g_loss : 1.183814
# batch 6 d_loss : 0.881796
# batch 6 g_loss : 1.169210
# Epoch is 31
# Number of batches 7
# batch 0 d_loss : 0.787920
# batch 0 g_loss : 1.193605
# batch 1 d_loss : 0.832876
# batch 1 g_loss : 1.127041
# batch 2 d_loss : 0.830134
# batch 2 g_loss : 1.149039
# batch 3 d_loss : 0.869819
# batch 3 g_loss : 1.170334
# batch 4 d_loss : 0.783653
# batch 4 g_loss : 1.165047
# batch 5 d_loss : 0.842184
# batch 5 g_loss : 1.218464
# batch 6 d_loss : 0.842546
# batch 6 g_loss : 1.170305
# Epoch is 32
# Number of batches 7
# batch 0 d_loss : 0.773926
# batch 0 g_loss : 1.145239
# batch 1 d_loss : 0.748819
# batch 1 g_loss : 1.171368
# batch 2 d_loss : 0.746000
# batch 2 g_loss : 1.177393
# batch 3 d_loss : 0.751762
# batch 3 g_loss : 1.191483
# batch 4 d_loss : 0.706232
# batch 4 g_loss : 1.250747
# batch 5 d_loss : 0.711603
# batch 5 g_loss : 1.255361
# batch 6 d_loss : 0.659191
# batch 6 g_loss : 1.309228
# Epoch is 33
# Number of batches 7
# batch 0 d_loss : 0.621495
# batch 0 g_loss : 1.356606
# batch 1 d_loss : 0.620792
# batch 1 g_loss : 1.330329
# batch 2 d_loss : 0.594577
# batch 2 g_loss : 1.304392
# batch 3 d_loss : 0.575137
# batch 3 g_loss : 1.404410
# batch 4 d_loss : 0.557176
# batch 4 g_loss : 1.366701
# batch 5 d_loss : 0.572013
# batch 5 g_loss : 1.402432
# batch 6 d_loss : 0.520669
# batch 6 g_loss : 1.406819
# Epoch is 34
# Number of batches 7
# batch 0 d_loss : 0.543793
# batch 0 g_loss : 1.391386
# batch 1 d_loss : 0.529918
# batch 1 g_loss : 1.506144
# batch 2 d_loss : 0.525153
# batch 2 g_loss : 1.412540
# batch 3 d_loss : 0.482402
# batch 3 g_loss : 1.409234
# batch 4 d_loss : 0.501538
# batch 4 g_loss : 1.397479
# batch 5 d_loss : 0.533202
# batch 5 g_loss : 1.447727
# batch 6 d_loss : 0.487516
# batch 6 g_loss : 1.425821
# Epoch is 35
# Number of batches 7
# batch 0 d_loss : 0.542799
# batch 0 g_loss : 1.435729
# batch 1 d_loss : 0.527412
# batch 1 g_loss : 1.351280
# batch 2 d_loss : 0.542542
# batch 2 g_loss : 1.348785
# batch 3 d_loss : 0.500613
# batch 3 g_loss : 1.365414
# batch 4 d_loss : 0.542919
# batch 4 g_loss : 1.354623
# batch 5 d_loss : 0.572661
# batch 5 g_loss : 1.306874
# batch 6 d_loss : 0.520165
# batch 6 g_loss : 1.278103
# Epoch is 36
# Number of batches 7
# batch 0 d_loss : 0.615554
# batch 0 g_loss : 1.287475
# batch 1 d_loss : 0.593541
# batch 1 g_loss : 1.275504
# batch 2 d_loss : 0.610415
# batch 2 g_loss : 1.253288
# batch 3 d_loss : 0.570065
# batch 3 g_loss : 1.298645
# batch 4 d_loss : 0.615419
# batch 4 g_loss : 1.212970
# batch 5 d_loss : 0.658106
# batch 5 g_loss : 1.146019
# batch 6 d_loss : 0.608518
# batch 6 g_loss : 1.134070
# Epoch is 37
# Number of batches 7
# batch 0 d_loss : 0.707968
# batch 0 g_loss : 1.182754
# batch 1 d_loss : 0.693882
# batch 1 g_loss : 1.136670
# batch 2 d_loss : 0.717504
# batch 2 g_loss : 1.186429
# batch 3 d_loss : 0.677170
# batch 3 g_loss : 1.144549
# batch 4 d_loss : 0.706212
# batch 4 g_loss : 1.149061
# batch 5 d_loss : 0.744258
# batch 5 g_loss : 1.160289
# batch 6 d_loss : 0.669463
# batch 6 g_loss : 1.101148
# Epoch is 38
# Number of batches 7
# batch 0 d_loss : 0.767983
# batch 0 g_loss : 1.179858
# batch 1 d_loss : 0.752854
# batch 1 g_loss : 1.122898
# batch 2 d_loss : 0.748240
# batch 2 g_loss : 1.086382
# batch 3 d_loss : 0.719178
# batch 3 g_loss : 1.139758
# batch 4 d_loss : 0.727812
# batch 4 g_loss : 1.166820
# batch 5 d_loss : 0.733624
# batch 5 g_loss : 1.076095
# batch 6 d_loss : 0.701033
# batch 6 g_loss : 1.115713
# Epoch is 39
# Number of batches 7
# batch 0 d_loss : 0.751273
# batch 0 g_loss : 1.153391
# batch 1 d_loss : 0.757883
# batch 1 g_loss : 1.130487
# batch 2 d_loss : 0.730299
# batch 2 g_loss : 1.195491
# batch 3 d_loss : 0.726998
# batch 3 g_loss : 1.158930
# batch 4 d_loss : 0.700909
# batch 4 g_loss : 1.122188
# batch 5 d_loss : 0.706318
# batch 5 g_loss : 1.156100
# batch 6 d_loss : 0.699000
# batch 6 g_loss : 1.127112
# Epoch is 40
# Number of batches 7
# batch 0 d_loss : 0.684898
# batch 0 g_loss : 1.219430
# batch 1 d_loss : 0.696199
# batch 1 g_loss : 1.175611
# batch 2 d_loss : 0.694111
# batch 2 g_loss : 1.144634
# batch 3 d_loss : 0.686409
# batch 3 g_loss : 1.150744
# batch 4 d_loss : 0.646887
# batch 4 g_loss : 1.090100
# batch 5 d_loss : 0.657967
# batch 5 g_loss : 1.135880
# batch 6 d_loss : 0.688111
# batch 6 g_loss : 1.151549
# Epoch is 41
# Number of batches 7
# batch 0 d_loss : 0.640149
# batch 0 g_loss : 1.055268
# batch 1 d_loss : 0.650023
# batch 1 g_loss : 1.100918
# batch 2 d_loss : 0.649604
# batch 2 g_loss : 1.097454
# batch 3 d_loss : 0.649887
# batch 3 g_loss : 1.083755
# batch 4 d_loss : 0.623610
# batch 4 g_loss : 1.064610
# batch 5 d_loss : 0.618498
# batch 5 g_loss : 1.048707
# batch 6 d_loss : 0.642534
# batch 6 g_loss : 1.081399
# Epoch is 42
# Number of batches 7
# batch 0 d_loss : 0.605533
# batch 0 g_loss : 1.006407
# batch 1 d_loss : 0.617735
# batch 1 g_loss : 1.035857
# batch 2 d_loss : 0.616342
# batch 2 g_loss : 1.058366
# batch 3 d_loss : 0.629246
# batch 3 g_loss : 1.054754
# batch 4 d_loss : 0.591812
# batch 4 g_loss : 1.000583
# batch 5 d_loss : 0.615948
# batch 5 g_loss : 1.055014
# batch 6 d_loss : 0.621509
# batch 6 g_loss : 0.999646
# Epoch is 43
# Number of batches 7
# batch 0 d_loss : 0.576162
# batch 0 g_loss : 0.996748
# batch 1 d_loss : 0.585118
# batch 1 g_loss : 0.995383
# batch 2 d_loss : 0.597552
# batch 2 g_loss : 1.042310
# batch 3 d_loss : 0.612957
# batch 3 g_loss : 1.023606
# batch 4 d_loss : 0.567190
# batch 4 g_loss : 1.050073
# batch 5 d_loss : 0.597609
# batch 5 g_loss : 1.011586
# batch 6 d_loss : 0.623877
# batch 6 g_loss : 1.002301
# Epoch is 44
# Number of batches 7
# batch 0 d_loss : 0.558132
# batch 0 g_loss : 1.053423
# batch 1 d_loss : 0.588180
# batch 1 g_loss : 1.039393
# batch 2 d_loss : 0.581653
# batch 2 g_loss : 1.058065
# batch 3 d_loss : 0.610169
# batch 3 g_loss : 1.025959
# batch 4 d_loss : 0.566550
# batch 4 g_loss : 1.047319
# batch 5 d_loss : 0.569752
# batch 5 g_loss : 1.048927
# batch 6 d_loss : 0.623980
# batch 6 g_loss : 1.010278
# Epoch is 45
# Number of batches 7
# batch 0 d_loss : 0.544215
# batch 0 g_loss : 0.987873
# batch 1 d_loss : 0.582952
# batch 1 g_loss : 1.007017
# batch 2 d_loss : 0.580832
# batch 2 g_loss : 1.026999
# batch 3 d_loss : 0.603567
# batch 3 g_loss : 1.002677
# batch 4 d_loss : 0.562440
# batch 4 g_loss : 0.958242
# batch 5 d_loss : 0.595627
# batch 5 g_loss : 1.013087
# batch 6 d_loss : 0.651609
# batch 6 g_loss : 1.021582
# Epoch is 46
# Number of batches 7
# batch 0 d_loss : 0.564417
# batch 0 g_loss : 0.936969
# batch 1 d_loss : 0.576718
# batch 1 g_loss : 0.943256
# batch 2 d_loss : 0.588336
# batch 2 g_loss : 0.929432
# batch 3 d_loss : 0.620937
# batch 3 g_loss : 0.985202
# batch 4 d_loss : 0.594461
# batch 4 g_loss : 0.931733
# batch 5 d_loss : 0.618685
# batch 5 g_loss : 0.907813
# batch 6 d_loss : 0.641721
# batch 6 g_loss : 0.938279
# Epoch is 47
# Number of batches 7
# batch 0 d_loss : 0.586956
# batch 0 g_loss : 0.910936
# batch 1 d_loss : 0.609297
# batch 1 g_loss : 0.900648
# batch 2 d_loss : 0.598038
# batch 2 g_loss : 0.956640
# batch 3 d_loss : 0.650074
# batch 3 g_loss : 0.887777
# batch 4 d_loss : 0.611165
# batch 4 g_loss : 0.877028
# batch 5 d_loss : 0.632533
# batch 5 g_loss : 0.888557
# batch 6 d_loss : 0.678046
# batch 6 g_loss : 0.913121
# Epoch is 48
# Number of batches 7
# batch 0 d_loss : 0.595201
# batch 0 g_loss : 0.896222
# batch 1 d_loss : 0.633928
# batch 1 g_loss : 0.904013
# batch 2 d_loss : 0.623461
# batch 2 g_loss : 0.864330
# batch 3 d_loss : 0.666133
# batch 3 g_loss : 0.848159
# batch 4 d_loss : 0.615756
# batch 4 g_loss : 0.858526
# batch 5 d_loss : 0.643440
# batch 5 g_loss : 0.862979
# batch 6 d_loss : 0.683645
# batch 6 g_loss : 0.844869
# Epoch is 49
# Number of batches 7
# batch 0 d_loss : 0.626885
# batch 0 g_loss : 0.856484
# batch 1 d_loss : 0.668622
# batch 1 g_loss : 0.822607
# batch 2 d_loss : 0.640307
# batch 2 g_loss : 0.826826
# batch 3 d_loss : 0.666623
# batch 3 g_loss : 0.823350
# batch 4 d_loss : 0.642564
# batch 4 g_loss : 0.851215
# batch 5 d_loss : 0.656309
# batch 5 g_loss : 0.796750
# batch 6 d_loss : 0.687174
# batch 6 g_loss : 0.788053
# Epoch is 50
# Number of batches 7
# batch 0 d_loss : 0.638827
# batch 0 g_loss : 0.835676
# batch 1 d_loss : 0.671310
# batch 1 g_loss : 0.782777
# batch 2 d_loss : 0.664748
# batch 2 g_loss : 0.796319
# batch 3 d_loss : 0.663027
# batch 3 g_loss : 0.787902
# batch 4 d_loss : 0.654684
# batch 4 g_loss : 0.801118
# batch 5 d_loss : 0.680741
# batch 5 g_loss : 0.799201
# batch 6 d_loss : 0.686920
# batch 6 g_loss : 0.783857
# Epoch is 51
# Number of batches 7
# batch 0 d_loss : 0.640730
# batch 0 g_loss : 0.790199
# batch 1 d_loss : 0.687849
# batch 1 g_loss : 0.780063
# batch 2 d_loss : 0.655067
# batch 2 g_loss : 0.764674
# batch 3 d_loss : 0.672162
# batch 3 g_loss : 0.715213
# batch 4 d_loss : 0.647087
# batch 4 g_loss : 0.754991
# batch 5 d_loss : 0.670253
# batch 5 g_loss : 0.794354
# batch 6 d_loss : 0.676345
# batch 6 g_loss : 0.790210
# Epoch is 52
# Number of batches 7
# batch 0 d_loss : 0.643049
# batch 0 g_loss : 0.790069
# batch 1 d_loss : 0.673395
# batch 1 g_loss : 0.790302
# batch 2 d_loss : 0.651300
# batch 2 g_loss : 0.777896
# batch 3 d_loss : 0.676813
# batch 3 g_loss : 0.754578
# batch 4 d_loss : 0.617357
# batch 4 g_loss : 0.800073
# batch 5 d_loss : 0.668151
# batch 5 g_loss : 0.787169
# batch 6 d_loss : 0.640939
# batch 6 g_loss : 0.831784
# Epoch is 53
# Number of batches 7
# batch 0 d_loss : 0.624835
# batch 0 g_loss : 0.779353
# batch 1 d_loss : 0.653492
# batch 1 g_loss : 0.812437
# batch 2 d_loss : 0.637049
# batch 2 g_loss : 0.781332
# batch 3 d_loss : 0.626561
# batch 3 g_loss : 0.809308
# batch 4 d_loss : 0.613501
# batch 4 g_loss : 0.802741
# batch 5 d_loss : 0.655594
# batch 5 g_loss : 0.808399
# batch 6 d_loss : 0.613249
# batch 6 g_loss : 0.789008
# Epoch is 54
# Number of batches 7
# batch 0 d_loss : 0.611492
# batch 0 g_loss : 0.816240
# batch 1 d_loss : 0.634896
# batch 1 g_loss : 0.866497
# batch 2 d_loss : 0.619667
# batch 2 g_loss : 0.811027
# batch 3 d_loss : 0.610491
# batch 3 g_loss : 0.826117
# batch 4 d_loss : 0.606648
# batch 4 g_loss : 0.858404
# batch 5 d_loss : 0.627007
# batch 5 g_loss : 0.836373
# batch 6 d_loss : 0.609274
# batch 6 g_loss : 0.799414
# Epoch is 55
# Number of batches 7
# batch 0 d_loss : 0.603067
# batch 0 g_loss : 0.821645
# batch 1 d_loss : 0.626567
# batch 1 g_loss : 0.863213
# batch 2 d_loss : 0.598566
# batch 2 g_loss : 0.878530
# batch 3 d_loss : 0.599674
# batch 3 g_loss : 0.856462
# batch 4 d_loss : 0.591544
# batch 4 g_loss : 0.793671
# batch 5 d_loss : 0.615907
# batch 5 g_loss : 0.844917
# batch 6 d_loss : 0.610936
# batch 6 g_loss : 0.865237
# Epoch is 56
# Number of batches 7
# batch 0 d_loss : 0.588507
# batch 0 g_loss : 0.894161
# batch 1 d_loss : 0.615968
# batch 1 g_loss : 0.864704
# batch 2 d_loss : 0.589813
# batch 2 g_loss : 0.859037
# batch 3 d_loss : 0.583466
# batch 3 g_loss : 0.853703
# batch 4 d_loss : 0.561341
# batch 4 g_loss : 0.870552
# batch 5 d_loss : 0.625705
# batch 5 g_loss : 0.876880
# batch 6 d_loss : 0.561978
# batch 6 g_loss : 0.903993
# Epoch is 57
# Number of batches 7
# batch 0 d_loss : 0.587872
# batch 0 g_loss : 0.910592
# batch 1 d_loss : 0.616689
# batch 1 g_loss : 0.865163
# batch 2 d_loss : 0.605276
# batch 2 g_loss : 0.844562
# batch 3 d_loss : 0.591456
# batch 3 g_loss : 0.888115
# batch 4 d_loss : 0.556585
# batch 4 g_loss : 0.850333
# batch 5 d_loss : 0.635186
# batch 5 g_loss : 0.854539
# batch 6 d_loss : 0.580914
# batch 6 g_loss : 0.821769
# Epoch is 58
# Number of batches 7
# batch 0 d_loss : 0.578392
# batch 0 g_loss : 0.834352
# batch 1 d_loss : 0.626877
# batch 1 g_loss : 0.867102
# batch 2 d_loss : 0.618556
# batch 2 g_loss : 0.918205
# batch 3 d_loss : 0.603674
# batch 3 g_loss : 0.839841
# batch 4 d_loss : 0.589932
# batch 4 g_loss : 0.858476
# batch 5 d_loss : 0.632578
# batch 5 g_loss : 0.873575
# batch 6 d_loss : 0.577081
# batch 6 g_loss : 0.862164
# Epoch is 59
# Number of batches 7
# batch 0 d_loss : 0.627936
# batch 0 g_loss : 0.890127
# batch 1 d_loss : 0.614115
# batch 1 g_loss : 0.898806
# batch 2 d_loss : 0.618011
# batch 2 g_loss : 0.869689
# batch 3 d_loss : 0.603280
# batch 3 g_loss : 0.875562
# batch 4 d_loss : 0.579155
# batch 4 g_loss : 0.880305
# batch 5 d_loss : 0.627563
# batch 5 g_loss : 0.877646
# batch 6 d_loss : 0.565163
# batch 6 g_loss : 0.955332
# Epoch is 60
# Number of batches 7
# batch 0 d_loss : 0.616456
# batch 0 g_loss : 0.892931
# batch 1 d_loss : 0.622225
# batch 1 g_loss : 0.888695
# batch 2 d_loss : 0.620561
# batch 2 g_loss : 0.958005
# batch 3 d_loss : 0.603256
# batch 3 g_loss : 0.973264
# batch 4 d_loss : 0.572210
# batch 4 g_loss : 0.877594
# batch 5 d_loss : 0.648894
# batch 5 g_loss : 0.877626
# batch 6 d_loss : 0.591064
# batch 6 g_loss : 0.917082
# Epoch is 61
# Number of batches 7
# batch 0 d_loss : 0.616793
# batch 0 g_loss : 0.886938
# batch 1 d_loss : 0.639257
# batch 1 g_loss : 0.901350
# batch 2 d_loss : 0.646678
# batch 2 g_loss : 0.880092
# batch 3 d_loss : 0.593781
# batch 3 g_loss : 0.885597
# batch 4 d_loss : 0.598063
# batch 4 g_loss : 0.890834
# batch 5 d_loss : 0.653823
# batch 5 g_loss : 0.924487
# batch 6 d_loss : 0.605373
# batch 6 g_loss : 0.863667
# Epoch is 62
# Number of batches 7
# batch 0 d_loss : 0.656258
# batch 0 g_loss : 0.885846
# batch 1 d_loss : 0.672272
# batch 1 g_loss : 0.862515
# batch 2 d_loss : 0.624846
# batch 2 g_loss : 0.864095
# batch 3 d_loss : 0.622057
# batch 3 g_loss : 0.890873
# batch 4 d_loss : 0.611517
# batch 4 g_loss : 0.879467
# batch 5 d_loss : 0.663104
# batch 5 g_loss : 0.844244
# batch 6 d_loss : 0.625300
# batch 6 g_loss : 0.886584
# Epoch is 63
# Number of batches 7
# batch 0 d_loss : 0.647034
# batch 0 g_loss : 0.879973
# batch 1 d_loss : 0.669774
# batch 1 g_loss : 0.909821
# batch 2 d_loss : 0.639287
# batch 2 g_loss : 0.925417
# batch 3 d_loss : 0.636613
# batch 3 g_loss : 0.899440
# batch 4 d_loss : 0.595895
# batch 4 g_loss : 0.862763
# batch 5 d_loss : 0.673758
# batch 5 g_loss : 0.895758
# batch 6 d_loss : 0.608812
# batch 6 g_loss : 0.880023
# Epoch is 64
# Number of batches 7
# batch 0 d_loss : 0.624470
# batch 0 g_loss : 0.900091
# batch 1 d_loss : 0.677124
# batch 1 g_loss : 0.879891
# batch 2 d_loss : 0.660253
# batch 2 g_loss : 0.913356
# batch 3 d_loss : 0.660415
# batch 3 g_loss : 0.898659
# batch 4 d_loss : 0.614314
# batch 4 g_loss : 0.894417
# batch 5 d_loss : 0.672362
# batch 5 g_loss : 0.845159
# batch 6 d_loss : 0.615017
# batch 6 g_loss : 0.902946
# Epoch is 65
# Number of batches 7
# batch 0 d_loss : 0.646587
# batch 0 g_loss : 0.862076
# batch 1 d_loss : 0.673904
# batch 1 g_loss : 0.879118
# batch 2 d_loss : 0.650287
# batch 2 g_loss : 0.843242
# batch 3 d_loss : 0.640438
# batch 3 g_loss : 0.903435
# batch 4 d_loss : 0.600930
# batch 4 g_loss : 0.881343
# batch 5 d_loss : 0.697613
# batch 5 g_loss : 0.951664
# batch 6 d_loss : 0.630159
# batch 6 g_loss : 0.900624
# Epoch is 66
# Number of batches 7
# batch 0 d_loss : 0.643991
# batch 0 g_loss : 0.859717
# batch 1 d_loss : 0.659574
# batch 1 g_loss : 0.866151
# batch 2 d_loss : 0.653640
# batch 2 g_loss : 0.846627
# batch 3 d_loss : 0.660703
# batch 3 g_loss : 0.860411
# batch 4 d_loss : 0.618260
# batch 4 g_loss : 0.870556
# batch 5 d_loss : 0.686725
# batch 5 g_loss : 0.927624
# batch 6 d_loss : 0.634342
# batch 6 g_loss : 0.888743
# Epoch is 67
# Number of batches 7
# batch 0 d_loss : 0.647382
# batch 0 g_loss : 0.927959
# batch 1 d_loss : 0.656137
# batch 1 g_loss : 0.892248
# batch 2 d_loss : 0.648078
# batch 2 g_loss : 0.917336
# batch 3 d_loss : 0.669752
# batch 3 g_loss : 0.925618
# batch 4 d_loss : 0.609339
# batch 4 g_loss : 0.949524
# batch 5 d_loss : 0.667388
# batch 5 g_loss : 0.859756
# batch 6 d_loss : 0.627090
# batch 6 g_loss : 0.875131
# Epoch is 68
# Number of batches 7
# batch 0 d_loss : 0.634400
# batch 0 g_loss : 0.900266
# batch 1 d_loss : 0.668310
# batch 1 g_loss : 0.911722
# batch 2 d_loss : 0.674744
# batch 2 g_loss : 0.898523
# batch 3 d_loss : 0.656588
# batch 3 g_loss : 0.898179
# batch 4 d_loss : 0.606553
# batch 4 g_loss : 0.858022
# batch 5 d_loss : 0.695418
# batch 5 g_loss : 0.912836
# batch 6 d_loss : 0.637702
# batch 6 g_loss : 0.869520
# Epoch is 69
# Number of batches 7
# batch 0 d_loss : 0.653617
# batch 0 g_loss : 0.894674
# batch 1 d_loss : 0.653723
# batch 1 g_loss : 0.864263
# batch 2 d_loss : 0.640332
# batch 2 g_loss : 0.908561
# batch 3 d_loss : 0.669481
# batch 3 g_loss : 0.897164
# batch 4 d_loss : 0.634607
# batch 4 g_loss : 0.909916
# batch 5 d_loss : 0.669648
# batch 5 g_loss : 0.879509
# batch 6 d_loss : 0.661288
# batch 6 g_loss : 0.903188
# Epoch is 70
# Number of batches 7
# batch 0 d_loss : 0.651447
# batch 0 g_loss : 0.894655
# batch 1 d_loss : 0.656726
# batch 1 g_loss : 0.928487
# batch 2 d_loss : 0.640971
# batch 2 g_loss : 0.900235
# batch 3 d_loss : 0.654784
# batch 3 g_loss : 0.916117
# batch 4 d_loss : 0.609946
# batch 4 g_loss : 0.915184
# batch 5 d_loss : 0.679981
# batch 5 g_loss : 0.890478
# batch 6 d_loss : 0.623768
# batch 6 g_loss : 0.864614
# Epoch is 71
# Number of batches 7
# batch 0 d_loss : 0.634111
# batch 0 g_loss : 0.903298
# batch 1 d_loss : 0.645915
# batch 1 g_loss : 0.906837
# batch 2 d_loss : 0.654850
# batch 2 g_loss : 0.933592
# batch 3 d_loss : 0.655432
# batch 3 g_loss : 0.864661
# batch 4 d_loss : 0.640919
# batch 4 g_loss : 0.899929
# batch 5 d_loss : 0.678080
# batch 5 g_loss : 0.867414
# batch 6 d_loss : 0.653006
# batch 6 g_loss : 0.886171
# Epoch is 72
# Number of batches 7
# batch 0 d_loss : 0.637150
# batch 0 g_loss : 0.843008
# batch 1 d_loss : 0.684040
# batch 1 g_loss : 0.899348
# batch 2 d_loss : 0.658317
# batch 2 g_loss : 0.865576
# batch 3 d_loss : 0.646879
# batch 3 g_loss : 0.860179
# batch 4 d_loss : 0.615027
# batch 4 g_loss : 0.840139
# batch 5 d_loss : 0.680467
# batch 5 g_loss : 0.875794
# batch 6 d_loss : 0.640552
# batch 6 g_loss : 0.834898
# Epoch is 73
# Number of batches 7
# batch 0 d_loss : 0.640461
# batch 0 g_loss : 0.858588
# batch 1 d_loss : 0.676662
# batch 1 g_loss : 0.853808
# batch 2 d_loss : 0.651770
# batch 2 g_loss : 0.904093
# batch 3 d_loss : 0.646932
# batch 3 g_loss : 0.861032
# batch 4 d_loss : 0.638988
# batch 4 g_loss : 0.885608
# batch 5 d_loss : 0.678714
# batch 5 g_loss : 0.856524
# batch 6 d_loss : 0.651566
# batch 6 g_loss : 0.846309
# Epoch is 74
# Number of batches 7
# batch 0 d_loss : 0.640218
# batch 0 g_loss : 0.849083
# batch 1 d_loss : 0.685321
# batch 1 g_loss : 0.877646
# batch 2 d_loss : 0.655656
# batch 2 g_loss : 0.860434
# batch 3 d_loss : 0.648220
# batch 3 g_loss : 0.833522
# batch 4 d_loss : 0.653856
# batch 4 g_loss : 0.840259
# batch 5 d_loss : 0.675427
# batch 5 g_loss : 0.826548
# batch 6 d_loss : 0.656794
# batch 6 g_loss : 0.821573
# Epoch is 75
# Number of batches 7
# batch 0 d_loss : 0.646404
# batch 0 g_loss : 0.818971
# batch 1 d_loss : 0.653896
# batch 1 g_loss : 0.856215
# batch 2 d_loss : 0.671480
# batch 2 g_loss : 0.845144
# batch 3 d_loss : 0.658398
# batch 3 g_loss : 0.842857
# batch 4 d_loss : 0.637649
# batch 4 g_loss : 0.856729
# batch 5 d_loss : 0.667535
# batch 5 g_loss : 0.831885
# batch 6 d_loss : 0.646018
# batch 6 g_loss : 0.853383
# Epoch is 76
# Number of batches 7
# batch 0 d_loss : 0.636624
# batch 0 g_loss : 0.856976
# batch 1 d_loss : 0.660628
# batch 1 g_loss : 0.821697
# batch 2 d_loss : 0.636229
# batch 2 g_loss : 0.842273
# batch 3 d_loss : 0.640346
# batch 3 g_loss : 0.828228
# batch 4 d_loss : 0.631571
# batch 4 g_loss : 0.837423
# batch 5 d_loss : 0.658066
# batch 5 g_loss : 0.818881
# batch 6 d_loss : 0.640123
# batch 6 g_loss : 0.790789
# Epoch is 77
# Number of batches 7
# batch 0 d_loss : 0.638902
# batch 0 g_loss : 0.881354
# batch 1 d_loss : 0.651684
# batch 1 g_loss : 0.823373
# batch 2 d_loss : 0.652237
# batch 2 g_loss : 0.835786
# batch 3 d_loss : 0.648133
# batch 3 g_loss : 0.852846
# batch 4 d_loss : 0.648473
# batch 4 g_loss : 0.808846
# batch 5 d_loss : 0.666261
# batch 5 g_loss : 0.794897
# batch 6 d_loss : 0.660809
# batch 6 g_loss : 0.814767
# Epoch is 78
# Number of batches 7
# batch 0 d_loss : 0.626482
# batch 0 g_loss : 0.850797
# batch 1 d_loss : 0.649716
# batch 1 g_loss : 0.798202
# batch 2 d_loss : 0.647241
# batch 2 g_loss : 0.787595
# batch 3 d_loss : 0.663908
# batch 3 g_loss : 0.826917
# batch 4 d_loss : 0.621451
# batch 4 g_loss : 0.835022
# batch 5 d_loss : 0.665006
# batch 5 g_loss : 0.793285
# batch 6 d_loss : 0.628361
# batch 6 g_loss : 0.838142
# Epoch is 79
# Number of batches 7
# batch 0 d_loss : 0.625953
# batch 0 g_loss : 0.826318
# batch 1 d_loss : 0.633762
# batch 1 g_loss : 0.806222
# batch 2 d_loss : 0.648809
# batch 2 g_loss : 0.830655
# batch 3 d_loss : 0.643901
# batch 3 g_loss : 0.832168
# batch 4 d_loss : 0.627496
# batch 4 g_loss : 0.848115
# batch 5 d_loss : 0.654282
# batch 5 g_loss : 0.798693
# batch 6 d_loss : 0.622614
# batch 6 g_loss : 0.792331
# Epoch is 80
# Number of batches 7
# batch 0 d_loss : 0.638453
# batch 0 g_loss : 0.807723
# batch 1 d_loss : 0.653441
# batch 1 g_loss : 0.842202
# batch 2 d_loss : 0.650898
# batch 2 g_loss : 0.830513
# batch 3 d_loss : 0.664931
# batch 3 g_loss : 0.836838
# batch 4 d_loss : 0.629297
# batch 4 g_loss : 0.830360
# batch 5 d_loss : 0.656272
# batch 5 g_loss : 0.837202
# batch 6 d_loss : 0.641448
# batch 6 g_loss : 0.870251
# Epoch is 81
# Number of batches 7
# batch 0 d_loss : 0.640773
# batch 0 g_loss : 0.857285
# batch 1 d_loss : 0.645517
# batch 1 g_loss : 0.851307
# batch 2 d_loss : 0.647431
# batch 2 g_loss : 0.829303
# batch 3 d_loss : 0.646128
# batch 3 g_loss : 0.870660
# batch 4 d_loss : 0.629779
# batch 4 g_loss : 0.852059
# batch 5 d_loss : 0.645181
# batch 5 g_loss : 0.848599
# batch 6 d_loss : 0.629983
# batch 6 g_loss : 0.844607
# Epoch is 82
# Number of batches 7
# batch 0 d_loss : 0.621611
# batch 0 g_loss : 0.844147
# batch 1 d_loss : 0.625743
# batch 1 g_loss : 0.841028
# batch 2 d_loss : 0.637718
# batch 2 g_loss : 0.874857
# batch 3 d_loss : 0.642755
# batch 3 g_loss : 0.865032
# batch 4 d_loss : 0.631376
# batch 4 g_loss : 0.859598
# batch 5 d_loss : 0.636312
# batch 5 g_loss : 0.834419
# batch 6 d_loss : 0.629651
# batch 6 g_loss : 0.841282
# Epoch is 83
# Number of batches 7
# batch 0 d_loss : 0.615004
# batch 0 g_loss : 0.887396
# batch 1 d_loss : 0.637341
# batch 1 g_loss : 0.888126
# batch 2 d_loss : 0.613850
# batch 2 g_loss : 0.821314
# batch 3 d_loss : 0.622845
# batch 3 g_loss : 0.861606
# batch 4 d_loss : 0.639418
# batch 4 g_loss : 0.809515
# batch 5 d_loss : 0.636350
# batch 5 g_loss : 0.841672
# batch 6 d_loss : 0.625321
# batch 6 g_loss : 0.863874
# Epoch is 84
# Number of batches 7
# batch 0 d_loss : 0.618377
# batch 0 g_loss : 0.826936
# batch 1 d_loss : 0.628853
# batch 1 g_loss : 0.845701
# batch 2 d_loss : 0.645060
# batch 2 g_loss : 0.795710
# batch 3 d_loss : 0.631504
# batch 3 g_loss : 0.832819
# batch 4 d_loss : 0.636409
# batch 4 g_loss : 0.837068
# batch 5 d_loss : 0.637226
# batch 5 g_loss : 0.852279
# batch 6 d_loss : 0.623545
# batch 6 g_loss : 0.825773
# Epoch is 85
# Number of batches 7
# batch 0 d_loss : 0.619724
# batch 0 g_loss : 0.865977
# batch 1 d_loss : 0.630281
# batch 1 g_loss : 0.838344
# batch 2 d_loss : 0.649184
# batch 2 g_loss : 0.922031
# batch 3 d_loss : 0.654299
# batch 3 g_loss : 0.849061
# batch 4 d_loss : 0.627042
# batch 4 g_loss : 0.878814
# batch 5 d_loss : 0.644431
# batch 5 g_loss : 0.845262
# batch 6 d_loss : 0.624119
# batch 6 g_loss : 0.860142
# Epoch is 86
# Number of batches 7
# batch 0 d_loss : 0.621711
# batch 0 g_loss : 0.848171
# batch 1 d_loss : 0.637344
# batch 1 g_loss : 0.870621
# batch 2 d_loss : 0.636544
# batch 2 g_loss : 0.824930
# batch 3 d_loss : 0.642974
# batch 3 g_loss : 0.843664
# batch 4 d_loss : 0.623850
# batch 4 g_loss : 0.871801
# batch 5 d_loss : 0.653416
# batch 5 g_loss : 0.884697
# batch 6 d_loss : 0.645766
# batch 6 g_loss : 0.857567
# Epoch is 87
# Number of batches 7
# batch 0 d_loss : 0.625719
# batch 0 g_loss : 0.877369
# batch 1 d_loss : 0.629924
# batch 1 g_loss : 0.827697
# batch 2 d_loss : 0.625925
# batch 2 g_loss : 0.875901
# batch 3 d_loss : 0.637929
# batch 3 g_loss : 0.863742
# batch 4 d_loss : 0.634057
# batch 4 g_loss : 0.803525
# batch 5 d_loss : 0.644033
# batch 5 g_loss : 0.843079
# batch 6 d_loss : 0.648761
# batch 6 g_loss : 0.834765
# Epoch is 88
# Number of batches 7
# batch 0 d_loss : 0.638232
# batch 0 g_loss : 0.816625
# batch 1 d_loss : 0.650502
# batch 1 g_loss : 0.836602
# batch 2 d_loss : 0.640570
# batch 2 g_loss : 0.825678
# batch 3 d_loss : 0.644025
# batch 3 g_loss : 0.857132
# batch 4 d_loss : 0.638615
# batch 4 g_loss : 0.822650
# batch 5 d_loss : 0.624451
# batch 5 g_loss : 0.821403
# batch 6 d_loss : 0.623445
# batch 6 g_loss : 0.865961
# Epoch is 89
# Number of batches 7
# batch 0 d_loss : 0.622041
# batch 0 g_loss : 0.810201
# batch 1 d_loss : 0.636048
# batch 1 g_loss : 0.810916
# batch 2 d_loss : 0.642381
# batch 2 g_loss : 0.852172
# batch 3 d_loss : 0.663815
# batch 3 g_loss : 0.850993
# batch 4 d_loss : 0.635750
# batch 4 g_loss : 0.836107
# batch 5 d_loss : 0.660749
# batch 5 g_loss : 0.835153
# batch 6 d_loss : 0.655819
# batch 6 g_loss : 0.829471
# Epoch is 90
# Number of batches 7
# batch 0 d_loss : 0.638792
# batch 0 g_loss : 0.833893
# batch 1 d_loss : 0.642588
# batch 1 g_loss : 0.836853
# batch 2 d_loss : 0.644039
# batch 2 g_loss : 0.871047
# batch 3 d_loss : 0.650859
# batch 3 g_loss : 0.796932
# batch 4 d_loss : 0.653371
# batch 4 g_loss : 0.866710
# batch 5 d_loss : 0.655570
# batch 5 g_loss : 0.828976
# batch 6 d_loss : 0.667072
# batch 6 g_loss : 0.828963
# Epoch is 91
# Number of batches 7
# batch 0 d_loss : 0.637346
# batch 0 g_loss : 0.829493
# batch 1 d_loss : 0.639193
# batch 1 g_loss : 0.877027
# batch 2 d_loss : 0.659421
# batch 2 g_loss : 0.849188
# batch 3 d_loss : 0.650298
# batch 3 g_loss : 0.821238
# batch 4 d_loss : 0.644187
# batch 4 g_loss : 0.826293
# batch 5 d_loss : 0.660155
# batch 5 g_loss : 0.833489
# batch 6 d_loss : 0.676237
# batch 6 g_loss : 0.808591
# Epoch is 92
# Number of batches 7
# batch 0 d_loss : 0.611898
# batch 0 g_loss : 0.815952
# batch 1 d_loss : 0.638388
# batch 1 g_loss : 0.854169
# batch 2 d_loss : 0.655960
# batch 2 g_loss : 0.812707
# batch 3 d_loss : 0.654976
# batch 3 g_loss : 0.843081
# batch 4 d_loss : 0.659911
# batch 4 g_loss : 0.855399
# batch 5 d_loss : 0.668508
# batch 5 g_loss : 0.824743
# batch 6 d_loss : 0.653243
# batch 6 g_loss : 0.798089
# Epoch is 93
# Number of batches 7
# batch 0 d_loss : 0.633076
# batch 0 g_loss : 0.824092
# batch 1 d_loss : 0.648063
# batch 1 g_loss : 0.822478
# batch 2 d_loss : 0.645594
# batch 2 g_loss : 0.811881
# batch 3 d_loss : 0.679437
# batch 3 g_loss : 0.813090
# batch 4 d_loss : 0.653051
# batch 4 g_loss : 0.825118
# batch 5 d_loss : 0.654203
# batch 5 g_loss : 0.830916
# batch 6 d_loss : 0.660128
# batch 6 g_loss : 0.810623
# Epoch is 94
# Number of batches 7
# batch 0 d_loss : 0.642120
# batch 0 g_loss : 0.861521
# batch 1 d_loss : 0.647797
# batch 1 g_loss : 0.811060
# batch 2 d_loss : 0.651733
# batch 2 g_loss : 0.827613
# batch 3 d_loss : 0.680554
# batch 3 g_loss : 0.798014
# batch 4 d_loss : 0.657700
# batch 4 g_loss : 0.854472
# batch 5 d_loss : 0.651932
# batch 5 g_loss : 0.825730
# batch 6 d_loss : 0.670873
# batch 6 g_loss : 0.812489
# Epoch is 95
# Number of batches 7
# batch 0 d_loss : 0.634463
# batch 0 g_loss : 0.862548
# batch 1 d_loss : 0.676977
# batch 1 g_loss : 0.803366
# batch 2 d_loss : 0.648980
# batch 2 g_loss : 0.841855
# batch 3 d_loss : 0.663918
# batch 3 g_loss : 0.819312
# batch 4 d_loss : 0.656079
# batch 4 g_loss : 0.888325
# batch 5 d_loss : 0.650525
# batch 5 g_loss : 0.868644
# batch 6 d_loss : 0.667375
# batch 4 d_loss : 0.590997
# batch 4 g_loss : 0.896482
# batch 5 d_loss : 0.610049
# batch 5 g_loss : 0.889342
# batch 6 d_loss : 0.581039
# batch 6 g_loss : 0.912747
# Epoch is 107
# Number of batches 7
# batch 0 d_loss : 0.601312
# batch 0 g_loss : 0.886581
# batch 1 d_loss : 0.598130
# batch 1 g_loss : 0.898923
# batch 2 d_loss : 0.594905
# batch 2 g_loss : 0.894618
# batch 3 d_loss : 0.592973
# batch 3 g_loss : 0.937369
# batch 4 d_loss : 0.581657
# batch 4 g_loss : 0.927303
# batch 5 d_loss : 0.604971
# batch 5 g_loss : 0.889613
# batch 6 d_loss : 0.565477
# batch 6 g_loss : 0.928287
# Epoch is 108
# Number of batches 7
# batch 0 d_loss : 0.589737
# batch 0 g_loss : 0.878466
# batch 1 d_loss : 0.589485
# batch 1 g_loss : 0.908434
# batch 2 d_loss : 0.587025
# batch 2 g_loss : 0.886267
# batch 3 d_loss : 0.581318
# batch 3 g_loss : 0.895752
# batch 4 d_loss : 0.570334
# batch 4 g_loss : 0.873190
# batch 5 d_loss : 0.597124
# batch 5 g_loss : 0.907136
# batch 6 d_loss : 0.579840
# batch 6 g_loss : 0.907818
# Epoch is 109
# Number of batches 7
# batch 0 d_loss : 0.580778
# batch 0 g_loss : 0.930281
# batch 1 d_loss : 0.590061
# batch 1 g_loss : 0.904156
# batch 2 d_loss : 0.599658
# batch 2 g_loss : 0.877840
# batch 3 d_loss : 0.579028
# batch 3 g_loss : 0.936392
# batch 4 d_loss : 0.569843
# batch 4 g_loss : 0.894011
# batch 5 d_loss : 0.579347
# batch 5 g_loss : 0.929565
# batch 6 d_loss : 0.567241
# batch 6 g_loss : 0.893676
# Epoch is 110
# Number of batches 7
# batch 0 d_loss : 0.572833
# batch 0 g_loss : 0.902851
# batch 1 d_loss : 0.584839
# batch 1 g_loss : 0.882930
# batch 2 d_loss : 0.566267
# batch 2 g_loss : 0.926142
# batch 3 d_loss : 0.588476
# batch 3 g_loss : 0.916623
# batch 4 d_loss : 0.549158
# batch 4 g_loss : 0.894372
# batch 5 d_loss : 0.595911
# batch 5 g_loss : 0.910113
# batch 6 d_loss : 0.562473
# batch 6 g_loss : 0.921767
# Epoch is 111
# Number of batches 7
# batch 0 d_loss : 0.572442
# batch 0 g_loss : 0.949862
# batch 1 d_loss : 0.578200
# batch 1 g_loss : 0.915672
# batch 2 d_loss : 0.588583
# batch 2 g_loss : 0.935144
# batch 3 d_loss : 0.577915
# batch 3 g_loss : 0.900047
# batch 4 d_loss : 0.577183
# batch 4 g_loss : 0.911420
# batch 5 d_loss : 0.581908
# batch 5 g_loss : 0.912112
# batch 6 d_loss : 0.555923
# batch 6 g_loss : 0.936114
# Epoch is 112
# Number of batches 7
# batch 0 d_loss : 0.581314
# batch 0 g_loss : 0.926747
# batch 1 d_loss : 0.569240
# batch 1 g_loss : 0.914288
# batch 2 d_loss : 0.572214
# batch 2 g_loss : 0.939163
# batch 3 d_loss : 0.552604
# batch 3 g_loss : 0.880064
# batch 4 d_loss : 0.562372
# batch 4 g_loss : 0.966543
# batch 5 d_loss : 0.574214
# batch 5 g_loss : 0.871159
# batch 6 d_loss : 0.544600
# batch 6 g_loss : 0.878273
# Epoch is 113
# Number of batches 7
# batch 0 d_loss : 0.568520
# batch 0 g_loss : 0.942629
# batch 1 d_loss : 0.581857
# batch 1 g_loss : 0.905396
# batch 2 d_loss : 0.545100
# batch 2 g_loss : 0.902411
# batch 3 d_loss : 0.576572
# batch 3 g_loss : 0.938264
# batch 4 d_loss : 0.568431
# batch 4 g_loss : 0.914965
# batch 5 d_loss : 0.567165
# batch 5 g_loss : 0.890790
# batch 6 d_loss : 0.555430
# batch 6 g_loss : 0.895674
# Epoch is 114
# Number of batches 7
# batch 0 d_loss : 0.557248
# batch 0 g_loss : 0.892473
# batch 1 d_loss : 0.552239
# batch 1 g_loss : 0.881256
# batch 2 d_loss : 0.561048
# batch 2 g_loss : 0.921690
# batch 3 d_loss : 0.557981
# batch 3 g_loss : 0.888265
# batch 4 d_loss : 0.538637
# batch 4 g_loss : 0.885826
# batch 5 d_loss : 0.567742
# batch 5 g_loss : 0.935260
# batch 6 d_loss : 0.552862
# batch 6 g_loss : 0.904236
# Epoch is 115
# Number of batches 7
# batch 0 d_loss : 0.553900
# batch 0 g_loss : 0.970469
# batch 1 d_loss : 0.565949
# batch 1 g_loss : 0.936785
# batch 2 d_loss : 0.579204
# batch 2 g_loss : 0.906756
# batch 3 d_loss : 0.552533
# batch 3 g_loss : 0.926903
# batch 4 d_loss : 0.539133
# batch 4 g_loss : 0.909731
# batch 5 d_loss : 0.564010
# batch 5 g_loss : 0.918385
# batch 6 d_loss : 0.546430
# batch 6 g_loss : 0.933264
# Epoch is 116
# Number of batches 7
# batch 0 d_loss : 0.562363
# batch 0 g_loss : 0.913174
# batch 1 d_loss : 0.556589
# batch 1 g_loss : 0.916052
# batch 2 d_loss : 0.548349
# batch 2 g_loss : 0.949125
# batch 3 d_loss : 0.570253
# batch 3 g_loss : 0.951590
# batch 4 d_loss : 0.532118
# batch 4 g_loss : 0.935527
# batch 5 d_loss : 0.537618
# batch 5 g_loss : 0.948917
# batch 6 d_loss : 0.532890
# batch 6 g_loss : 0.958335
# Epoch is 117
# Number of batches 7
# batch 0 d_loss : 0.552896
# batch 0 g_loss : 0.967227
# batch 1 d_loss : 0.555660
# batch 1 g_loss : 0.936845
# batch 2 d_loss : 0.554057
# batch 2 g_loss : 0.932513
# batch 3 d_loss : 0.551345
# batch 3 g_loss : 0.903932
# batch 4 d_loss : 0.537114
# batch 4 g_loss : 0.943270
# batch 5 d_loss : 0.542719
# batch 5 g_loss : 0.910447
# batch 6 d_loss : 0.534635
# batch 6 g_loss : 0.952765
# Epoch is 118
# Number of batches 7
# batch 0 d_loss : 0.534885
# batch 0 g_loss : 0.931744
# batch 1 d_loss : 0.552111
# batch 1 g_loss : 0.920421
# batch 2 d_loss : 0.552154
# batch 2 g_loss : 0.930654
# batch 3 d_loss : 0.551823
# batch 3 g_loss : 0.910102
# batch 0 d_loss : 0.442158
# batch 0 g_loss : 1.077876
# batch 1 d_loss : 0.459352
# batch 1 g_loss : 1.070089
# batch 2 d_loss : 0.425798
# batch 2 g_loss : 1.043058
# batch 3 d_loss : 0.438259
# batch 3 g_loss : 1.073482
# batch 4 d_loss : 0.412852
# batch 4 g_loss : 1.133505
# batch 5 d_loss : 0.454963
# batch 5 g_loss : 1.063496
# batch 6 d_loss : 0.419743
# batch 6 g_loss : 1.127438
# Epoch is 134
# Number of batches 7
# batch 0 d_loss : 0.419981
# batch 0 g_loss : 1.103910
# batch 1 d_loss : 0.454519
# batch 1 g_loss : 1.085183
# batch 2 d_loss : 0.411035
# batch 2 g_loss : 1.114846
# batch 3 d_loss : 0.424722
# batch 3 g_loss : 1.050830
# batch 4 d_loss : 0.411935
# batch 4 g_loss : 1.081082
# batch 5 d_loss : 0.461912
# batch 5 g_loss : 1.077891
# batch 6 d_loss : 0.426386
# batch 6 g_loss : 1.069569
# Epoch is 135
# Number of batches 7
# batch 0 d_loss : 0.433082
# batch 0 g_loss : 1.133014
# batch 1 d_loss : 0.431672
# batch 1 g_loss : 1.069115
# batch 2 d_loss : 0.415607
# batch 2 g_loss : 1.121568
# batch 3 d_loss : 0.404341
# batch 3 g_loss : 1.133472
# batch 4 d_loss : 0.397603
# batch 4 g_loss : 1.116748
# batch 5 d_loss : 0.441737
# batch 5 g_loss : 1.091379
# batch 6 d_loss : 0.404138
# batch 6 g_loss : 1.100206
# Epoch is 136
# Number of batches 7
# batch 0 d_loss : 0.410213
# batch 0 g_loss : 1.087425
# batch 1 d_loss : 0.425819
# batch 1 g_loss : 1.078596
# batch 2 d_loss : 0.410044
# batch 2 g_loss : 1.136987
# batch 3 d_loss : 0.419520
# batch 3 g_loss : 1.122091
# batch 4 d_loss : 0.405281
# batch 4 g_loss : 1.149896
# batch 5 d_loss : 0.433032
# batch 5 g_loss : 1.170349
# batch 6 d_loss : 0.408174
# batch 6 g_loss : 1.175558
# Epoch is 137
# Number of batches 7
# batch 0 d_loss : 0.407625
# batch 0 g_loss : 1.180411
# batch 1 d_loss : 0.427470
# batch 1 g_loss : 1.147529
# batch 2 d_loss : 0.407075
# batch 2 g_loss : 1.124295
# batch 3 d_loss : 0.408662
# batch 3 g_loss : 1.110282
# batch 4 d_loss : 0.385206
# batch 4 g_loss : 1.144975
# batch 5 d_loss : 0.446016
# batch 5 g_loss : 1.090235
# batch 6 d_loss : 0.399855
# batch 6 g_loss : 1.140242
# Epoch is 138
# Number of batches 7
# batch 0 d_loss : 0.391912
# batch 0 g_loss : 1.150690
# batch 1 d_loss : 0.417755
# batch 1 g_loss : 1.149493
# batch 2 d_loss : 0.385495
# batch 2 g_loss : 1.194331
# batch 3 d_loss : 0.402000
# batch 3 g_loss : 1.185452
# batch 4 d_loss : 0.384513
# batch 4 g_loss : 1.215771
# batch 5 d_loss : 0.449127
# batch 5 g_loss : 1.216818
# batch 6 d_loss : 0.379335
# batch 6 g_loss : 1.216650
# Epoch is 139
# Number of batches 7
# batch 0 d_loss : 0.397382
# batch 0 g_loss : 1.209835
# batch 1 d_loss : 0.405481
# batch 1 g_loss : 1.132719
# batch 2 d_loss : 0.386593
# batch 2 g_loss : 1.191761
# batch 3 d_loss : 0.394205
# batch 3 g_loss : 1.146543
# batch 4 d_loss : 0.362444
# batch 4 g_loss : 1.208845
# batch 5 d_loss : 0.433710
# batch 5 g_loss : 1.230132
# batch 6 d_loss : 0.389251
# batch 6 g_loss : 1.252589
# Epoch is 140
# Number of batches 7
# batch 0 d_loss : 0.386792
# batch 0 g_loss : 1.214543
# batch 1 d_loss : 0.409163
# batch 1 g_loss : 1.228715
# batch 2 d_loss : 0.371718
# batch 2 g_loss : 1.264572
# batch 3 d_loss : 0.385650
# batch 3 g_loss : 1.221209
# batch 4 d_loss : 0.371200
# batch 4 g_loss : 1.210368
# batch 5 d_loss : 0.419867
# batch 5 g_loss : 1.217666
# batch 6 d_loss : 0.373440
# batch 6 g_loss : 1.215342
# Epoch is 141
# Number of batches 7
# batch 0 d_loss : 0.378562
# batch 0 g_loss : 1.217804
# batch 1 d_loss : 0.395243
# batch 1 g_loss : 1.242704
# batch 2 d_loss : 0.373882
# batch 2 g_loss : 1.247858
# batch 3 d_loss : 0.361635
# batch 3 g_loss : 1.188197
# batch 4 d_loss : 0.352595
# batch 4 g_loss : 1.222680
# batch 5 d_loss : 0.423579
# batch 5 g_loss : 1.199608
# batch 6 d_loss : 0.374757
# batch 6 g_loss : 1.272291
# Epoch is 142
# Number of batches 7
# batch 0 d_loss : 0.379539
# batch 0 g_loss : 1.203249
# batch 1 d_loss : 0.398473
# batch 1 g_loss : 1.184461
# batch 2 d_loss : 0.355012
# batch 2 g_loss : 1.244183
# batch 3 d_loss : 0.372214
# batch 3 g_loss : 1.240320
# batch 4 d_loss : 0.354942
# batch 4 g_loss : 1.296003
# batch 5 d_loss : 0.417778
# batch 5 g_loss : 1.248185
# batch 6 d_loss : 0.364266
# batch 6 g_loss : 1.256481
# Epoch is 143
# Number of batches 7
# batch 0 d_loss : 0.381732
# batch 0 g_loss : 1.237334
# batch 1 d_loss : 0.376472
# batch 1 g_loss : 1.234042
# batch 2 d_loss : 0.372448
# batch 2 g_loss : 1.243029
# batch 3 d_loss : 0.368606
# batch 3 g_loss : 1.208182
# batch 4 d_loss : 0.368167
# batch 4 g_loss : 1.231927
# batch 5 d_loss : 0.413784
# batch 5 g_loss : 1.217992
# batch 6 d_loss : 0.373634
# batch 6 g_loss : 1.275587
# Epoch is 144
# Number of batches 7
# batch 0 d_loss : 0.372952
# batch 0 g_loss : 1.334876
# batch 1 d_loss : 0.375136
# batch 1 g_loss : 1.268898
# batch 2 d_loss : 0.359607
# batch 2 g_loss : 1.335849
# batch 3 d_loss : 0.359747
# batch 3 g_loss : 1.293502
# batch 4 d_loss : 0.360112
# batch 4 g_loss : 1.271889
# batch 5 d_loss : 0.408224
# batch 5 g_loss : 1.301601
# batch 6 d_loss : 0.362719
# batch 6 g_loss : 1.293020
# Epoch is 145
# Number of batches 7
# batch 0 d_loss : 0.372116
# batch 0 g_loss : 1.278372
# batch 1 d_loss : 0.384556
# batch 1 g_loss : 1.292453
# batch 2 d_loss : 0.376141
# batch 2 g_loss : 1.291361
# batch 3 d_loss : 0.358333
# batch 3 g_loss : 1.288812
# batch 4 d_loss : 0.359671
# batch 4 g_loss : 1.288860
# batch 5 d_loss : 0.401205
# batch 5 g_loss : 1.279585
# batch 6 d_loss : 0.364170
# batch 6 g_loss : 1.227563
# Epoch is 146
# Number of batches 7
# batch 1 d_loss : 0.616501
# batch 1 g_loss : 1.013730
# ...
# Number of batches 7
# batch 0 d_loss : 0.163942
# batch 0 g_loss : 2.662572
# batch 1 d_loss : 0.130645
# batch 1 g_loss : 2.774065
# batch 2 d_loss : 0.132728
# batch 2 g_loss : 2.754629
# batch 3 d_loss : 0.133083
# batch 3 g_loss : 2.574551
# batch 4 d_loss : 0.140958
# batch 4 g_loss : 2.489622
# batch 5 d_loss : 0.136305
# batch 5 g_loss : 2.380608
# batch 6 d_loss : 0.144457
# batch 6 g_loss : 2.588646
# Epoch is 1450
# Number of batches 7
# batch 0 d_loss : 0.148158
# batch 0 g_loss : 2.590086
# batch 1 d_loss : 0.139368
# batch 1 g_loss : 2.801899
# batch 2 d_loss : 0.149144
# batch 2 g_loss : 2.768425
# batch 3 d_loss : 0.142410
# batch 3 g_loss : 2.658248
# batch 4 d_loss : 0.134102
# batch 4 g_loss : 2.646556
# batch 5 d_loss : 0.138984
# batch 5 g_loss : 2.650717
# batch 6 d_loss : 0.135038
# batch 6 g_loss : 2.547716
# Epoch is 1451
# Number of batches 7
# batch 0 d_loss : 0.148926
# batch 0 g_loss : 2.753173
# batch 1 d_loss : 0.127050
# batch 1 g_loss : 2.734222
# batch 2 d_loss : 0.121950
# batch 2 g_loss : 2.703763
# batch 3 d_loss : 0.132117
# batch 3 g_loss : 2.652976
# batch 4 d_loss : 0.144449
# batch 4 g_loss : 2.903376
# batch 5 d_loss : 0.144294
# batch 5 g_loss : 2.618023
# batch 6 d_loss : 0.142255
# batch 6 g_loss : 2.769425
# Epoch is 1452
# Number of batches 7
# batch 0 d_loss : 0.136028
# batch 0 g_loss : 2.769759
# batch 1 d_loss : 0.123436
# batch 1 g_loss : 2.632703
# batch 2 d_loss : 0.120833
# batch 2 g_loss : 2.904270
# batch 3 d_loss : 0.126460
# batch 3 g_loss : 2.894668
# batch 4 d_loss : 0.136483
# batch 4 g_loss : 2.643576
# batch 5 d_loss : 0.142033
# batch 5 g_loss : 2.622857
# batch 6 d_loss : 0.136319
# batch 6 g_loss : 2.466151
# Epoch is 1453
# Number of batches 7
# batch 0 d_loss : 0.146483
# batch 0 g_loss : 2.732922
# batch 1 d_loss : 0.135996
# batch 1 g_loss : 2.702052
# batch 2 d_loss : 0.125131
# batch 2 g_loss : 2.787037
# batch 3 d_loss : 0.146241
# batch 3 g_loss : 2.687072
# batch 4 d_loss : 0.140219
# batch 4 g_loss : 2.746826
# batch 5 d_loss : 0.156357
# batch 5 g_loss : 2.681771
# batch 6 d_loss : 0.148011
# batch 6 g_loss : 2.574618
# Epoch is 1454
# Number of batches 7
# batch 0 d_loss : 0.147127
# batch 0 g_loss : 2.724084
# batch 1 d_loss : 0.123139
# batch 1 g_loss : 2.634889
# batch 2 d_loss : 0.129717
# batch 2 g_loss : 2.641205
# batch 3 d_loss : 0.153572
# batch 3 g_loss : 2.869319
# batch 4 d_loss : 0.157221
# batch 4 g_loss : 2.755016
# batch 5 d_loss : 0.150077
# batch 5 g_loss : 2.590558
# batch 6 d_loss : 0.150744
# batch 6 g_loss : 2.669390
# Epoch is 1455
# Number of batches 7
# batch 0 d_loss : 0.150426
# batch 0 g_loss : 2.533307
# batch 1 d_loss : 0.119072
# batch 1 g_loss : 2.888968
# batch 2 d_loss : 0.121409
# batch 2 g_loss : 2.843868
# batch 3 d_loss : 0.126994
# batch 3 g_loss : 2.869690
# batch 4 d_loss : 0.138046
# batch 4 g_loss : 2.647909
# batch 5 d_loss : 0.132486
# batch 5 g_loss : 2.622099
# batch 6 d_loss : 0.122454
# batch 6 g_loss : 2.798893
# Epoch is 1456
# Number of batches 7
# batch 0 d_loss : 0.152865
# batch 0 g_loss : 2.516948
# batch 1 d_loss : 0.118943
# batch 1 g_loss : 2.750294
# batch 2 d_loss : 0.139986
# batch 2 g_loss : 2.687976
# batch 3 d_loss : 0.132604
# batch 3 g_loss : 2.533539
# batch 4 d_loss : 0.121434
# batch 4 g_loss : 2.637523
# batch 5 d_loss : 0.130457
# batch 5 g_loss : 2.577833
# batch 6 d_loss : 0.122497
# batch 6 g_loss : 2.821466
# Epoch is 1457
# Number of batches 7
# batch 0 d_loss : 0.140017
# batch 0 g_loss : 2.567566
# batch 1 d_loss : 0.132728
# batch 1 g_loss : 2.677888
# batch 2 d_loss : 0.131136
# batch 2 g_loss : 2.777143
# batch 3 d_loss : 0.144660
# batch 3 g_loss : 2.613457
# batch 4 d_loss : 0.133913
# batch 4 g_loss : 2.679899
# batch 5 d_loss : 0.127019
# batch 5 g_loss : 2.573207
# batch 6 d_loss : 0.135566
# batch 6 g_loss : 2.459087
# Epoch is 1458
# Number of batches 7
# batch 0 d_loss : 0.141465
# batch 0 g_loss : 2.505616
# batch 1 d_loss : 0.124595
# batch 1 g_loss : 2.634602
# batch 2 d_loss : 0.143481
# batch 2 g_loss : 2.798791
# batch 3 d_loss : 0.144630
# batch 3 g_loss : 2.687918
# batch 4 d_loss : 0.132338
# batch 4 g_loss : 2.877824
# batch 5 d_loss : 0.141601
# batch 5 g_loss : 2.525288
# batch 6 d_loss : 0.127245
# batch 6 g_loss : 2.553676
# Epoch is 1459
# Number of batches 7
# batch 0 d_loss : 0.156907
# batch 0 g_loss : 2.491195
# batch 1 d_loss : 0.143426
# batch 1 g_loss : 2.497138
# batch 2 d_loss : 0.128146
# batch 2 g_loss : 2.981812
# batch 3 d_loss : 0.146616
# batch 3 g_loss : 2.640823
# batch 4 d_loss : 0.138957
# batch 4 g_loss : 2.869578
# batch 5 d_loss : 0.149443
# batch 5 g_loss : 2.586568
# batch 6 d_loss : 0.146957
# batch 6 g_loss : 2.563912
# Epoch is 1460
# Number of batches 7
# batch 0 d_loss : 0.148294
# batch 0 g_loss : 2.678523
# batch 1 d_loss : 0.148710
# batch 1 g_loss : 2.708601
# batch 2 d_loss : 0.125519
# batch 2 g_loss : 2.670618
# batch 3 d_loss : 0.138493
# batch 3 g_loss : 2.474539
# batch 4 d_loss : 0.142579
# batch 4 g_loss : 2.628937
# batch 5 d_loss : 0.165783
# batch 5 g_loss : 2.604491
# batch 6 d_loss : 0.141746
# batch 6 g_loss : 2.822693
# Epoch is 1461
# Number of batches 7
# batch 0 d_loss : 0.142127
# batch 0 g_loss : 2.802563
# batch 1 d_loss : 0.129128
# batch 1 g_loss : 2.767534
# batch 2 d_loss : 0.121537
# batch 2 g_loss : 2.690425
# batch 3 d_loss : 0.131209
# batch 3 g_loss : 2.663957
# batch 4 d_loss : 0.129395
# batch 4 g_loss : 2.872275
# batch 5 d_loss : 0.122416
# batch 5 g_loss : 2.552329
# batch 6 d_loss : 0.134154
# batch 6 g_loss : 2.672461
# Epoch is 1462
# Number of batches 7
# batch 0 d_loss : 0.130051
# batch 0 g_loss : 2.784146
# batch 1 d_loss : 0.111220
# batch 1 g_loss : 2.575915
# batch 2 d_loss : 0.118723
# batch 2 g_loss : 2.738665
# batch 3 d_loss : 0.117674
# batch 3 g_loss : 2.960203
# batch 4 d_loss : 0.131672
# batch 4 g_loss : 2.597711
# batch 5 d_loss : 0.122309
# batch 5 g_loss : 2.600034
# batch 6 d_loss : 0.137407
# batch 6 g_loss : 2.501024
# Epoch is 1463
# Number of batches 7
# batch 0 d_loss : 0.139419
# batch 0 g_loss : 2.677547
# batch 1 d_loss : 0.133718
# batch 1 g_loss : 2.515599
# batch 2 d_loss : 0.135624
# batch 2 g_loss : 2.682644
# batch 3 d_loss : 0.154385
# batch 3 g_loss : 2.939001
# batch 4 d_loss : 0.137336
# batch 4 g_loss : 2.676944
# batch 5 d_loss : 0.155472
# batch 5 g_loss : 2.529675
# batch 6 d_loss : 0.142715
# batch 6 g_loss : 2.789245
# Epoch is 1464
# Number of batches 7
# batch 0 d_loss : 0.181073
# batch 0 g_loss : 2.610095
# batch 1 d_loss : 0.139980
# batch 1 g_loss : 2.698880
# batch 2 d_loss : 0.135638
# batch 2 g_loss : 2.801856
# batch 3 d_loss : 0.145515
# batch 3 g_loss : 2.652942
# batch 4 d_loss : 0.147121
# batch 4 g_loss : 2.874474
# batch 5 d_loss : 0.118980
# batch 5 g_loss : 2.880227
# batch 6 d_loss : 0.134490
# batch 6 g_loss : 2.844724
# Epoch is 1465
# Number of batches 7
# batch 0 d_loss : 0.133411
# batch 0 g_loss : 2.859160
# batch 1 d_loss : 0.104764
# batch 1 g_loss : 2.813431
# batch 2 d_loss : 0.115206
# batch 2 g_loss : 2.916413
# batch 3 d_loss : 0.114755
# batch 3 g_loss : 2.954336
# batch 4 d_loss : 0.113209
# batch 4 g_loss : 2.967056
# batch 5 d_loss : 0.109223
# batch 5 g_loss : 2.843204
# batch 6 d_loss : 0.114922
# batch 6 g_loss : 2.624464
# Epoch is 1466
# Number of batches 7
# batch 0 d_loss : 0.111412
# batch 0 g_loss : 2.651841
# batch 1 d_loss : 0.095824
# batch 1 g_loss : 2.860650
# batch 2 d_loss : 0.128836
# batch 2 g_loss : 2.825433
# batch 3 d_loss : 0.109894
# batch 3 g_loss : 3.066056
# batch 4 d_loss : 0.121846
# batch 4 g_loss : 2.748154
# batch 5 d_loss : 0.114104
# batch 5 g_loss : 2.780212
# batch 6 d_loss : 0.115378
# batch 6 g_loss : 2.575028
# Epoch is 1467
# Number of batches 7
# batch 0 d_loss : 0.132377
# batch 0 g_loss : 2.815866
# batch 1 d_loss : 0.129204
# batch 1 g_loss : 2.852004
# batch 2 d_loss : 0.135511
# batch 2 g_loss : 2.866991
# batch 3 d_loss : 0.130318
# batch 3 g_loss : 3.162700
# batch 4 d_loss : 0.131032
# batch 4 g_loss : 2.949756
# batch 5 d_loss : 0.136100
# batch 5 g_loss : 2.787017
# batch 6 d_loss : 0.132821
# batch 6 g_loss : 2.691795
# Epoch is 1468
# Number of batches 7
# batch 0 d_loss : 0.159838
# batch 0 g_loss : 2.792797
# batch 1 d_loss : 0.123690
# batch 1 g_loss : 2.839973
# batch 2 d_loss : 0.121335
# batch 2 g_loss : 2.938438
# batch 3 d_loss : 0.143969
# batch 3 g_loss : 2.513493
# batch 4 d_loss : 0.152778
# batch 4 g_loss : 2.854848
# batch 5 d_loss : 0.141533
# batch 5 g_loss : 2.727993
# batch 6 d_loss : 0.154514
# batch 6 g_loss : 2.421669
# Epoch is 1469
# Number of batches 7
# batch 0 d_loss : 0.168765
# batch 0 g_loss : 2.518780
# batch 1 d_loss : 0.143940
# batch 1 g_loss : 2.669492
# batch 2 d_loss : 0.127985
# batch 2 g_loss : 2.546912
# batch 3 d_loss : 0.136985
# batch 3 g_loss : 2.584991
# batch 4 d_loss : 0.146805
# batch 4 g_loss : 2.568698
# batch 5 d_loss : 0.150331
# batch 5 g_loss : 2.596073
# batch 6 d_loss : 0.139612
# batch 6 g_loss : 2.644382
# Epoch is 1470
# Number of batches 7
# batch 0 d_loss : 0.161027
# batch 0 g_loss : 2.567499
# batch 1 d_loss : 0.136341
# batch 1 g_loss : 2.480036
# batch 2 d_loss : 0.147380
# batch 2 g_loss : 2.548903
# batch 3 d_loss : 0.155905
# batch 3 g_loss : 2.811822
# batch 4 d_loss : 0.140422
# batch 4 g_loss : 2.713585
# batch 5 d_loss : 0.188086
# batch 5 g_loss : 2.624921
# batch 6 d_loss : 0.140325
# batch 6 g_loss : 2.768249
# Epoch is 1471
# Number of batches 7
# batch 0 d_loss : 0.127123
# batch 0 g_loss : 3.112265
# batch 1 d_loss : 0.109597
# batch 1 g_loss : 3.194013
# batch 2 d_loss : 0.111920
# batch 2 g_loss : 3.262997
# batch 3 d_loss : 0.101044
# batch 3 g_loss : 3.046860
# batch 4 d_loss : 0.117284
# batch 4 g_loss : 2.992124
# batch 5 d_loss : 0.115994
# batch 5 g_loss : 2.787668
# batch 6 d_loss : 0.131270
# batch 6 g_loss : 2.602951
# Epoch is 1472
# Number of batches 7
# batch 0 d_loss : 0.134129
# batch 0 g_loss : 2.661374
# batch 1 d_loss : 0.124379
# batch 1 g_loss : 2.769862
# batch 2 d_loss : 0.127288
# batch 2 g_loss : 2.646341
# batch 3 d_loss : 0.143118
# batch 3 g_loss : 2.672113
# batch 4 d_loss : 0.124388
# batch 4 g_loss : 2.846405
# batch 5 d_loss : 0.153566
# batch 5 g_loss : 2.895137
# batch 6 d_loss : 0.127741
# batch 6 g_loss : 2.663149
# Epoch is 1473
# Number of batches 7
# batch 0 d_loss : 0.147263
# batch 0 g_loss : 2.569559
# batch 1 d_loss : 0.123724
# batch 1 g_loss : 2.502179
# batch 2 d_loss : 0.124622
# batch 2 g_loss : 2.872092
# batch 3 d_loss : 0.134327
# batch 3 g_loss : 2.582357
# batch 4 d_loss : 0.133616
# batch 4 g_loss : 2.766816
# batch 5 d_loss : 0.131224
# batch 5 g_loss : 2.814358
# batch 6 d_loss : 0.140131
# batch 6 g_loss : 2.759263
# Epoch is 1474
# Number of batches 7
# batch 0 d_loss : 0.154419
# batch 0 g_loss : 2.578033
# batch 1 d_loss : 0.118828
# batch 1 g_loss : 2.976577
# batch 2 d_loss : 0.119512
# batch 2 g_loss : 2.742128
# batch 3 d_loss : 0.122727
# batch 3 g_loss : 2.943374
# batch 4 d_loss : 0.117838
# batch 4 g_loss : 2.679473
# batch 5 d_loss : 0.128572
# batch 5 g_loss : 2.672489
# batch 6 d_loss : 0.133255
# batch 6 g_loss : 2.772315
# Epoch is 1475
# Number of batches 7
# batch 0 d_loss : 0.130456
# batch 0 g_loss : 2.591855
# batch 1 d_loss : 0.116566
# batch 1 g_loss : 3.007829
# batch 2 d_loss : 0.116075
# batch 2 g_loss : 2.964295
# batch 3 d_loss : 0.133997
# batch 3 g_loss : 2.677292
# batch 4 d_loss : 0.133272
# batch 4 g_loss : 2.708266
# batch 5 d_loss : 0.128615
# batch 5 g_loss : 2.843981
# batch 6 d_loss : 0.118523
# batch 6 g_loss : 2.609053
# Epoch is 1476
# Number of batches 7
# batch 0 d_loss : 0.122228
# batch 0 g_loss : 2.788212
# batch 1 d_loss : 0.105328
# batch 1 g_loss : 2.978828
# batch 2 d_loss : 0.108084
# batch 2 g_loss : 2.849891
# batch 3 d_loss : 0.116298
# batch 3 g_loss : 3.183641
# batch 4 d_loss : 0.106898
# batch 4 g_loss : 2.779689
# batch 5 d_loss : 0.102094
# batch 5 g_loss : 2.699158
# batch 6 d_loss : 0.113044
# batch 6 g_loss : 2.774655
# Epoch is 1477
# Number of batches 7
# batch 0 d_loss : 0.117790
# batch 0 g_loss : 2.924081
# batch 1 d_loss : 0.087322
# batch 1 g_loss : 2.924096
# batch 2 d_loss : 0.088914
# batch 2 g_loss : 2.821116
# batch 3 d_loss : 0.105450
# batch 3 g_loss : 2.908870
# batch 4 d_loss : 0.093490
# batch 4 g_loss : 3.096486
# batch 5 d_loss : 0.095953
# batch 5 g_loss : 3.059262
# batch 6 d_loss : 0.115514
# batch 6 g_loss : 2.725476
# Epoch is 1478
# Number of batches 7
# batch 0 d_loss : 0.115622
# batch 0 g_loss : 2.902323
# batch 1 d_loss : 0.111281
# batch 1 g_loss : 2.752832
# batch 2 d_loss : 0.108749
# batch 2 g_loss : 2.945158
# batch 3 d_loss : 0.134187
# batch 3 g_loss : 2.650885
# batch 4 d_loss : 0.119717
# batch 4 g_loss : 2.759835
# batch 5 d_loss : 0.122968
# batch 5 g_loss : 2.838353
# batch 6 d_loss : 0.138784
# batch 6 g_loss : 2.900478
# Epoch is 1479
# Number of batches 7
# batch 0 d_loss : 0.148313
# batch 0 g_loss : 2.773731
# batch 1 d_loss : 0.119641
# batch 1 g_loss : 2.819778
# batch 2 d_loss : 0.127114
# batch 2 g_loss : 2.878468
# batch 3 d_loss : 0.148057
# batch 3 g_loss : 2.804410
# batch 4 d_loss : 0.136668
# batch 4 g_loss : 2.643582
# batch 5 d_loss : 0.155333
# batch 5 g_loss : 2.721175
# batch 6 d_loss : 0.137099
# batch 6 g_loss : 2.666036
# Epoch is 1480
# Number of batches 7
# batch 0 d_loss : 0.144071
# batch 0 g_loss : 2.576275
# batch 1 d_loss : 0.131640
# batch 1 g_loss : 2.628132
# batch 2 d_loss : 0.148807
# batch 2 g_loss : 2.803226
# batch 3 d_loss : 0.146721
# batch 3 g_loss : 2.411886
# batch 4 d_loss : 0.152008
# batch 4 g_loss : 2.583907
# batch 5 d_loss : 0.148172
# batch 5 g_loss : 2.616597
# batch 6 d_loss : 0.150649
# batch 6 g_loss : 2.516554
# Epoch is 1481
# Number of batches 7
# batch 0 d_loss : 0.161474
# batch 0 g_loss : 2.425061
# batch 1 d_loss : 0.162345
# batch 1 g_loss : 2.594087
# batch 2 d_loss : 0.149478
# batch 2 g_loss : 2.806010
# batch 3 d_loss : 0.160645
# batch 3 g_loss : 2.692060
# batch 4 d_loss : 0.145311
# batch 4 g_loss : 2.547411
# batch 5 d_loss : 0.177071
# batch 5 g_loss : 2.442966
# batch 6 d_loss : 0.153564
# batch 6 g_loss : 2.625899
# Epoch is 1482
# Number of batches 7
# batch 0 d_loss : 0.142594
# batch 0 g_loss : 2.936027
# batch 1 d_loss : 0.099639
# batch 1 g_loss : 3.132008
# batch 2 d_loss : 0.099173
# batch 2 g_loss : 3.467157
# batch 3 d_loss : 0.096373
# batch 3 g_loss : 3.134300
# batch 4 d_loss : 0.095708
# batch 4 g_loss : 3.404171
# batch 5 d_loss : 0.099313
# batch 5 g_loss : 3.234852
# batch 6 d_loss : 0.089101
# batch 6 g_loss : 3.040668
# Epoch is 1483
# Number of batches 7
# batch 0 d_loss : 0.115602
# batch 0 g_loss : 3.021565
# batch 1 d_loss : 0.105895
# batch 1 g_loss : 2.950132
# batch 2 d_loss : 0.091324
# batch 2 g_loss : 3.042454
# batch 3 d_loss : 0.095810
# batch 3 g_loss : 2.949698
# batch 4 d_loss : 0.100375
# batch 4 g_loss : 2.949828
# batch 5 d_loss : 0.083730
# batch 5 g_loss : 3.146739
# batch 6 d_loss : 0.091148
# batch 6 g_loss : 3.203721
# Epoch is 1484
# Number of batches 7
# batch 0 d_loss : 0.090900
# batch 0 g_loss : 3.182916
# batch 1 d_loss : 0.096435
# batch 1 g_loss : 3.285142
# batch 2 d_loss : 0.081476
# batch 2 g_loss : 3.048629
# batch 3 d_loss : 0.082752
# batch 3 g_loss : 3.188292
# batch 4 d_loss : 0.088876
# batch 4 g_loss : 3.331877
# batch 5 d_loss : 0.085596
# batch 5 g_loss : 2.985670
# batch 6 d_loss : 0.094369
# batch 6 g_loss : 3.091240
# Epoch is 1485
# Number of batches 7
# batch 0 d_loss : 0.086481
# batch 0 g_loss : 3.072539
# batch 1 d_loss : 0.077678
# batch 1 g_loss : 3.162302
# batch 2 d_loss : 0.066205
# batch 2 g_loss : 3.203959
# batch 3 d_loss : 0.085770
# batch 3 g_loss : 3.135881
# batch 4 d_loss : 0.068306
# batch 4 g_loss : 3.300424
# batch 5 d_loss : 0.064523
# batch 5 g_loss : 3.344745
# batch 6 d_loss : 0.063899
# batch 6 g_loss : 3.503616
# Epoch is 1486
# Number of batches 7
# batch 0 d_loss : 0.073426
# batch 0 g_loss : 3.437114
# batch 1 d_loss : 0.055618
# batch 1 g_loss : 3.460521
# batch 2 d_loss : 0.052968
# batch 2 g_loss : 3.506456
# batch 3 d_loss : 0.059042
# batch 3 g_loss : 3.301750
# batch 4 d_loss : 0.065604
# batch 4 g_loss : 3.313942
# batch 5 d_loss : 0.075348
# batch 5 g_loss : 3.281411
# batch 6 d_loss : 0.086377
# batch 6 g_loss : 3.148714
# Epoch is 1487
# Number of batches 7
# batch 0 d_loss : 0.083699
# batch 0 g_loss : 3.504172
# batch 1 d_loss : 0.065029
# batch 1 g_loss : 3.436121
# batch 2 d_loss : 0.075851
# batch 2 g_loss : 3.386530
# batch 3 d_loss : 0.070800
# batch 3 g_loss : 3.103176
# batch 4 d_loss : 0.084244
# batch 4 g_loss : 3.060020
# batch 5 d_loss : 0.072191
# batch 5 g_loss : 3.078629
# batch 6 d_loss : 0.097756
# batch 6 g_loss : 3.366851
# Epoch is 1488
# Number of batches 7
# batch 0 d_loss : 0.095045
# batch 0 g_loss : 3.305826
# batch 1 d_loss : 0.074635
# batch 1 g_loss : 3.415972
# batch 2 d_loss : 0.081887
# batch 2 g_loss : 3.040587
# batch 3 d_loss : 0.094258
# batch 3 g_loss : 3.003212
# batch 4 d_loss : 0.115702
# batch 4 g_loss : 2.956012
# batch 5 d_loss : 0.119856
# batch 5 g_loss : 2.735431
# batch 6 d_loss : 0.161631
# batch 6 g_loss : 3.014805
# Epoch is 1489
# Number of batches 7
# batch 0 d_loss : 0.142086
# batch 0 g_loss : 2.813702

# %%
generate(1)
# Out:
# 1/1 [==============================] - 0s
# (1, 1, 128, 128)
