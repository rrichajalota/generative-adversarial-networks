# %%
from __future__ import print_function

from keras import backend as K
K.set_image_dim_ordering('th') # ensure our dimension notation matches

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.convolutional import Convolution2D, AveragePooling2D
from keras.layers.core import Flatten
from keras.optimizers import SGD, Adam
from keras.datasets import mnist
from keras import utils
import numpy as np
from PIL import Image, ImageOps
import argparse
import math
from keras.layers.advanced_activations import LeakyReLU

import os
import os.path

import glob
# Out:
# Using Theano backend.

# %%
def generator_model():
    model = Sequential()
    model.add(Dense(input_dim=100, output_dim=1024))
    #model.add(LeakyReLU(alpha=.001))
    model.add(Activation('tanh'))
    model.add(Dense(128*8*8))
    #model.add(LeakyReLU(alpha=.001))
    model.add(BatchNormalization())
    model.add(Activation('tanh'))
    model.add(Reshape((128, 8, 8), input_shape=(128*8*8,)))
    model.add(UpSampling2D(size=(4, 4)))
    model.add(Convolution2D(64, 5, 5, border_mode='same'))
    #model.add(LeakyReLU(alpha=.001))
    model.add(Activation('tanh'))
    model.add(UpSampling2D(size=(4, 4)))
    model.add(Convolution2D(1, 5, 5, border_mode='same'))
    model.add(Activation('tanh'))
    return model


def discriminator_model():
    model = Sequential()
    model.add(Convolution2D(
                        64, 5, 5,
                        border_mode='same',
                        input_shape=(1, 128, 128)))
    #model.add(LeakyReLU(alpha=.001))
    model.add(Activation('tanh'))
    model.add(AveragePooling2D(pool_size=(4, 4)))
    model.add(Convolution2D(128, 5, 5))
    #model.add(LeakyReLU(alpha=.001))
    model.add(Activation('tanh'))
    model.add(AveragePooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(256))
    #model.add(LeakyReLU(alpha=.001))
    model.add(Activation('tanh'))
    model.add(Dense(1))
    model.add(Activation('sigmoid'))
    return model


def generator_containing_discriminator(generator, discriminator):
    model = Sequential()
    model.add(generator)
    discriminator.trainable = False
    model.add(discriminator)
    return model


def combine_images(generated_images):
    num = generated_images.shape[0]
    width = int(math.sqrt(num))
    height = int(math.ceil(float(num)/width))
    shape = generated_images.shape[2:]
    image = np.zeros((height*shape[0], width*shape[1]),
                     dtype=generated_images.dtype)
    for index, img in enumerate(generated_images):
        i = int(index/width)
        j = index % width
        image[i*shape[0]:(i+1)*shape[0], j*shape[1]:(j+1)*shape[1]] = \
            img[0, :, :]
    return image

# %%
model = generator_model()
print(model.summary())
model.compile(loss='categorical_crossentropy', optimizer='adam')
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# dense_1 (Dense)                  (None, 1024)          103424      dense_input_1[0][0]
# ____________________________________________________________________________________________________
# activation_1 (Activation)        (None, 1024)          0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 8192)          8396800     activation_1[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_1 (BatchNorma (None, 8192)          32768       dense_2[0][0]
# ____________________________________________________________________________________________________
# activation_2 (Activation)        (None, 8192)          0           batchnormalization_1[0][0]
# ____________________________________________________________________________________________________
# reshape_1 (Reshape)              (None, 128, 8, 8)     0           activation_2[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_1 (UpSampling2D)    (None, 128, 32, 32)   0           reshape_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 64, 32, 32)    204864      upsampling2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_3 (Activation)        (None, 64, 32, 32)    0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_2 (UpSampling2D)    (None, 64, 128, 128)  0           activation_3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_2 (Convolution2D)  (None, 1, 128, 128)   1601        upsampling2d_2[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 1, 128, 128)   0           convolution2d_2[0][0]
# ====================================================================================================
# Total params: 8,739,457
# Trainable params: 8,723,073
# Non-trainable params: 16,384
# ____________________________________________________________________________________________________
# None

# %%
model = discriminator_model()
print(model.summary())
model.compile(loss='categorical_crossentropy', optimizer='SGD')
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# convolution2d_3 (Convolution2D)  (None, 64, 128, 128)  1664        convolution2d_input_1[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 64, 128, 128)  0           convolution2d_3[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_1 (AveragePooli (None, 64, 32, 32)    0           activation_5[0][0]
# ____________________________________________________________________________________________________
# convolution2d_4 (Convolution2D)  (None, 128, 28, 28)   204928      averagepooling2d_1[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 128, 28, 28)   0           convolution2d_4[0][0]
# ____________________________________________________________________________________________________
# averagepooling2d_2 (AveragePooli (None, 128, 14, 14)   0           activation_6[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 25088)         0           averagepooling2d_2[0][0]
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 256)           6422784     flatten_1[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 256)           0           dense_3[0][0]
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 1)             257         activation_7[0][0]
# ____________________________________________________________________________________________________
# activation_8 (Activation)        (None, 1)             0           dense_4[0][0]
# ====================================================================================================
# Total params: 6,629,633
# Trainable params: 6,629,633
# Non-trainable params: 0
# ____________________________________________________________________________________________________
# None

# %%
def load_data(pixels=128, verbose=False):
    print("Loading data")
    X_train = []
    paths = glob.glob(os.path.normpath(os.getcwd() + '/celeba/train/*.jpg'))
    for path in paths:
        if verbose: print(path)
        im = Image.open(path)
        im = ImageOps.fit(im, (pixels, pixels), Image.ANTIALIAS)
        im = ImageOps.grayscale(im)
        #im.show()
        im = np.asarray(im)
        #im = im/255.0
        X_train.append(im)
    print("Finished loading data")
    return np.array(X_train)

def train(epochs, BATCH_SIZE, weights=False):
    """
    :param epochs: Train for this many epochs
    :param BATCH_SIZE: Size of minibatch
    :param weights: If True, load weights from file, otherwise train the model from scratch. 
    Use this if you have already saved state of the network and want to train it further.
    """
    X_train = load_data()
    X_train = (X_train.astype(np.float32) - 127.5)/127.5
    X_train = X_train.reshape((X_train.shape[0], 1) + X_train.shape[1:])
    discriminator = discriminator_model()
    generator = generator_model()
    if weights:
        generator.load_weights('goodgenerator.h5')
        discriminator.load_weights('gooddiscriminator.h5')
    discriminator_on_generator = generator_containing_discriminator(generator, discriminator)
    d_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    g_optim = SGD(lr=0.0005, momentum=0.9, nesterov=True)
    generator.compile(loss='binary_crossentropy', optimizer="SGD")
    discriminator_on_generator.compile(
        loss='binary_crossentropy', optimizer=g_optim)
    discriminator.trainable = True
    discriminator.compile(loss='binary_crossentropy', optimizer=d_optim)
    noise = np.zeros((BATCH_SIZE, 100))
    for epoch in range(epochs):
        print("Epoch is", epoch)
        print("Number of batches", int(X_train.shape[0]/BATCH_SIZE))
        for index in range(int(X_train.shape[0]/BATCH_SIZE)):
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            image_batch = X_train[index*BATCH_SIZE:(index+1)*BATCH_SIZE]
            generated_images = generator.predict(noise, verbose=0)
            #print(generated_images.shape)
            if index % 20 == 0 and epoch % 10 == 0:
                image = combine_images(generated_images)
                image = image*127.5+127.5
                destpath = os.path.normpath(os.getcwd()+ "/face-generated-images/"+str(epoch)+"_"+str(index)+".png")
                Image.fromarray(image.astype(np.uint8)).save(destpath)
            X = np.concatenate((image_batch, generated_images))
            y = [1] * BATCH_SIZE + [0] * BATCH_SIZE
            d_loss = discriminator.train_on_batch(X, y)
            print("batch %d d_loss : %f" % (index, d_loss))
            for i in range(BATCH_SIZE):
                noise[i, :] = np.random.uniform(-1, 1, 100)
            discriminator.trainable = False
            g_loss = discriminator_on_generator.train_on_batch(
                noise, [1] * BATCH_SIZE)
            discriminator.trainable = True
            print("batch %d g_loss : %f" % (index, g_loss))
            if epoch % 10 == 9:
                generator.save_weights('goodgenerator.h5', True)
                discriminator.save_weights('gooddiscriminator.h5', True)

def clean(image):
    for i in range(1, image.shape[0] - 1):
        for j in range(1, image.shape[1] - 1):
            if image[i][j] + image[i+1][j] + image[i][j+1] + image[i-1][j] + image[i][j-1] > 127 * 5:
                image[i][j] = 255
    return image

def generate(BATCH_SIZE):
    generator = generator_model()
    generator.compile(loss='binary_crossentropy', optimizer="SGD")
    generator.load_weights('goodgenerator.h5')
    noise = np.zeros((BATCH_SIZE, 100))
    a = np.random.uniform(-1, 1, 100)
    b = np.random.uniform(-1, 1, 100)
    grad = (b - a) / BATCH_SIZE
    for i in range(BATCH_SIZE):
        noise[i, :] = np.random.uniform(-1, 1, 100)
    generated_images = generator.predict(noise, verbose=1)
    #image = combine_images(generated_images)
    print(generated_images.shape)
    for image in generated_images:
        image = image[0]
        image = image*127.5+127.5
        Image.fromarray(image.astype(np.uint8)).save("dirty.png")
        Image.fromarray(image.astype(np.uint8)).show()
        clean(image)
        image = Image.fromarray(image.astype(np.uint8))
        image.show()        
        image.save("clean.png")


def get_args():
    parser = argparse.ArgumentParser()
    parser.add_argument("--mode", type=str)
    parser.add_argument("--batch_size", type=int, default=128)
    parser.add_argument("--nice", dest="nice", action="store_true")
    parser.set_defaults(nice=False)
    args = parser.parse_args()
    return args

# %%
train(1700, 100, False)
# Out:
# Loading data
# Finished loading data
# Epoch is 0
# Number of batches 7
# batch 0 d_loss : 0.702406
# batch 0 g_loss : 0.694393
# batch 1 d_loss : 0.704080
# batch 1 g_loss : 0.693746
# batch 2 d_loss : 0.704128
# batch 2 g_loss : 0.692278
# batch 3 d_loss : 0.700592
# batch 3 g_loss : 0.692627
# batch 4 d_loss : 0.696862
# batch 4 g_loss : 0.692925
# batch 5 d_loss : 0.688195
# batch 5 g_loss : 0.695965
# batch 6 d_loss : 0.684005
# batch 6 g_loss : 0.695435
# Epoch is 1
# Number of batches 7
# batch 0 d_loss : 0.676541
# batch 0 g_loss : 0.697682
# batch 1 d_loss : 0.675504
# batch 1 g_loss : 0.692209
# batch 2 d_loss : 0.670622
# batch 2 g_loss : 0.695229
# batch 3 d_loss : 0.658330
# batch 3 g_loss : 0.691734
# batch 4 d_loss : 0.656567
# batch 4 g_loss : 0.695701
# batch 5 d_loss : 0.653911
# batch 5 g_loss : 0.695619
# batch 6 d_loss : 0.634948
# batch 6 g_loss : 0.696317
# Epoch is 2
# Number of batches 7
# batch 0 d_loss : 0.642717
# batch 0 g_loss : 0.694230
# batch 1 d_loss : 0.639671
# batch 1 g_loss : 0.693844
# batch 2 d_loss : 0.630920
# batch 2 g_loss : 0.696316
# batch 3 d_loss : 0.616699
# batch 3 g_loss : 0.692863
# batch 4 d_loss : 0.620014
# batch 4 g_loss : 0.697990
# batch 5 d_loss : 0.621472
# batch 5 g_loss : 0.694770
# batch 6 d_loss : 0.594243
# batch 6 g_loss : 0.693194
# Epoch is 3
# Number of batches 7
# batch 0 d_loss : 0.614496
# batch 0 g_loss : 0.690319
# batch 1 d_loss : 0.611338
# batch 1 g_loss : 0.692323
# batch 2 d_loss : 0.607902
# batch 2 g_loss : 0.690458
# batch 3 d_loss : 0.585063
# batch 3 g_loss : 0.695838
# batch 4 d_loss : 0.594056
# batch 4 g_loss : 0.699567
# batch 5 d_loss : 0.601662
# batch 5 g_loss : 0.692139
# batch 6 d_loss : 0.570899
# batch 6 g_loss : 0.694368
# Epoch is 4
# Number of batches 7
# batch 0 d_loss : 0.597247
# batch 0 g_loss : 0.694701
# batch 1 d_loss : 0.594987
# batch 1 g_loss : 0.691139
# batch 2 d_loss : 0.587362
# batch 2 g_loss : 0.691012
# batch 3 d_loss : 0.569576
# batch 3 g_loss : 0.696985
# batch 4 d_loss : 0.582010
# batch 4 g_loss : 0.693987
# batch 5 d_loss : 0.588155
# batch 5 g_loss : 0.698709
# batch 6 d_loss : 0.555273
# batch 6 g_loss : 0.684021
# Epoch is 5
# Number of batches 7
# batch 0 d_loss : 0.590935
# batch 0 g_loss : 0.692638
# batch 1 d_loss : 0.584919
# batch 1 g_loss : 0.697153
# batch 2 d_loss : 0.582798
# batch 2 g_loss : 0.686504
# batch 3 d_loss : 0.556316
# batch 3 g_loss : 0.697727
# batch 4 d_loss : 0.560590
# batch 4 g_loss : 0.706481
# batch 5 d_loss : 0.583928
# batch 5 g_loss : 0.709661
# batch 6 d_loss : 0.543570
# batch 6 g_loss : 0.699058
# Epoch is 6
# Number of batches 7
# batch 0 d_loss : 0.560516
# batch 0 g_loss : 0.710363
# batch 1 d_loss : 0.561573
# batch 1 g_loss : 0.715020
# batch 2 d_loss : 0.548606
# batch 2 g_loss : 0.723798
# batch 3 d_loss : 0.530055
# batch 3 g_loss : 0.730067
# batch 4 d_loss : 0.532230
# batch 4 g_loss : 0.732484
# batch 5 d_loss : 0.553904
# batch 5 g_loss : 0.737501
# batch 6 d_loss : 0.513393
# batch 6 g_loss : 0.750231
# Epoch is 7
# Number of batches 7
# batch 0 d_loss : 0.517059
# batch 0 g_loss : 0.767018
# batch 1 d_loss : 0.521990
# batch 1 g_loss : 0.771765
# batch 2 d_loss : 0.508909
# batch 2 g_loss : 0.771332
# batch 3 d_loss : 0.491454
# batch 3 g_loss : 0.775455
# batch 4 d_loss : 0.480585
# batch 4 g_loss : 0.794467
# batch 5 d_loss : 0.511414
# batch 5 g_loss : 0.805349
# batch 6 d_loss : 0.470996
# batch 6 g_loss : 0.812895
# Epoch is 8
# Number of batches 7
# batch 0 d_loss : 0.462514
# batch 0 g_loss : 0.820653
# batch 1 d_loss : 0.471854
# batch 1 g_loss : 0.833698
# batch 2 d_loss : 0.463938
# batch 2 g_loss : 0.841020
# batch 3 d_loss : 0.454429
# batch 3 g_loss : 0.891632
# batch 4 d_loss : 0.430336
# batch 4 g_loss : 0.862890
# batch 5 d_loss : 0.469164
# batch 5 g_loss : 0.886461
# batch 6 d_loss : 0.439691
# batch 6 g_loss : 0.881645
# Epoch is 9
# Number of batches 7
# batch 0 d_loss : 0.423031
# batch 0 g_loss : 0.885952
# batch 1 d_loss : 0.448094
# batch 1 g_loss : 0.893894
# batch 2 d_loss : 0.440273
# batch 2 g_loss : 0.919655
# batch 3 d_loss : 0.431503
# batch 3 g_loss : 0.907939
# batch 4 d_loss : 0.419031
# batch 4 g_loss : 0.901426
# batch 5 d_loss : 0.463345
# batch 5 g_loss : 0.908501
# batch 6 d_loss : 0.447960
# batch 6 g_loss : 0.885848
# Epoch is 10
# Number of batches 7
# batch 0 d_loss : 0.415256
# batch 0 g_loss : 0.877376
# batch 1 d_loss : 0.459193
# batch 1 g_loss : 0.911310
# batch 2 d_loss : 0.457927
# batch 2 g_loss : 0.885887
# batch 3 d_loss : 0.460801
# batch 3 g_loss : 0.879762
# batch 4 d_loss : 0.451348
# batch 4 g_loss : 0.855336
# batch 5 d_loss : 0.497590
# batch 5 g_loss : 0.846884
# batch 6 d_loss : 0.484566
# batch 6 g_loss : 0.834659
# Epoch is 11
# Number of batches 7
# batch 0 d_loss : 0.462691
# batch 0 g_loss : 0.840237
# batch 1 d_loss : 0.504286
# batch 1 g_loss : 0.818088
# batch 2 d_loss : 0.511816
# batch 2 g_loss : 0.782718
# batch 3 d_loss : 0.500581
# batch 3 g_loss : 0.774490
# batch 4 d_loss : 0.482633
# batch 4 g_loss : 0.803259
# batch 5 d_loss : 0.550469
# batch 5 g_loss : 0.768675
# batch 6 d_loss : 0.508930
# batch 6 g_loss : 0.772920
# Epoch is 12
# Number of batches 7
# batch 0 d_loss : 0.496153
# batch 0 g_loss : 0.783486
# batch 1 d_loss : 0.523746
# batch 1 g_loss : 0.792188
# batch 2 d_loss : 0.511650
# batch 2 g_loss : 0.795453
# batch 3 d_loss : 0.470200
# batch 3 g_loss : 0.817789
# batch 4 d_loss : 0.460206
# batch 4 g_loss : 0.812446
# batch 2 g_loss : 0.823268
# batch 3 d_loss : 0.672104
# batch 3 g_loss : 0.807975
# batch 4 d_loss : 0.639246
# batch 4 g_loss : 0.794342
# batch 5 d_loss : 0.693504
# batch 5 g_loss : 0.807033
# batch 6 d_loss : 0.650996
# batch 6 g_loss : 0.825631
# Epoch is 79
# Number of batches 7
# batch 0 d_loss : 0.652938
# batch 0 g_loss : 0.813341
# batch 1 d_loss : 0.704416
# batch 1 g_loss : 0.777527
# batch 2 d_loss : 0.672084
# batch 2 g_loss : 0.843245
# batch 3 d_loss : 0.691252
# batch 3 g_loss : 0.824625
# batch 4 d_loss : 0.654605
# batch 4 g_loss : 0.815867
# batch 5 d_loss : 0.683831
# batch 5 g_loss : 0.810931
# batch 6 d_loss : 0.647676
# batch 6 g_loss : 0.838221
# Epoch is 80
# Number of batches 7
# batch 0 d_loss : 0.665297
# batch 0 g_loss : 0.790618
# batch 1 d_loss : 0.675995
# batch 1 g_loss : 0.811202
# batch 2 d_loss : 0.651934
# batch 2 g_loss : 0.808306
# batch 3 d_loss : 0.684457
# batch 3 g_loss : 0.809830
# batch 4 d_loss : 0.665387
# batch 4 g_loss : 0.836382
# batch 5 d_loss : 0.693983
# batch 5 g_loss : 0.775082
# batch 6 d_loss : 0.663780
# batch 6 g_loss : 0.794292
# Epoch is 81
# Number of batches 7
# batch 0 d_loss : 0.653153
# batch 0 g_loss : 0.782744
# batch 1 d_loss : 0.703540
# batch 1 g_loss : 0.800596
# batch 2 d_loss : 0.664722
# batch 2 g_loss : 0.798351
# batch 3 d_loss : 0.667759
# batch 3 g_loss : 0.810125
# batch 4 d_loss : 0.641535
# batch 4 g_loss : 0.824062
# batch 5 d_loss : 0.700703
# batch 5 g_loss : 0.797239
# batch 6 d_loss : 0.651304
# batch 6 g_loss : 0.831343
# Epoch is 82
# Number of batches 7
# batch 0 d_loss : 0.671835
# batch 0 g_loss : 0.809446
# batch 1 d_loss : 0.684294
# batch 1 g_loss : 0.800139
# batch 2 d_loss : 0.655849
# batch 2 g_loss : 0.788895
# batch 3 d_loss : 0.669602
# batch 3 g_loss : 0.794815
# batch 4 d_loss : 0.653605
# batch 4 g_loss : 0.829908
# batch 5 d_loss : 0.700562
# batch 5 g_loss : 0.816368
# batch 6 d_loss : 0.644164
# batch 6 g_loss : 0.807470
# Epoch is 83
# Number of batches 7
# batch 0 d_loss : 0.636959
# batch 0 g_loss : 0.810846
# batch 1 d_loss : 0.677980
# batch 1 g_loss : 0.856451
# batch 2 d_loss : 0.673704
# batch 2 g_loss : 0.849135
# batch 3 d_loss : 0.659880
# batch 3 g_loss : 0.823070
# batch 4 d_loss : 0.650785
# batch 4 g_loss : 0.787123
# batch 5 d_loss : 0.683717
# batch 5 g_loss : 0.770593
# batch 6 d_loss : 0.676068
# batch 6 g_loss : 0.872889
# Epoch is 84
# Number of batches 7
# batch 0 d_loss : 0.648637
# batch 0 g_loss : 0.776191
# batch 1 d_loss : 0.681800
# batch 1 g_loss : 0.813612
# batch 2 d_loss : 0.675618
# batch 2 g_loss : 0.799687
# batch 3 d_loss : 0.654718
# batch 3 g_loss : 0.798417
# batch 4 d_loss : 0.663955
# batch 4 g_loss : 0.838492
# batch 5 d_loss : 0.678359
# batch 5 g_loss : 0.824640
# batch 6 d_loss : 0.643601
# batch 6 g_loss : 0.806314
# Epoch is 85
# Number of batches 7
# batch 0 d_loss : 0.651645
# batch 0 g_loss : 0.803663
# batch 1 d_loss : 0.694125
# batch 1 g_loss : 0.755206
# batch 2 d_loss : 0.671880
# batch 2 g_loss : 0.772427
# batch 3 d_loss : 0.670800
# batch 3 g_loss : 0.802733
# batch 4 d_loss : 0.657211
# batch 4 g_loss : 0.812184
# batch 5 d_loss : 0.682506
# batch 5 g_loss : 0.819551
# batch 6 d_loss : 0.639204
# batch 6 g_loss : 0.845501
# Epoch is 86
# Number of batches 7
# batch 0 d_loss : 0.649304
# batch 0 g_loss : 0.801918
# batch 1 d_loss : 0.672079
# batch 1 g_loss : 0.821567
# batch 2 d_loss : 0.660179
# batch 2 g_loss : 0.800500
# batch 3 d_loss : 0.661651
# batch 3 g_loss : 0.822684
# batch 4 d_loss : 0.644877
# batch 4 g_loss : 0.792850
# batch 5 d_loss : 0.658589
# batch 5 g_loss : 0.804968
# batch 6 d_loss : 0.641042
# batch 6 g_loss : 0.812799
# Epoch is 87
# Number of batches 7
# batch 0 d_loss : 0.651932
# batch 0 g_loss : 0.776920
# batch 1 d_loss : 0.667640
# batch 1 g_loss : 0.780405
# batch 2 d_loss : 0.655792
# batch 2 g_loss : 0.818262
# batch 3 d_loss : 0.650304
# batch 3 g_loss : 0.825392
# batch 4 d_loss : 0.639283
# batch 4 g_loss : 0.779455
# batch 5 d_loss : 0.675834
# batch 5 g_loss : 0.820688
# batch 6 d_loss : 0.625595
# batch 6 g_loss : 0.812202
# Epoch is 88
# Number of batches 7
# batch 0 d_loss : 0.652256
# batch 0 g_loss : 0.810797
# batch 1 d_loss : 0.658212
# batch 1 g_loss : 0.805687
# batch 2 d_loss : 0.657138
# batch 2 g_loss : 0.824668
# batch 3 d_loss : 0.650458
# batch 3 g_loss : 0.799695
# batch 4 d_loss : 0.650789
# batch 4 g_loss : 0.776624
# batch 5 d_loss : 0.660927
# batch 5 g_loss : 0.789658
# batch 6 d_loss : 0.649924
# batch 6 g_loss : 0.797797
# Epoch is 89
# Number of batches 7
# batch 0 d_loss : 0.636112
# batch 0 g_loss : 0.791768
# batch 1 d_loss : 0.650147
# batch 1 g_loss : 0.787682
# batch 2 d_loss : 0.670887
# batch 2 g_loss : 0.828224
# batch 3 d_loss : 0.663815
# batch 3 g_loss : 0.813316
# batch 4 d_loss : 0.650950
# batch 4 g_loss : 0.820347
# batch 5 d_loss : 0.652850
# batch 5 g_loss : 0.821392
# batch 6 d_loss : 0.647844
# batch 6 g_loss : 0.807426
# Epoch is 90
# Number of batches 7
# batch 0 d_loss : 0.660691
# batch 0 g_loss : 0.838776
# batch 1 d_loss : 0.637851
# batch 1 g_loss : 0.814911
# batch 2 d_loss : 0.652697
# batch 2 g_loss : 0.787811
# batch 3 d_loss : 0.665741
# batch 3 g_loss : 0.845193
# batch 4 d_loss : 0.651332
# batch 4 g_loss : 0.770324
# batch 5 d_loss : 0.673123
# batch 5 g_loss : 0.803541
# batch 6 d_loss : 0.646069
# batch 6 g_loss : 0.769989
# Epoch is 91
# Number of batches 7
# batch 0 d_loss : 0.649778
# batch 0 g_loss : 0.785663
# batch 1 d_loss : 0.657280
# batch 1 g_loss : 0.793628
# batch 2 d_loss : 0.656633
# batch 2 g_loss : 0.816811
# batch 3 d_loss : 0.648466
# batch 3 g_loss : 0.786214
# batch 4 d_loss : 0.641977
# batch 4 g_loss : 0.819102
# batch 5 d_loss : 0.657874
# batch 5 g_loss : 0.798910
# batch 6 d_loss : 0.665331
# batch 6 g_loss : 0.818794
# Epoch is 92
# Number of batches 7
# batch 0 d_loss : 0.647083
# batch 0 g_loss : 0.830024
# batch 1 d_loss : 0.662984
# batch 1 g_loss : 0.759044
# batch 2 d_loss : 0.660672
# batch 2 g_loss : 0.806686
# batch 3 d_loss : 0.662696
# batch 3 g_loss : 0.817849
# batch 4 d_loss : 0.641750
# batch 4 g_loss : 0.835183
# batch 5 d_loss : 0.649453
# batch 5 g_loss : 0.854338
# batch 6 d_loss : 0.665753
# batch 6 g_loss : 0.808409
# Epoch is 93
# Number of batches 7
# batch 0 d_loss : 0.642430
# batch 0 g_loss : 0.840608
# batch 1 d_loss : 0.659857
# batch 1 g_loss : 0.848759
# batch 2 d_loss : 0.645550
# batch 2 g_loss : 0.810424
# batch 3 d_loss : 0.669327
# batch 3 g_loss : 0.831286
# batch 4 d_loss : 0.647351
# batch 4 g_loss : 0.815061
# batch 5 d_loss : 0.658333
# batch 5 g_loss : 0.815836
# batch 6 d_loss : 0.651587
# batch 6 g_loss : 0.810441
# Epoch is 94
# Number of batches 7
# batch 0 d_loss : 0.635234
# batch 0 g_loss : 0.814643
# batch 1 d_loss : 0.673727
# batch 1 g_loss : 0.804678
# batch 2 d_loss : 0.642671
# batch 2 g_loss : 0.811418
# batch 3 d_loss : 0.670959
# batch 3 g_loss : 0.836402
# batch 4 d_loss : 0.651241
# batch 4 g_loss : 0.804468
# batch 5 d_loss : 0.655096
# batch 5 g_loss : 0.813003
# batch 6 d_loss : 0.676045
# batch 6 g_loss : 0.784925
# Epoch is 95
# Number of batches 7
# batch 0 d_loss : 0.629385
# batch 0 g_loss : 0.821528
# batch 1 d_loss : 0.652138
# batch 1 g_loss : 0.821705
# batch 2 d_loss : 0.628350
# batch 2 g_loss : 0.806565
# batch 3 d_loss : 0.663662
# batch 3 g_loss : 0.831812
# batch 4 d_loss : 0.642353
# batch 4 g_loss : 0.779256
# batch 5 d_loss : 0.646362
# batch 5 g_loss : 0.801624
# batch 6 d_loss : 0.655955
# batch 6 g_loss : 0.799666
# Epoch is 96
# Number of batches 7
# batch 0 d_loss : 0.637903
# batch 0 g_loss : 0.819630
# batch 1 d_loss : 0.666892
# batch 1 g_loss : 0.847042
# batch 2 d_loss : 0.661461
# batch 2 g_loss : 0.830695
# batch 3 d_loss : 0.673907
# batch 3 g_loss : 0.848675
# batch 4 d_loss : 0.656062
# batch 4 g_loss : 0.770366
# batch 5 d_loss : 0.649344
# batch 5 g_loss : 0.821697
# batch 6 d_loss : 0.676962
# batch 6 g_loss : 0.808520
# Epoch is 97
# Number of batches 7
# batch 0 d_loss : 0.654647
# batch 0 g_loss : 0.768561
# batch 1 d_loss : 0.670356
# batch 1 g_loss : 0.794778
# batch 2 d_loss : 0.650705
# batch 2 g_loss : 0.831145
# batch 3 d_loss : 0.654750
# batch 3 g_loss : 0.778923
# batch 4 d_loss : 0.659301
# batch 4 g_loss : 0.803070
# batch 5 d_loss : 0.677031
# batch 5 g_loss : 0.790392
# batch 6 d_loss : 0.655531
# batch 6 g_loss : 0.785663
# Epoch is 98
# Number of batches 7
# batch 0 d_loss : 0.642107
# batch 0 g_loss : 0.833441
# batch 1 d_loss : 0.661091
# batch 1 g_loss : 0.777924
# batch 2 d_loss : 0.658253
# batch 2 g_loss : 0.796196
# batch 3 d_loss : 0.670120
# batch 3 g_loss : 0.760692
# batch 4 d_loss : 0.653402
# batch 4 g_loss : 0.780330
# batch 5 d_loss : 0.656642
# batch 5 g_loss : 0.768304
# batch 6 d_loss : 0.640388
# batch 6 g_loss : 0.786699
# Epoch is 99
# Number of batches 7
# batch 0 d_loss : 0.644336
# batch 0 g_loss : 0.790332
# batch 1 d_loss : 0.645631
# batch 1 g_loss : 0.777708
# batch 2 d_loss : 0.657782
# batch 2 g_loss : 0.770896
# batch 3 d_loss : 0.665565
# batch 3 g_loss : 0.782527
# batch 4 d_loss : 0.670715
# batch 4 g_loss : 0.772151
# batch 5 d_loss : 0.674428
# batch 5 g_loss : 0.795350
# batch 6 d_loss : 0.688574
# batch 6 g_loss : 0.735978
# Epoch is 100
# Number of batches 7
# batch 0 d_loss : 0.623878
# batch 0 g_loss : 0.748932
# batch 1 d_loss : 0.669677
# batch 1 g_loss : 0.755994
# batch 2 d_loss : 0.662409
# batch 2 g_loss : 0.727503
# batch 3 d_loss : 0.682432
# batch 3 g_loss : 0.795744
# batch 4 d_loss : 0.697094
# batch 4 g_loss : 0.713988
# batch 5 d_loss : 0.671189
# batch 5 g_loss : 0.747129
# batch 6 d_loss : 0.672077
# batch 6 g_loss : 0.717440
# Epoch is 101
# Number of batches 7
# batch 0 d_loss : 0.657004
# batch 0 g_loss : 0.765664
# batch 1 d_loss : 0.692975
# batch 1 g_loss : 0.782148
# batch 2 d_loss : 0.651649
# batch 2 g_loss : 0.813485
# batch 3 d_loss : 0.697899
# batch 3 g_loss : 0.784299
# batch 4 d_loss : 0.683371
# batch 4 g_loss : 0.777494
# batch 5 d_loss : 0.653166
# batch 5 g_loss : 0.748171
# batch 6 d_loss : 0.676312
# batch 6 g_loss : 0.752158
# Epoch is 102
# Number of batches 7
# batch 0 d_loss : 0.637045
# batch 0 g_loss : 0.743305
# batch 1 d_loss : 0.671611
# batch 1 g_loss : 0.723562
# batch 2 d_loss : 0.685872
# batch 2 g_loss : 0.755397
# batch 3 d_loss : 0.702718
# batch 3 g_loss : 0.723434
# batch 4 d_loss : 0.670101
# batch 4 g_loss : 0.784870
# batch 5 d_loss : 0.683703
# batch 5 g_loss : 0.713416
# batch 6 d_loss : 0.708764
# batch 6 g_loss : 0.776860
# Epoch is 103
# Number of batches 7
# batch 0 d_loss : 0.662113
# batch 0 g_loss : 0.758276
# batch 1 d_loss : 0.659484
# batch 1 g_loss : 0.745312
# batch 2 d_loss : 0.673711
# batch 2 g_loss : 0.754632
# batch 3 d_loss : 0.687455
# batch 3 g_loss : 0.736794
# batch 4 d_loss : 0.669276
# batch 4 g_loss : 0.748686
# batch 5 d_loss : 0.684083
# batch 5 g_loss : 0.793813
# batch 6 d_loss : 0.686664
# batch 6 g_loss : 0.769381
# Epoch is 104
# Number of batches 7
# batch 0 d_loss : 0.662334
# batch 0 g_loss : 0.733552
# batch 1 d_loss : 0.682994
# batch 1 g_loss : 0.740952
# batch 2 d_loss : 0.681252
# batch 2 g_loss : 0.768772
# batch 3 d_loss : 0.683026
# batch 3 g_loss : 0.766327
# batch 4 d_loss : 0.666318
# batch 4 g_loss : 0.730833
# batch 5 d_loss : 0.703072
# batch 5 g_loss : 0.741466
# batch 6 d_loss : 0.669960
# batch 6 g_loss : 0.720038
# Epoch is 105
# Number of batches 7
# batch 3 d_loss : 0.623453
# batch 3 g_loss : 0.771441
# batch 4 d_loss : 0.633680
# batch 4 g_loss : 0.756270
# batch 5 d_loss : 0.652077
# batch 5 g_loss : 0.773620
# batch 6 d_loss : 0.632324
# batch 6 g_loss : 0.786822
# Epoch is 117
# Number of batches 7
# batch 0 d_loss : 0.659178
# batch 0 g_loss : 0.786308
# batch 1 d_loss : 0.636590
# batch 1 g_loss : 0.800806
# batch 2 d_loss : 0.641276
# batch 2 g_loss : 0.773681
# batch 3 d_loss : 0.630911
# batch 3 g_loss : 0.781200
# batch 4 d_loss : 0.638390
# batch 4 g_loss : 0.809914
# batch 5 d_loss : 0.663985
# batch 5 g_loss : 0.781120
# batch 6 d_loss : 0.618587
# batch 6 g_loss : 0.795461
# Epoch is 118
# Number of batches 7
# batch 0 d_loss : 0.639550
# batch 0 g_loss : 0.784846
# batch 1 d_loss : 0.648936
# batch 1 g_loss : 0.780141
# batch 2 d_loss : 0.645982
# batch 2 g_loss : 0.831700
# batch 3 d_loss : 0.653271
# batch 3 g_loss : 0.836341
# batch 4 d_loss : 0.633221
# batch 4 g_loss : 0.776581
# batch 5 d_loss : 0.651871
# batch 5 g_loss : 0.818831
# batch 6 d_loss : 0.626938
# batch 6 g_loss : 0.758696
# Epoch is 119
# Number of batches 7
# batch 0 d_loss : 0.633576
# batch 0 g_loss : 0.777470
# batch 1 d_loss : 0.641470
# batch 1 g_loss : 0.821941
# batch 2 d_loss : 0.634838
# batch 2 g_loss : 0.792264
# batch 3 d_loss : 0.640180
# batch 3 g_loss : 0.788709
# batch 4 d_loss : 0.617751
# batch 4 g_loss : 0.781086
# batch 5 d_loss : 0.649855
# batch 5 g_loss : 0.836945
# batch 6 d_loss : 0.615904
# batch 6 g_loss : 0.779160
# Epoch is 120
# Number of batches 7
# batch 0 d_loss : 0.631324
# batch 0 g_loss : 0.766957
# batch 1 d_loss : 0.620454
# batch 1 g_loss : 0.786458
# batch 2 d_loss : 0.642274
# batch 2 g_loss : 0.791318
# batch 3 d_loss : 0.638088
# batch 3 g_loss : 0.755330
# batch 4 d_loss : 0.628693
# batch 4 g_loss : 0.818251
# batch 5 d_loss : 0.639816
# batch 5 g_loss : 0.741741
# batch 6 d_loss : 0.637760
# batch 6 g_loss : 0.738468
# Epoch is 121
# Number of batches 7
# batch 0 d_loss : 0.627994
# batch 0 g_loss : 0.768375
# batch 1 d_loss : 0.649867
# batch 1 g_loss : 0.758510
# batch 2 d_loss : 0.643492
# batch 2 g_loss : 0.787783
# batch 3 d_loss : 0.642838
# batch 3 g_loss : 0.733307
# batch 4 d_loss : 0.623011
# batch 4 g_loss : 0.800543
# batch 5 d_loss : 0.627459
# batch 5 g_loss : 0.754497
# batch 6 d_loss : 0.643996
# batch 6 g_loss : 0.776989
# Epoch is 122
# Number of batches 7
# batch 0 d_loss : 0.656807
# batch 0 g_loss : 0.721819
# batch 1 d_loss : 0.625977
# batch 1 g_loss : 0.787780
# batch 2 d_loss : 0.644926
# batch 2 g_loss : 0.758927
# batch 3 d_loss : 0.625220
# batch 3 g_loss : 0.764883
# batch 4 d_loss : 0.642377
# batch 4 g_loss : 0.756978
# batch 5 d_loss : 0.651502
# batch 5 g_loss : 0.767817
# batch 6 d_loss : 0.643916
# batch 6 g_loss : 0.759636
# Epoch is 123
# Number of batches 7
# batch 0 d_loss : 0.623450
# batch 0 g_loss : 0.725690
# batch 1 d_loss : 0.659386
# batch 1 g_loss : 0.767013
# batch 2 d_loss : 0.652392
# batch 2 g_loss : 0.754277
# batch 3 d_loss : 0.652083
# batch 3 g_loss : 0.755502
# batch 4 d_loss : 0.657369
# batch 4 g_loss : 0.736582
# batch 5 d_loss : 0.650111
# batch 5 g_loss : 0.752599
# batch 6 d_loss : 0.636958
# batch 6 g_loss : 0.745842
# Epoch is 124
# Number of batches 7
# batch 0 d_loss : 0.641315
# batch 0 g_loss : 0.753011
# batch 1 d_loss : 0.639961
# batch 1 g_loss : 0.731273
# batch 2 d_loss : 0.651268
# batch 2 g_loss : 0.760519
# batch 3 d_loss : 0.640559
# batch 3 g_loss : 0.793724
# batch 4 d_loss : 0.655029
# batch 4 g_loss : 0.748214
# batch 5 d_loss : 0.650963
# batch 5 g_loss : 0.744407
# batch 6 d_loss : 0.636560
# batch 6 g_loss : 0.795961
# Epoch is 125
# Number of batches 7
# batch 0 d_loss : 0.623730
# batch 0 g_loss : 0.716261
# batch 1 d_loss : 0.654282
# batch 1 g_loss : 0.744253
# batch 2 d_loss : 0.671805
# batch 2 g_loss : 0.748931
# batch 3 d_loss : 0.653369
# batch 3 g_loss : 0.737830
# batch 4 d_loss : 0.622494
# batch 4 g_loss : 0.765632
# batch 5 d_loss : 0.657808
# batch 5 g_loss : 0.741703
# batch 6 d_loss : 0.669963
# batch 6 g_loss : 0.748574
# Epoch is 126
# Number of batches 7
# batch 0 d_loss : 0.643417
# batch 0 g_loss : 0.755712
# batch 1 d_loss : 0.664446
# batch 1 g_loss : 0.777254
# batch 2 d_loss : 0.662365
# batch 2 g_loss : 0.760925
# batch 3 d_loss : 0.658604
# batch 3 g_loss : 0.761554
# batch 4 d_loss : 0.630862
# batch 4 g_loss : 0.734789
# batch 5 d_loss : 0.634868
# batch 5 g_loss : 0.752256
# batch 6 d_loss : 0.632710
# batch 6 g_loss : 0.781586
# Epoch is 127
# Number of batches 7
# batch 0 d_loss : 0.646738
# batch 0 g_loss : 0.734498
# batch 1 d_loss : 0.658397
# batch 1 g_loss : 0.775200
# batch 2 d_loss : 0.635657
# batch 2 g_loss : 0.762444
# batch 3 d_loss : 0.646867
# batch 3 g_loss : 0.777875
# batch 4 d_loss : 0.639872
# batch 4 g_loss : 0.764240
# batch 5 d_loss : 0.629017
# batch 5 g_loss : 0.763534
# batch 6 d_loss : 0.607274
# batch 6 g_loss : 0.714098
# Epoch is 128
# Number of batches 7
# batch 0 d_loss : 0.639008
# batch 0 g_loss : 0.759677
# batch 1 d_loss : 0.639836
# batch 1 g_loss : 0.805092
# batch 2 d_loss : 0.616987
# batch 2 g_loss : 0.767724
# batch 3 d_loss : 0.632108
# batch 3 g_loss : 0.792526
# batch 4 d_loss : 0.631530
# batch 4 g_loss : 0.788208
# batch 5 d_loss : 0.629700
# batch 5 g_loss : 0.748231
# batch 6 d_loss : 0.635844
# batch 6 g_loss : 0.834139
# Epoch is 129
# Number of batches 7
# batch 0 d_loss : 0.633545
# batch 0 g_loss : 0.771891
# batch 1 d_loss : 0.618617
# batch 1 g_loss : 0.805313
# batch 2 d_loss : 0.625977
# batch 2 g_loss : 0.806943
# batch 3 d_loss : 0.625027
# batch 3 g_loss : 0.789807
# batch 4 d_loss : 0.620578
# batch 4 g_loss : 0.824658
# batch 5 d_loss : 0.643059
# batch 5 g_loss : 0.774877
# batch 6 d_loss : 0.619342
# batch 6 g_loss : 0.776588
# Epoch is 130
# Number of batches 7
# batch 0 d_loss : 0.614071
# batch 0 g_loss : 0.775001
# batch 1 d_loss : 0.624584
# batch 1 g_loss : 0.808873
# batch 2 d_loss : 0.629308
# batch 2 g_loss : 0.791702
# batch 3 d_loss : 0.631860
# batch 3 g_loss : 0.821723
# batch 4 d_loss : 0.632028
# batch 4 g_loss : 0.819590
# batch 5 d_loss : 0.608005
# batch 5 g_loss : 0.817495
# batch 6 d_loss : 0.603847
# batch 6 g_loss : 0.795658
# Epoch is 131
# Number of batches 7
# batch 0 d_loss : 0.624578
# batch 0 g_loss : 0.799251
# batch 1 d_loss : 0.628625
# batch 1 g_loss : 0.787976
# batch 2 d_loss : 0.633752
# batch 2 g_loss : 0.805059
# batch 3 d_loss : 0.618965
# batch 3 g_loss : 0.815853
# batch 4 d_loss : 0.633344
# batch 4 g_loss : 0.808036
# batch 5 d_loss : 0.589905
# batch 5 g_loss : 0.788772
# batch 6 d_loss : 0.604630
# batch 6 g_loss : 0.841123
# Epoch is 132
# Number of batches 7
# batch 0 d_loss : 0.627142
# batch 0 g_loss : 0.812528
# batch 1 d_loss : 0.606928
# batch 1 g_loss : 0.788666
# batch 2 d_loss : 0.603474
# batch 2 g_loss : 0.826495
# batch 3 d_loss : 0.604311
# batch 3 g_loss : 0.819862
# batch 4 d_loss : 0.603396
# batch 4 g_loss : 0.858637
# batch 5 d_loss : 0.600690
# batch 5 g_loss : 0.830333
# batch 6 d_loss : 0.599147
# batch 6 g_loss : 0.783409
# Epoch is 133
# Number of batches 7
# batch 0 d_loss : 0.585225
# batch 0 g_loss : 0.821894
# batch 1 d_loss : 0.624339
# batch 1 g_loss : 0.798939
# batch 2 d_loss : 0.624497
# batch 2 g_loss : 0.804904
# batch 3 d_loss : 0.599498
# batch 3 g_loss : 0.819540
# batch 4 d_loss : 0.593550
# batch 4 g_loss : 0.848297
# batch 5 d_loss : 0.585351
# batch 5 g_loss : 0.795639
# batch 6 d_loss : 0.586785
# batch 6 g_loss : 0.843497
# Epoch is 134
# Number of batches 7
# batch 0 d_loss : 0.587815
# batch 0 g_loss : 0.830784
# batch 1 d_loss : 0.589326
# batch 1 g_loss : 0.816461
# batch 2 d_loss : 0.614065
# batch 2 g_loss : 0.849533
# batch 3 d_loss : 0.611289
# batch 3 g_loss : 0.789947
# batch 4 d_loss : 0.584461
# batch 4 g_loss : 0.809690
# batch 5 d_loss : 0.585079
# batch 5 g_loss : 0.792106
# batch 6 d_loss : 0.586706
# batch 6 g_loss : 0.836662
# Epoch is 135
# Number of batches 7
# batch 0 d_loss : 0.574770
# batch 0 g_loss : 0.835461
# batch 1 d_loss : 0.589148
# batch 1 g_loss : 0.810865
# batch 2 d_loss : 0.624296
# batch 2 g_loss : 0.844356
# batch 3 d_loss : 0.590789
# batch 3 g_loss : 0.813255
# batch 4 d_loss : 0.589425
# batch 4 g_loss : 0.782379
# batch 5 d_loss : 0.596647
# batch 5 g_loss : 0.792245
# batch 6 d_loss : 0.597277
# batch 6 g_loss : 0.824440
# Epoch is 136
# Number of batches 7
# batch 0 d_loss : 0.601927
# batch 0 g_loss : 0.797814
# batch 1 d_loss : 0.607723
# batch 1 g_loss : 0.831602
# batch 2 d_loss : 0.626401
# batch 2 g_loss : 0.819646
# batch 3 d_loss : 0.613670
# batch 3 g_loss : 0.785266
# batch 4 d_loss : 0.586706
# batch 4 g_loss : 0.784193
# batch 5 d_loss : 0.592837
# batch 5 g_loss : 0.815886
# batch 6 d_loss : 0.585321
# batch 6 g_loss : 0.792338
# Epoch is 137
# Number of batches 7
# batch 0 d_loss : 0.602470
# batch 0 g_loss : 0.810535
# batch 1 d_loss : 0.609257
# batch 1 g_loss : 0.814822
# batch 2 d_loss : 0.604157
# batch 2 g_loss : 0.798454
# batch 3 d_loss : 0.599911
# batch 3 g_loss : 0.775257
# batch 4 d_loss : 0.591627
# batch 4 g_loss : 0.788841
# batch 5 d_loss : 0.601230
# batch 5 g_loss : 0.799088
# batch 6 d_loss : 0.581934
# batch 6 g_loss : 0.865159
# Epoch is 138
# Number of batches 7
# batch 0 d_loss : 0.582388
# batch 0 g_loss : 0.788258
# batch 1 d_loss : 0.614444
# batch 1 g_loss : 0.790728
# batch 2 d_loss : 0.609893
# batch 2 g_loss : 0.816097
# batch 3 d_loss : 0.615689
# batch 3 g_loss : 0.813261
# batch 4 d_loss : 0.580043
# batch 4 g_loss : 0.830548
# batch 5 d_loss : 0.591285
# batch 5 g_loss : 0.797167
# batch 6 d_loss : 0.600438
# batch 6 g_loss : 0.792772
# Epoch is 139
# Number of batches 7
# batch 0 d_loss : 0.586627
# batch 0 g_loss : 0.746157
# batch 1 d_loss : 0.609176
# batch 1 g_loss : 0.804300
# batch 2 d_loss : 0.611022
# batch 2 g_loss : 0.803455
# batch 3 d_loss : 0.581097
# batch 3 g_loss : 0.805614
# batch 4 d_loss : 0.565056
# batch 4 g_loss : 0.820192
# batch 5 d_loss : 0.579135
# batch 5 g_loss : 0.821670
# batch 6 d_loss : 0.599976
# batch 6 g_loss : 0.807491
# Epoch is 140
# Number of batches 7
# batch 0 d_loss : 0.588000
# batch 0 g_loss : 0.819209
# batch 1 d_loss : 0.604263
# batch 1 g_loss : 0.781609
# batch 2 d_loss : 0.591484
# batch 2 g_loss : 0.823915
# batch 3 d_loss : 0.571777
# batch 3 g_loss : 0.798679
# batch 4 d_loss : 0.579013
# batch 4 g_loss : 0.777442
# batch 5 d_loss : 0.591849
# batch 5 g_loss : 0.821160
# batch 6 d_loss : 0.580507
# batch 6 g_loss : 0.797694
# Epoch is 141
# Number of batches 7
# batch 0 d_loss : 0.582486
# batch 0 g_loss : 0.789812
# batch 1 d_loss : 0.606629
# batch 1 g_loss : 0.788027
# batch 2 d_loss : 0.593766
# batch 2 g_loss : 0.809953
# batch 3 d_loss : 0.605810
# batch 3 g_loss : 0.812595
# batch 4 d_loss : 0.564406
# batch 4 g_loss : 0.794438
# batch 5 d_loss : 0.591385
# batch 5 g_loss : 0.812221
# batch 6 d_loss : 0.576128
# batch 6 g_loss : 0.826371
# Epoch is 142
# Number of batches 7
# batch 0 d_loss : 0.565483
# batch 0 g_loss : 0.827193
# batch 1 d_loss : 0.604800
# batch 1 g_loss : 0.821615
# batch 2 d_loss : 0.580476
# batch 2 g_loss : 0.792351
# batch 3 d_loss : 0.584680
# batch 3 g_loss : 0.801547
# batch 4 d_loss : 0.560712
# batch 4 g_loss : 0.803422
# batch 5 d_loss : 0.576786
# batch 5 g_loss : 0.837854
# batch 6 d_loss : 0.559407
# batch 6 g_loss : 0.878645
# Epoch is 143
# Number of batches 7
# batch 0 d_loss : 0.557743
# batch 0 g_loss : 0.815583
# batch 1 d_loss : 0.597465
# batch 1 g_loss : 0.821661
# batch 2 d_loss : 0.580381
# batch 2 g_loss : 0.804551
# batch 3 d_loss : 0.592477
# batch 3 g_loss : 0.876970
# batch 4 d_loss : 0.547789
# batch 4 g_loss : 0.888636
# batch 5 d_loss : 0.580737
# batch 5 g_loss : 0.892603
# batch 6 d_loss : 0.559823
# batch 6 g_loss : 0.902733
# Epoch is 144
# Number of batches 7
# batch 0 d_loss : 0.542001
# batch 0 g_loss : 0.880740
# batch 1 d_loss : 0.565274
# batch 1 g_loss : 0.840142
# batch 2 d_loss : 0.578907
# batch 2 g_loss : 0.896719
# batch 3 d_loss : 0.563833
# batch 3 g_loss : 0.876400
# batch 4 d_loss : 0.563738
# batch 4 g_loss : 0.851885
# batch 5 d_loss : 0.590047
# batch 5 g_loss : 0.869993
# batch 6 d_loss : 0.557693
# batch 6 g_loss : 0.870594
# Epoch is 145
# Number of batches 7
# batch 0 d_loss : 0.560573
# batch 0 g_loss : 0.863913
# batch 1 d_loss : 0.582954
# batch 1 g_loss : 0.895691
# batch 2 d_loss : 0.563088
# batch 2 g_loss : 0.880486
# batch 3 d_loss : 0.549840
# batch 3 g_loss : 0.899985
# batch 4 d_loss : 0.524194
# batch 4 g_loss : 0.866141
# batch 5 d_loss : 0.580248
# batch 5 g_loss : 0.867988
# batch 6 d_loss : 0.554902
# batch 6 g_loss : 0.871678
# Epoch is 146
# Number of batches 7
# batch 0 d_loss : 0.516757
# batch 0 g_loss : 0.893652
# batch 1 d_loss : 0.572170
# batch 1 g_loss : 0.870534
# batch 2 d_loss : 0.538467
# batch 2 g_loss : 0.908151
# batch 3 d_loss : 0.538882
# batch 3 g_loss : 0.877529
# batch 4 d_loss : 0.517005
# batch 4 g_loss : 0.902279
# batch 5 d_loss : 0.540468
# batch 5 g_loss : 0.937873
# batch 6 d_loss : 0.522981
# batch 6 g_loss : 0.873638
# Epoch is 147
# Number of batches 7
# batch 0 d_loss : 0.513216
# batch 0 g_loss : 0.931232
# batch 1 d_loss : 0.551110
# batch 1 g_loss : 0.889683
# batch 2 d_loss : 0.532421
# batch 2 g_loss : 0.917504
# batch 3 d_loss : 0.514693
# batch 3 g_loss : 0.853445
# batch 4 d_loss : 0.480368
# batch 4 g_loss : 0.929488
# batch 5 d_loss : 0.549273
# batch 5 g_loss : 0.882531
# batch 6 d_loss : 0.524362
# batch 6 g_loss : 0.879452
# Epoch is 148
# Number of batches 7
# batch 0 d_loss : 0.500810
# batch 0 g_loss : 0.867516
# batch 1 d_loss : 0.517282
# batch 1 g_loss : 0.913739
# batch 2 d_loss : 0.518592
# batch 2 g_loss : 0.882148
# batch 3 d_loss : 0.504424
# batch 3 g_loss : 0.935662
# batch 4 d_loss : 0.503960
# batch 4 g_loss : 0.899130
# batch 5 d_loss : 0.543763
# batch 5 g_loss : 0.900012
# batch 6 d_loss : 0.511836
# batch 6 g_loss : 0.949424
# Epoch is 149
# Number of batches 7
# batch 0 d_loss : 0.499027
# batch 0 g_loss : 0.951248
# batch 1 d_loss : 0.535099
# batch 1 g_loss : 0.937512
# batch 2 d_loss : 0.504340
# batch 2 g_loss : 0.935670
# batch 3 d_loss : 0.483160
# batch 3 g_loss : 0.948383
# batch 4 d_loss : 0.491523
# batch 4 g_loss : 0.950085
# batch 5 d_loss : 0.527519
# batch 5 g_loss : 0.961237
# batch 6 d_loss : 0.475903
# batch 6 g_loss : 0.959900
# Epoch is 150
# Number of batches 7
# batch 0 d_loss : 0.471944
# batch 0 g_loss : 0.985314
# batch 1 d_loss : 0.518615
# batch 1 g_loss : 0.991467
# batch 2 d_loss : 0.502018
# batch 2 g_loss : 0.917764
# batch 3 d_loss : 0.499993
# batch 3 g_loss : 0.984729
# batch 4 d_loss : 0.481276
# batch 4 g_loss : 0.981839
# batch 5 d_loss : 0.515861
# batch 5 g_loss : 0.976789
# batch 6 d_loss : 0.486541
# batch 6 g_loss : 0.986858
# Epoch is 151
# Number of batches 7
# batch 0 d_loss : 0.479567
# batch 0 g_loss : 0.991342
# batch 1 d_loss : 0.501269
# batch 1 g_loss : 0.963691
# batch 2 d_loss : 0.475453
# batch 2 g_loss : 0.943660
# batch 3 d_loss : 0.474586
# batch 3 g_loss : 0.988828
# batch 4 d_loss : 0.468757
# batch 4 g_loss : 1.036353
# batch 5 d_loss : 0.490307
# batch 5 g_loss : 0.969554
# batch 6 d_loss : 0.461087
# batch 6 g_loss : 1.007324
# Epoch is 152
# Number of batches 7
# batch 0 d_loss : 0.490274
# batch 0 g_loss : 0.989844
# batch 1 d_loss : 0.498700
# batch 1 g_loss : 0.954752
# batch 2 d_loss : 0.478418
# batch 2 g_loss : 0.961609
# batch 3 d_loss : 0.456317
# batch 3 g_loss : 0.966534
# batch 4 d_loss : 0.445706
# batch 4 g_loss : 1.034244
# batch 5 d_loss : 0.493607
# batch 5 g_loss : 0.977155
# batch 6 d_loss : 0.450113
# batch 6 g_loss : 1.042648
# Epoch is 153
# Number of batches 7
# batch 0 d_loss : 0.450478
# batch 0 g_loss : 1.020201
# batch 1 d_loss : 0.469178
# batch 1 g_loss : 0.996546
# batch 2 d_loss : 0.448225
# batch 2 g_loss : 1.026034
# batch 3 d_loss : 0.438318
# batch 3 g_loss : 1.027157
# batch 4 d_loss : 0.420589
# batch 4 g_loss : 1.000864
# batch 5 d_loss : 0.463131
# batch 5 g_loss : 1.037245
# batch 6 d_loss : 0.449488
# batch 6 g_loss : 1.004016
# Epoch is 154
# Number of batches 7
# batch 0 d_loss : 0.431133
# batch 0 g_loss : 1.017479
# batch 1 d_loss : 0.461427
# batch 1 g_loss : 1.019960
# batch 2 d_loss : 0.435788
# batch 2 g_loss : 1.021302
# batch 3 d_loss : 0.425108
# batch 3 g_loss : 1.067098
# batch 4 d_loss : 0.417629
# batch 4 g_loss : 1.074945
# batch 5 d_loss : 0.435313
# batch 5 g_loss : 1.080431
# batch 6 d_loss : 0.448763
# batch 6 g_loss : 1.064731
# Epoch is 155
# Number of batches 7
# batch 0 d_loss : 0.410871
# batch 0 g_loss : 1.098418
# batch 1 d_loss : 0.426143
# batch 1 g_loss : 1.041095
# batch 2 d_loss : 0.427177
# batch 2 g_loss : 1.056381
# batch 3 d_loss : 0.429537
# batch 3 g_loss : 1.092577
# batch 4 d_loss : 0.416398
# batch 4 g_loss : 1.082773
# batch 5 d_loss : 0.426064
# batch 5 g_loss : 1.069148
# batch 6 d_loss : 0.416483
# batch 6 g_loss : 1.114990
# Epoch is 156
# Number of batches 7
# batch 0 d_loss : 0.404022
# batch 0 g_loss : 1.016563
# batch 1 d_loss : 0.437755
# batch 1 g_loss : 1.104104
# batch 2 d_loss : 0.395824
# batch 2 g_loss : 1.033509
# batch 3 d_loss : 0.393827
# batch 3 g_loss : 1.065892
# batch 4 d_loss : 0.396298
# batch 4 g_loss : 1.062358
# batch 5 d_loss : 0.404741
# batch 5 g_loss : 1.109393
# batch 6 d_loss : 0.414347
# batch 6 g_loss : 1.096354
# Epoch is 157
# Number of batches 7
# batch 0 d_loss : 0.395715
# batch 0 g_loss : 1.104049
# batch 1 d_loss : 0.407081
# batch 1 g_loss : 1.127039
# batch 2 d_loss : 0.402265
# batch 2 g_loss : 1.099724
# batch 3 d_loss : 0.391718
# batch 3 g_loss : 1.122703
# batch 4 d_loss : 0.393164
# batch 4 g_loss : 1.122220
# batch 5 d_loss : 0.391336
# batch 5 g_loss : 1.149060
# batch 6 d_loss : 0.398581
# batch 6 g_loss : 1.147568
# Epoch is 158
# Number of batches 7
# batch 0 d_loss : 0.374485
# batch 0 g_loss : 1.123874
# batch 1 d_loss : 0.395799
# batch 1 g_loss : 1.177798
# batch 2 d_loss : 0.389670
# batch 2 g_loss : 1.102553
# batch 3 d_loss : 0.376182
# batch 3 g_loss : 1.189524
# batch 4 d_loss : 0.369432
# batch 4 g_loss : 1.182811
# batch 5 d_loss : 0.386170
# batch 5 g_loss : 1.157243
# batch 6 d_loss : 0.380750
# batch 6 g_loss : 1.138156
# Epoch is 159
# Number of batches 7
# batch 0 d_loss : 0.369852
# batch 0 g_loss : 1.112158
# batch 1 d_loss : 0.373219
# batch 1 g_loss : 1.221925
# batch 2 d_loss : 0.365578
# batch 2 g_loss : 1.225816
# batch 3 d_loss : 0.363424
# batch 3 g_loss : 1.170304
# batch 4 d_loss : 0.365749
# batch 4 g_loss : 1.197676
# batch 5 d_loss : 0.379834
# batch 5 g_loss : 1.169945
# batch 6 d_loss : 0.365445
# batch 6 g_loss : 1.255039
# Epoch is 160
# Number of batches 7
# batch 0 d_loss : 0.368565
# batch 0 g_loss : 1.224992
# batch 1 d_loss : 0.364272
# batch 1 g_loss : 1.195495
# batch 2 d_loss : 0.362626
# batch 2 g_loss : 1.234472
# batch 3 d_loss : 0.352980
# batch 3 g_loss : 1.203694
# batch 4 d_loss : 0.332806
# batch 4 g_loss : 1.181443
# batch 5 d_loss : 0.377887
# batch 5 g_loss : 1.168872
# batch 6 d_loss : 0.349873
# batch 6 g_loss : 1.179160
# Epoch is 161
# Number of batches 7
# batch 0 d_loss : 0.356652
# batch 0 g_loss : 1.197081
# batch 1 d_loss : 0.355339
# batch 1 g_loss : 1.250061
# batch 2 d_loss : 0.351448
# batch 2 g_loss : 1.231123
# batch 3 d_loss : 0.322237
# batch 3 g_loss : 1.287674
# batch 4 d_loss : 0.332779
# batch 4 g_loss : 1.211002
# batch 5 d_loss : 0.353799
# batch 5 g_loss : 1.279624
# batch 6 d_loss : 0.347940
# batch 6 g_loss : 1.283303
# Epoch is 162
# Number of batches 7
# batch 0 d_loss : 0.331059
# batch 0 g_loss : 1.260440
# batch 1 d_loss : 0.355321
# batch 1 g_loss : 1.283124
# batch 2 d_loss : 0.337860
# batch 2 g_loss : 1.324450
# batch 3 d_loss : 0.325617
# batch 3 g_loss : 1.262434
# batch 4 d_loss : 0.334583
# batch 4 g_loss : 1.301252
# batch 5 d_loss : 0.346130
# batch 5 g_loss : 1.249612
# batch 6 d_loss : 0.362548
# batch 6 g_loss : 1.297683
# Epoch is 163
# Number of batches 7
# batch 0 d_loss : 0.340691
# batch 0 g_loss : 1.298013
# batch 1 d_loss : 0.354737
# batch 1 g_loss : 1.244424
# batch 2 d_loss : 0.354522
# batch 2 g_loss : 1.194686
# batch 3 d_loss : 0.327815
# batch 3 g_loss : 1.236872
# batch 4 d_loss : 0.341322
# batch 4 g_loss : 1.257168
# batch 5 d_loss : 0.348701
# batch 5 g_loss : 1.214005
# batch 6 d_loss : 0.354993
# batch 6 g_loss : 1.257141
# Epoch is 164
# Number of batches 7
# batch 0 d_loss : 0.341829
# batch 0 g_loss : 1.254898
# batch 1 d_loss : 0.374718
# batch 1 g_loss : 1.232576
# batch 2 d_loss : 0.346151
# batch 2 g_loss : 1.279140
# batch 3 d_loss : 0.334832
# batch 3 g_loss : 1.257833
# batch 4 d_loss : 0.345312
# batch 4 g_loss : 1.308527
# batch 5 d_loss : 0.359288
# batch 5 g_loss : 1.252275
# batch 6 d_loss : 0.363013
# batch 6 g_loss : 1.199515
# Epoch is 165
# Number of batches 7
# batch 0 d_loss : 0.370107
# batch 0 g_loss : 1.183138
# batch 1 d_loss : 0.378908
# batch 1 g_loss : 1.196044
# batch 2 d_loss : 0.366158
# batch 2 g_loss : 1.124741
# batch 3 d_loss : 0.359120
# batch 3 g_loss : 1.158747
# batch 4 d_loss : 0.374092
# batch 4 g_loss : 1.170303
# batch 5 d_loss : 0.389553
# batch 5 g_loss : 1.212379
# batch 6 d_loss : 0.423789
# batch 6 g_loss : 1.231619
# Epoch is 166
# Number of batches 7
# batch 0 d_loss : 0.389415
# batch 0 g_loss : 1.137258
# batch 1 d_loss : 0.437301
# batch 1 g_loss : 1.086858
# batch 2 d_loss : 0.429080
# batch 2 g_loss : 1.116292
# batch 3 d_loss : 0.416205
# batch 3 g_loss : 1.056195
# batch 4 d_loss : 0.413431
# batch 4 g_loss : 1.063725
# batch 5 d_loss : 0.473409
# batch 5 g_loss : 1.005908
# batch 6 d_loss : 0.486979
# batch 6 g_loss : 1.006079
# Epoch is 167
# Number of batches 7
# batch 0 d_loss : 0.483056
# batch 0 g_loss : 0.976918
# batch 1 d_loss : 0.529392
# batch 1 g_loss : 0.961705
# batch 2 d_loss : 0.513947
# batch 2 g_loss : 0.972637
# batch 3 d_loss : 0.539456
# batch 3 g_loss : 0.905283
# batch 4 d_loss : 0.536717
# batch 4 g_loss : 0.869650
# batch 5 d_loss : 0.607066
# batch 5 g_loss : 0.900038
# batch 6 d_loss : 0.623803
# batch 6 g_loss : 0.815254
# Epoch is 168
# Number of batches 7
# batch 0 d_loss : 0.621473
# batch 0 g_loss : 0.828549
# batch 1 d_loss : 0.660914
# batch 1 g_loss : 0.811063
# batch 2 d_loss : 0.659176
# batch 2 g_loss : 0.807042
# batch 3 d_loss : 0.616741
# batch 3 g_loss : 0.834565
# batch 4 d_loss : 0.640354
# batch 4 g_loss : 0.819608
# batch 5 d_loss : 0.708287
# batch 5 g_loss : 0.858693
# batch 6 d_loss : 0.664877
# batch 6 g_loss : 0.897488
# Epoch is 169
# Number of batches 7
# batch 0 d_loss : 0.672286
# batch 0 g_loss : 0.977288
# batch 1 d_loss : 0.682340
# batch 0 d_loss : 0.524942
# batch 0 g_loss : 1.055306
# batch 1 d_loss : 0.557927
# batch 1 g_loss : 1.035963
# batch 2 d_loss : 0.537529
# batch 2 g_loss : 0.977520
# batch 3 d_loss : 0.566754
# batch 3 g_loss : 0.960067
# batch 4 d_loss : 0.552012
# batch 4 g_loss : 0.997681
# batch 5 d_loss : 0.532797
# batch 5 g_loss : 0.949083
# batch 6 d_loss : 0.561314
# batch 6 g_loss : 0.923242
# Epoch is 193
# Number of batches 7
# batch 0 d_loss : 0.539315
# batch 0 g_loss : 0.868702
# batch 1 d_loss : 0.565937
# batch 1 g_loss : 0.951598
# batch 2 d_loss : 0.553510
# batch 2 g_loss : 0.929527
# batch 3 d_loss : 0.569882
# batch 3 g_loss : 0.908412
# batch 4 d_loss : 0.565237
# batch 4 g_loss : 0.925919
# batch 5 d_loss : 0.575889
# batch 5 g_loss : 0.953416
# batch 6 d_loss : 0.573657
# batch 6 g_loss : 0.952698
# Epoch is 194
# Number of batches 7
# batch 0 d_loss : 0.572972
# batch 0 g_loss : 0.930332
# batch 1 d_loss : 0.615184
# batch 1 g_loss : 0.873322
# batch 2 d_loss : 0.578622
# batch 2 g_loss : 0.919456
# batch 3 d_loss : 0.597356
# batch 3 g_loss : 0.911721
# batch 4 d_loss : 0.596371
# batch 4 g_loss : 0.894410
# batch 5 d_loss : 0.592305
# batch 5 g_loss : 0.847494
# batch 6 d_loss : 0.604036
# batch 6 g_loss : 0.901166
# Epoch is 195
# Number of batches 7
# batch 0 d_loss : 0.600007
# batch 0 g_loss : 0.822451
# batch 1 d_loss : 0.637107
# batch 1 g_loss : 0.853529
# batch 2 d_loss : 0.592974
# batch 2 g_loss : 0.848751
# batch 3 d_loss : 0.606581
# batch 3 g_loss : 0.809929
# batch 4 d_loss : 0.582801
# batch 4 g_loss : 0.809352
# batch 5 d_loss : 0.596748
# batch 5 g_loss : 0.837139
# batch 6 d_loss : 0.594759
# batch 6 g_loss : 0.826562
# Epoch is 196
# Number of batches 7
# batch 0 d_loss : 0.583035
# batch 0 g_loss : 0.836176
# batch 1 d_loss : 0.608348
# batch 1 g_loss : 0.859817
# batch 2 d_loss : 0.562991
# batch 2 g_loss : 0.883157
# batch 3 d_loss : 0.583086
# batch 3 g_loss : 0.856588
# batch 4 d_loss : 0.560071
# batch 4 g_loss : 0.886309
# batch 5 d_loss : 0.585487
# batch 5 g_loss : 0.897328
# batch 6 d_loss : 0.561345
# batch 6 g_loss : 0.922892
# Epoch is 197
# Number of batches 7
# batch 0 d_loss : 0.556831
# batch 0 g_loss : 0.913104
# batch 1 d_loss : 0.598453
# batch 1 g_loss : 0.923350
# batch 2 d_loss : 0.569657
# batch 2 g_loss : 0.931573
# batch 3 d_loss : 0.556984
# batch 3 g_loss : 0.931474
# batch 4 d_loss : 0.537043
# batch 4 g_loss : 0.969766
# batch 5 d_loss : 0.584440
# batch 5 g_loss : 0.978785
# batch 6 d_loss : 0.532971
# batch 6 g_loss : 0.982799
# Epoch is 198
# Number of batches 7
# batch 0 d_loss : 0.535430
# batch 0 g_loss : 0.992901
# batch 1 d_loss : 0.592070
# batch 1 g_loss : 0.984538
# batch 2 d_loss : 0.554340
# batch 2 g_loss : 1.013070
# batch 3 d_loss : 0.548855
# batch 3 g_loss : 1.026846
# batch 4 d_loss : 0.533934
# batch 4 g_loss : 1.030266
# batch 5 d_loss : 0.595904
# batch 5 g_loss : 1.058218
# batch 6 d_loss : 0.526072
# batch 6 g_loss : 1.054010
# Epoch is 199
# Number of batches 7
# batch 0 d_loss : 0.540190
# batch 0 g_loss : 1.098826
# batch 1 d_loss : 0.602309
# batch 1 g_loss : 1.033836
# batch 2 d_loss : 0.569718
# batch 2 g_loss : 1.033763
# batch 3 d_loss : 0.553204
# batch 3 g_loss : 1.023467
# batch 4 d_loss : 0.540969
# batch 4 g_loss : 1.034211
# batch 5 d_loss : 0.604192
# batch 5 g_loss : 1.066821
# batch 6 d_loss : 0.534026
# batch 6 g_loss : 1.036319
# Epoch is 200
# Number of batches 7
# batch 0 d_loss : 0.559660
# batch 0 g_loss : 1.018931
# batch 1 d_loss : 0.601669
# batch 1 g_loss : 1.012728
# batch 2 d_loss : 0.581551
# batch 2 g_loss : 0.967221
# batch 3 d_loss : 0.546769
# batch 3 g_loss : 0.971079
# batch 4 d_loss : 0.568307
# batch 4 g_loss : 0.967240
# batch 5 d_loss : 0.615624
# batch 5 g_loss : 0.962850
# batch 6 d_loss : 0.571385
# batch 6 g_loss : 0.901399
# Epoch is 201
# Number of batches 7
# batch 0 d_loss : 0.584981
# batch 0 g_loss : 0.965976
# batch 1 d_loss : 0.638743
# batch 1 g_loss : 0.918698
# batch 2 d_loss : 0.602558
# batch 2 g_loss : 0.927870
# batch 3 d_loss : 0.593523
# batch 3 g_loss : 0.914392
# batch 4 d_loss : 0.587749
# batch 4 g_loss : 0.933477
# batch 5 d_loss : 0.625170
# batch 5 g_loss : 0.958239
# batch 6 d_loss : 0.607251
# batch 6 g_loss : 0.992844
# Epoch is 202
# Number of batches 7
# batch 0 d_loss : 0.579966
# batch 0 g_loss : 0.971753
# batch 1 d_loss : 0.634474
# batch 1 g_loss : 0.930894
# batch 2 d_loss : 0.604849
# batch 2 g_loss : 0.997486
# batch 3 d_loss : 0.610855
# batch 3 g_loss : 0.938019
# batch 4 d_loss : 0.578850
# batch 4 g_loss : 0.961853
# batch 5 d_loss : 0.604046
# batch 5 g_loss : 1.012298
# batch 6 d_loss : 0.589550
# batch 6 g_loss : 0.999811
# Epoch is 203
# Number of batches 7
# batch 0 d_loss : 0.573206
# batch 0 g_loss : 0.996915
# batch 1 d_loss : 0.616606
# batch 1 g_loss : 1.075876
# batch 2 d_loss : 0.563727
# batch 2 g_loss : 1.071588
# batch 3 d_loss : 0.573357
# batch 3 g_loss : 0.983751
# batch 4 d_loss : 0.559048
# batch 4 g_loss : 0.962944
# batch 5 d_loss : 0.582980
# batch 5 g_loss : 1.000069
# batch 6 d_loss : 0.581698
# batch 6 g_loss : 0.923735
# Epoch is 204
# Number of batches 7
# batch 0 d_loss : 0.544193
# batch 0 g_loss : 1.001796
# batch 1 d_loss : 0.611933
# batch 1 g_loss : 0.997944
# batch 2 d_loss : 0.565306
# batch 2 g_loss : 1.016569
# batch 3 d_loss : 0.583351
# batch 3 g_loss : 0.985322
# batch 4 d_loss : 0.547256
# batch 4 g_loss : 0.993619
# batch 5 d_loss : 0.575989
# batch 5 g_loss : 1.022407
# batch 6 d_loss : 0.590413
# batch 6 g_loss : 1.070564
# Epoch is 205
# Number of batches 7
# batch 0 d_loss : 0.520898
# batch 0 g_loss : 1.019630
# batch 1 d_loss : 0.585447
# batch 1 g_loss : 1.025484
# batch 2 d_loss : 0.549444
# batch 2 g_loss : 1.033570
# batch 3 d_loss : 0.556450
# batch 3 g_loss : 0.945995
# batch 4 d_loss : 0.552005
# batch 4 g_loss : 0.981025
# batch 5 d_loss : 0.558472
# batch 5 g_loss : 0.980560
# batch 6 d_loss : 0.573396
# batch 6 g_loss : 1.064333
# Epoch is 206
# Number of batches 7
# batch 0 d_loss : 0.503709
# batch 0 g_loss : 1.003643
# batch 1 d_loss : 0.573035
# batch 1 g_loss : 1.044356
# batch 2 d_loss : 0.527568
# batch 2 g_loss : 1.042822
# batch 3 d_loss : 0.535700
# batch 3 g_loss : 1.031446
# batch 4 d_loss : 0.535661
# batch 4 g_loss : 1.014724
# batch 5 d_loss : 0.527805
# batch 5 g_loss : 1.039117
# batch 6 d_loss : 0.537247
# batch 6 g_loss : 1.050760
# Epoch is 207
# Number of batches 7
# batch 0 d_loss : 0.514218
# batch 0 g_loss : 0.988851
# batch 1 d_loss : 0.552410
# batch 1 g_loss : 0.991454
# batch 2 d_loss : 0.540793
# batch 2 g_loss : 1.009164
# batch 3 d_loss : 0.515823
# batch 3 g_loss : 1.024771
# batch 4 d_loss : 0.539262
# batch 4 g_loss : 0.941243
# batch 5 d_loss : 0.518160
# batch 5 g_loss : 0.961438
# batch 6 d_loss : 0.551744
# batch 6 g_loss : 0.929987
# Epoch is 208
# Number of batches 7
# batch 0 d_loss : 0.511857
# batch 0 g_loss : 0.935466
# batch 1 d_loss : 0.589489
# batch 1 g_loss : 0.940808
# batch 2 d_loss : 0.537893
# batch 2 g_loss : 0.912324
# batch 3 d_loss : 0.539740
# batch 3 g_loss : 0.918948
# batch 4 d_loss : 0.546839
# batch 4 g_loss : 0.940389
# batch 5 d_loss : 0.519312
# batch 5 g_loss : 0.951865
# batch 6 d_loss : 0.560913
# batch 6 g_loss : 0.965466
# Epoch is 209
# Number of batches 7
# batch 0 d_loss : 0.511335
# batch 0 g_loss : 0.972962
# batch 1 d_loss : 0.591118
# batch 1 g_loss : 0.963941
# batch 2 d_loss : 0.560274
# batch 2 g_loss : 0.935319
# batch 3 d_loss : 0.531294
# batch 3 g_loss : 0.947176
# batch 4 d_loss : 0.534844
# batch 4 g_loss : 0.966172
# batch 5 d_loss : 0.509572
# batch 5 g_loss : 0.950095
# batch 6 d_loss : 0.571728
# batch 6 g_loss : 0.939651
# Epoch is 210
# Number of batches 7
# batch 0 d_loss : 0.515226
# batch 0 g_loss : 1.002486
# batch 1 d_loss : 0.582361
# batch 1 g_loss : 0.956231
# batch 2 d_loss : 0.543230
# batch 2 g_loss : 0.953754
# batch 3 d_loss : 0.525365
# batch 3 g_loss : 0.935448
# batch 4 d_loss : 0.539076
# batch 4 g_loss : 0.852060
# batch 5 d_loss : 0.543478
# batch 5 g_loss : 0.954278
# batch 6 d_loss : 0.560352
# batch 6 g_loss : 0.886874
# Epoch is 211
# Number of batches 7
# batch 0 d_loss : 0.540665
# batch 0 g_loss : 0.935139
# batch 1 d_loss : 0.595751
# batch 1 g_loss : 0.880719
# batch 2 d_loss : 0.550697
# batch 2 g_loss : 0.951326
# batch 3 d_loss : 0.529416
# batch 3 g_loss : 0.926801
# batch 4 d_loss : 0.550605
# batch 4 g_loss : 0.878151
# batch 5 d_loss : 0.540092
# batch 5 g_loss : 0.939204
# batch 6 d_loss : 0.549404
# batch 6 g_loss : 0.940015
# Epoch is 212
# Number of batches 7
# batch 0 d_loss : 0.550185
# batch 0 g_loss : 0.969735
# batch 1 d_loss : 0.580263
# batch 1 g_loss : 0.972380
# batch 2 d_loss : 0.544078
# batch 2 g_loss : 1.013386
# batch 3 d_loss : 0.517343
# batch 3 g_loss : 0.990139
# batch 4 d_loss : 0.551334
# batch 4 g_loss : 1.055913
# batch 5 d_loss : 0.537725
# batch 5 g_loss : 0.982513
# batch 6 d_loss : 0.528781
# batch 6 g_loss : 0.999223
# Epoch is 213
# Number of batches 7
# batch 0 d_loss : 0.532725
# batch 0 g_loss : 1.018163
# batch 1 d_loss : 0.569687
# batch 1 g_loss : 1.025293
# batch 2 d_loss : 0.533245
# batch 2 g_loss : 1.030685
# batch 3 d_loss : 0.501968
# batch 3 g_loss : 0.993609
# batch 4 d_loss : 0.523985
# batch 4 g_loss : 0.932743
# batch 5 d_loss : 0.540870
# batch 5 g_loss : 0.971600
# batch 6 d_loss : 0.520435
# batch 6 g_loss : 0.929562
# Epoch is 214
# Number of batches 7
# batch 0 d_loss : 0.545113
# batch 0 g_loss : 0.940138
# batch 1 d_loss : 0.577968
# batch 1 g_loss : 0.950689
# batch 2 d_loss : 0.542182
# batch 2 g_loss : 0.968324
# batch 3 d_loss : 0.516119
# batch 3 g_loss : 0.987217
# batch 4 d_loss : 0.510710
# batch 4 g_loss : 0.997911
# batch 5 d_loss : 0.543023
# batch 5 g_loss : 0.979917
# batch 6 d_loss : 0.505935
# batch 6 g_loss : 0.923336
# Epoch is 215
# Number of batches 7
# batch 0 d_loss : 0.517954
# batch 0 g_loss : 1.007274
# batch 1 d_loss : 0.568478
# batch 1 g_loss : 0.961233
# batch 2 d_loss : 0.521882
# batch 2 g_loss : 0.984942
# batch 3 d_loss : 0.499282
# batch 3 g_loss : 0.973076
# batch 4 d_loss : 0.501886
# batch 4 g_loss : 0.962749
# batch 5 d_loss : 0.542645
# batch 5 g_loss : 0.933592
# batch 6 d_loss : 0.514087
# batch 6 g_loss : 0.927028
# Epoch is 216
# Number of batches 7
# batch 0 d_loss : 0.530347
# batch 0 g_loss : 0.940044
# batch 1 d_loss : 0.574915
# batch 1 g_loss : 0.995957
# batch 2 d_loss : 0.543765
# batch 2 g_loss : 1.038580
# batch 3 d_loss : 0.513536
# batch 3 g_loss : 1.035422
# batch 4 d_loss : 0.507653
# batch 4 g_loss : 1.026887
# batch 5 d_loss : 0.556230
# batch 5 g_loss : 0.986203
# batch 6 d_loss : 0.555659
# batch 6 g_loss : 1.028963
# Epoch is 217
# Number of batches 7
# batch 0 d_loss : 0.533777
# batch 0 g_loss : 1.079968
# batch 1 d_loss : 0.593587
# batch 1 g_loss : 1.016459
# batch 2 d_loss : 0.557465
# batch 2 g_loss : 0.979664
# batch 3 d_loss : 0.543629
# batch 3 g_loss : 0.999538
# batch 4 d_loss : 0.526576
# batch 4 g_loss : 0.958281
# batch 5 d_loss : 0.576974
# batch 5 g_loss : 0.994267
# batch 6 d_loss : 0.551496
# batch 6 g_loss : 0.967875
# Epoch is 218
# Number of batches 7
# batch 0 d_loss : 0.554617
# batch 0 g_loss : 0.990497
# batch 1 d_loss : 0.606761
# batch 1 g_loss : 1.025755
# batch 2 d_loss : 0.593475
# batch 2 g_loss : 0.977482
# batch 3 d_loss : 0.556769
# batch 3 g_loss : 1.039922
# batch 4 d_loss : 0.554597
# batch 4 g_loss : 1.074886
# batch 5 d_loss : 0.587565
# batch 5 g_loss : 1.048169
# batch 6 d_loss : 0.577458
# batch 6 g_loss : 1.008639
# Epoch is 219
# Number of batches 7
# batch 0 d_loss : 0.559100
# batch 0 g_loss : 0.982257
# batch 1 d_loss : 0.616720
# batch 5 d_loss : 0.598583
# batch 5 g_loss : 0.882553
# batch 6 d_loss : 0.571509
# batch 6 g_loss : 0.894126
# Epoch is 230
# Number of batches 7
# batch 0 d_loss : 0.604038
# batch 0 g_loss : 0.881792
# batch 1 d_loss : 0.608932
# batch 1 g_loss : 0.929462
# batch 2 d_loss : 0.578834
# batch 2 g_loss : 0.883210
# batch 3 d_loss : 0.563822
# batch 3 g_loss : 0.874837
# batch 4 d_loss : 0.559947
# batch 4 g_loss : 0.903391
# batch 5 d_loss : 0.581926
# batch 5 g_loss : 0.934500
# batch 6 d_loss : 0.543825
# batch 6 g_loss : 0.969505
# Epoch is 231
# Number of batches 7
# batch 0 d_loss : 0.588282
# batch 0 g_loss : 0.985608
# ...
# batch 1 d_loss : 0.086203
# batch 1 g_loss : 2.881823
# batch 2 d_loss : 0.102404
# batch 2 g_loss : 3.244110
# batch 3 d_loss : 0.117978
# batch 3 g_loss : 2.975989
# batch 4 d_loss : 0.100845
# batch 4 g_loss : 3.170326
# batch 5 d_loss : 0.102663
# batch 5 g_loss : 3.204985
# batch 6 d_loss : 0.110768
# batch 6 g_loss : 2.789207
# Epoch is 1621
# Number of batches 7
# batch 0 d_loss : 0.110018
# batch 0 g_loss : 2.802830
# batch 1 d_loss : 0.098015
# batch 1 g_loss : 2.895357
# batch 2 d_loss : 0.096840
# batch 2 g_loss : 3.032233
# batch 3 d_loss : 0.104436
# batch 3 g_loss : 2.978990
# batch 4 d_loss : 0.093019
# batch 4 g_loss : 2.980296
# batch 5 d_loss : 0.096803
# batch 5 g_loss : 2.974952
# batch 6 d_loss : 0.103174
# batch 6 g_loss : 2.793695
# Epoch is 1622
# Number of batches 7
# batch 0 d_loss : 0.099738
# batch 0 g_loss : 2.636781
# batch 1 d_loss : 0.105198
# batch 1 g_loss : 2.629484
# batch 2 d_loss : 0.092690
# batch 2 g_loss : 2.921761
# batch 3 d_loss : 0.102185
# batch 3 g_loss : 2.976540
# batch 4 d_loss : 0.083641
# batch 4 g_loss : 3.047860
# batch 5 d_loss : 0.101598
# batch 5 g_loss : 3.049117
# batch 6 d_loss : 0.127253
# batch 6 g_loss : 2.995877
# Epoch is 1623
# Number of batches 7
# batch 0 d_loss : 0.109583
# batch 0 g_loss : 3.031256
# batch 1 d_loss : 0.107400
# batch 1 g_loss : 3.027694
# batch 2 d_loss : 0.087720
# batch 2 g_loss : 2.747643
# batch 3 d_loss : 0.112694
# batch 3 g_loss : 2.891472
# batch 4 d_loss : 0.111517
# batch 4 g_loss : 3.038176
# batch 5 d_loss : 0.100295
# batch 5 g_loss : 2.901829
# batch 6 d_loss : 0.085670
# batch 6 g_loss : 2.822137
# Epoch is 1624
# Number of batches 7
# batch 0 d_loss : 0.117625
# batch 0 g_loss : 2.823700
# batch 1 d_loss : 0.093680
# batch 1 g_loss : 2.575752
# batch 2 d_loss : 0.111567
# batch 2 g_loss : 3.088872
# batch 3 d_loss : 0.104994
# batch 3 g_loss : 3.061154
# batch 4 d_loss : 0.102674
# batch 4 g_loss : 2.530586
# batch 5 d_loss : 0.108575
# batch 5 g_loss : 2.929046
# batch 6 d_loss : 0.102882
# batch 6 g_loss : 2.876457
# Epoch is 1625
# Number of batches 7
# batch 0 d_loss : 0.122110
# batch 0 g_loss : 2.903321
# batch 1 d_loss : 0.098531
# batch 1 g_loss : 2.983933
# batch 2 d_loss : 0.095093
# batch 2 g_loss : 3.056305
# batch 3 d_loss : 0.098173
# batch 3 g_loss : 3.032714
# batch 4 d_loss : 0.090188
# batch 4 g_loss : 2.816820
# batch 5 d_loss : 0.096692
# batch 5 g_loss : 2.851182
# batch 6 d_loss : 0.108883
# batch 6 g_loss : 2.821414
# Epoch is 1626
# Number of batches 7
# batch 0 d_loss : 0.101667
# batch 0 g_loss : 2.701381
# batch 1 d_loss : 0.101320
# batch 1 g_loss : 2.985407
# batch 2 d_loss : 0.085378
# batch 2 g_loss : 2.944642
# batch 3 d_loss : 0.104313
# batch 3 g_loss : 3.001093
# batch 4 d_loss : 0.095657
# batch 4 g_loss : 3.282093
# batch 5 d_loss : 0.120121
# batch 5 g_loss : 3.163040
# batch 6 d_loss : 0.100276
# batch 6 g_loss : 3.163446
# Epoch is 1627
# Number of batches 7
# batch 0 d_loss : 0.107152
# batch 0 g_loss : 3.075045
# batch 1 d_loss : 0.102786
# batch 1 g_loss : 3.144199
# batch 2 d_loss : 0.100898
# batch 2 g_loss : 3.098257
# batch 3 d_loss : 0.097346
# batch 3 g_loss : 3.029598
# batch 4 d_loss : 0.093654
# batch 4 g_loss : 2.769084
# batch 5 d_loss : 0.102578
# batch 5 g_loss : 2.826874
# batch 6 d_loss : 0.097871
# batch 6 g_loss : 2.760800
# Epoch is 1628
# Number of batches 7
# batch 0 d_loss : 0.106791
# batch 0 g_loss : 2.838325
# batch 1 d_loss : 0.104661
# batch 1 g_loss : 3.086618
# batch 2 d_loss : 0.083743
# batch 2 g_loss : 3.232125
# batch 3 d_loss : 0.102571
# batch 3 g_loss : 2.928447
# batch 4 d_loss : 0.104145
# batch 4 g_loss : 2.845285
# batch 5 d_loss : 0.108103
# batch 5 g_loss : 2.839975
# batch 6 d_loss : 0.096487
# batch 6 g_loss : 2.685226
# Epoch is 1629
# Number of batches 7
# batch 0 d_loss : 0.107508
# batch 0 g_loss : 3.085734
# batch 1 d_loss : 0.121542
# batch 1 g_loss : 3.022205
# batch 2 d_loss : 0.113216
# batch 2 g_loss : 2.984655
# batch 3 d_loss : 0.095015
# batch 3 g_loss : 2.977689
# batch 4 d_loss : 0.098175
# batch 4 g_loss : 3.132436
# batch 5 d_loss : 0.102178
# batch 5 g_loss : 2.735234
# batch 6 d_loss : 0.112457
# batch 6 g_loss : 2.843448
# Epoch is 1630
# Number of batches 7
# batch 0 d_loss : 0.112281
# batch 0 g_loss : 3.004540
# batch 1 d_loss : 0.091822
# batch 1 g_loss : 2.939569
# batch 2 d_loss : 0.096353
# batch 2 g_loss : 3.098314
# batch 3 d_loss : 0.101642
# batch 3 g_loss : 3.141279
# batch 4 d_loss : 0.098538
# batch 4 g_loss : 2.887124
# batch 5 d_loss : 0.100134
# batch 5 g_loss : 2.881015
# batch 6 d_loss : 0.114734
# batch 6 g_loss : 2.892930
# Epoch is 1631
# Number of batches 7
# batch 0 d_loss : 0.111643
# batch 0 g_loss : 2.846620
# batch 1 d_loss : 0.097714
# batch 1 g_loss : 3.041517
# batch 2 d_loss : 0.090366
# batch 2 g_loss : 2.754748
# batch 3 d_loss : 0.101646
# batch 3 g_loss : 2.953670
# batch 4 d_loss : 0.094348
# batch 4 g_loss : 3.110347
# batch 5 d_loss : 0.089792
# batch 5 g_loss : 3.359315
# batch 6 d_loss : 0.101003
# batch 6 g_loss : 2.884887
# Epoch is 1632
# Number of batches 7
# batch 0 d_loss : 0.117433
# batch 0 g_loss : 2.930570
# batch 1 d_loss : 0.102802
# batch 1 g_loss : 3.139725
# batch 2 d_loss : 0.097989
# batch 2 g_loss : 3.110466
# batch 3 d_loss : 0.109792
# batch 3 g_loss : 3.016810
# batch 4 d_loss : 0.095321
# batch 4 g_loss : 2.880137
# batch 5 d_loss : 0.102584
# batch 5 g_loss : 2.894096
# batch 6 d_loss : 0.096848
# batch 6 g_loss : 2.884017
# Epoch is 1633
# Number of batches 7
# batch 0 d_loss : 0.103514
# batch 0 g_loss : 3.075598
# batch 1 d_loss : 0.097593
# batch 1 g_loss : 2.967641
# batch 2 d_loss : 0.087661
# batch 2 g_loss : 3.192779
# batch 3 d_loss : 0.105676
# batch 3 g_loss : 3.204391
# batch 4 d_loss : 0.100525
# batch 4 g_loss : 2.833476
# batch 5 d_loss : 0.108480
# batch 5 g_loss : 2.865319
# batch 6 d_loss : 0.112934
# batch 6 g_loss : 2.671246
# Epoch is 1634
# Number of batches 7
# batch 4 d_loss : 0.102823
# batch 4 g_loss : 3.083646
# batch 5 d_loss : 0.110493
# batch 5 g_loss : 2.870963
# batch 6 d_loss : 0.103612
# batch 6 g_loss : 2.985883
# Epoch is 1646
# Number of batches 7
# batch 0 d_loss : 0.099759
# batch 0 g_loss : 2.936594
# batch 1 d_loss : 0.092759
# batch 1 g_loss : 3.348654
# batch 2 d_loss : 0.087116
# batch 2 g_loss : 3.404215
# batch 3 d_loss : 0.089302
# batch 3 g_loss : 3.104758
# batch 4 d_loss : 0.087983
# batch 4 g_loss : 2.867584
# batch 5 d_loss : 0.095598
# batch 5 g_loss : 2.849100
# batch 6 d_loss : 0.096657
# batch 6 g_loss : 2.865234
# Epoch is 1647
# Number of batches 7
# batch 0 d_loss : 0.111836
# batch 0 g_loss : 3.056782
# batch 1 d_loss : 0.097019
# batch 1 g_loss : 2.927773
# batch 2 d_loss : 0.082785
# batch 2 g_loss : 3.166933
# batch 3 d_loss : 0.107369
# batch 3 g_loss : 2.943510
# batch 4 d_loss : 0.090753
# batch 4 g_loss : 3.008460
# batch 5 d_loss : 0.110790
# batch 5 g_loss : 2.796132
# batch 6 d_loss : 0.096258
# batch 6 g_loss : 2.891622
# Epoch is 1648
# Number of batches 7
# batch 0 d_loss : 0.101644
# batch 0 g_loss : 2.899521
# batch 1 d_loss : 0.086151
# batch 2 d_loss : 0.096651
# batch 2 g_loss : 3.144115
# batch 3 d_loss : 0.098999
# batch 3 g_loss : 2.926970
# batch 4 d_loss : 0.092912
# batch 4 g_loss : 3.038912
# batch 5 d_loss : 0.094014
# batch 5 g_loss : 3.019837
# batch 6 d_loss : 0.113527
# batch 6 g_loss : 2.940384
# Epoch is 1677
# Number of batches 7
# batch 0 d_loss : 0.102921
# batch 0 g_loss : 3.030193
# batch 1 d_loss : 0.086307
# batch 1 g_loss : 2.850678
# batch 2 d_loss : 0.092628
# batch 2 g_loss : 3.115035
# batch 3 d_loss : 0.095256
# batch 3 g_loss : 2.784399
# batch 4 d_loss : 0.100332
# batch 4 g_loss : 3.045835
# batch 5 d_loss : 0.095839
# batch 5 g_loss : 2.930785
# batch 6 d_loss : 0.095469
# batch 6 g_loss : 2.821618
# Epoch is 1678
# Number of batches 7
# batch 0 d_loss : 0.112774
# batch 0 g_loss : 3.087553
# batch 1 d_loss : 0.091402
# batch 1 g_loss : 3.008371
# batch 2 d_loss : 0.096780
# batch 2 g_loss : 3.338449
# batch 3 d_loss : 0.106629
# batch 3 g_loss : 3.166648
# batch 4 d_loss : 0.092809
# batch 4 g_loss : 3.164502
# batch 5 d_loss : 0.108352
# batch 5 g_loss : 2.824653
# batch 6 d_loss : 0.086394
# batch 6 g_loss : 2.866464
# Epoch is 1679
# Number of batches 7
# batch 0 d_loss : 0.112074
# batch 0 g_loss : 2.795673
# batch 1 d_loss : 0.091203
# batch 1 g_loss : 2.636161
# batch 2 d_loss : 0.094068
# batch 2 g_loss : 3.114899
# batch 3 d_loss : 0.086777
# batch 3 g_loss : 2.932223
# batch 4 d_loss : 0.113546
# batch 4 g_loss : 2.978959
# batch 5 d_loss : 0.093162
# batch 5 g_loss : 3.280336
# batch 6 d_loss : 0.093723
# batch 6 g_loss : 3.119437
# Epoch is 1680
# Number of batches 7
# batch 0 d_loss : 0.096991
# batch 0 g_loss : 2.981328
# batch 1 d_loss : 0.090661
# batch 1 g_loss : 2.831258
# batch 2 d_loss : 0.090861
# batch 2 g_loss : 3.030833
# batch 3 d_loss : 0.096222
# batch 3 g_loss : 3.166728
# batch 4 d_loss : 0.089487
# batch 4 g_loss : 2.932212
# batch 5 d_loss : 0.106072
# batch 5 g_loss : 3.028730
# batch 6 d_loss : 0.103295
# batch 6 g_loss : 2.836891
# Epoch is 1681
# Number of batches 7
# batch 0 d_loss : 0.104718
# batch 0 g_loss : 3.107859
# batch 1 d_loss : 0.107967
# batch 1 g_loss : 3.228335
# batch 2 d_loss : 0.084287
# batch 2 g_loss : 3.082280
# batch 3 d_loss : 0.102576
# batch 3 g_loss : 2.994729
# batch 4 d_loss : 0.101244
# batch 4 g_loss : 2.893085
# batch 5 d_loss : 0.121364
# batch 5 g_loss : 2.936856
# batch 6 d_loss : 0.097370
# batch 6 g_loss : 3.106341
# Epoch is 1682
# Number of batches 7
# batch 0 d_loss : 0.114789
# batch 0 g_loss : 3.070406
# batch 1 d_loss : 0.079500
# batch 1 g_loss : 3.068905
# batch 2 d_loss : 0.091355
# batch 2 g_loss : 3.006939
# batch 3 d_loss : 0.113082
# batch 3 g_loss : 3.200290
# batch 4 d_loss : 0.095922
# batch 4 g_loss : 3.305845
# batch 5 d_loss : 0.100066
# batch 5 g_loss : 3.190134
# batch 6 d_loss : 0.092268
# batch 6 g_loss : 2.803814
# Epoch is 1683
# Number of batches 7
# batch 0 d_loss : 0.101836
# batch 0 g_loss : 2.823566
# batch 1 d_loss : 0.083301
# batch 1 g_loss : 2.933578
# batch 2 d_loss : 0.100976
# batch 2 g_loss : 2.898254
# batch 3 d_loss : 0.079212
# batch 3 g_loss : 2.895753
# batch 4 d_loss : 0.091125
# batch 4 g_loss : 2.963822
# batch 5 d_loss : 0.098328
# batch 5 g_loss : 3.115792
# batch 6 d_loss : 0.095277
# batch 6 g_loss : 2.821896
# Epoch is 1684
# Number of batches 7
# batch 0 d_loss : 0.094388
# batch 0 g_loss : 2.826929
# batch 1 d_loss : 0.084660
# batch 1 g_loss : 2.884238
# batch 2 d_loss : 0.106726
# batch 2 g_loss : 3.171157
# batch 3 d_loss : 0.100089
# batch 3 g_loss : 3.011662
# batch 4 d_loss : 0.090061
# batch 4 g_loss : 2.869357
# batch 5 d_loss : 0.088196
# batch 5 g_loss : 2.942041
# batch 6 d_loss : 0.098823
# batch 6 g_loss : 2.926664
# Epoch is 1685
# Number of batches 7
# batch 0 d_loss : 0.104587
# batch 0 g_loss : 2.875408
# batch 1 d_loss : 0.097872
# batch 1 g_loss : 3.044809
# batch 2 d_loss : 0.080163
# batch 2 g_loss : 3.219243
# batch 3 d_loss : 0.095661
# batch 3 g_loss : 2.895030
# batch 4 d_loss : 0.092679
# batch 4 g_loss : 2.962634
# batch 5 d_loss : 0.087735
# batch 5 g_loss : 2.965482
# batch 6 d_loss : 0.087137
# batch 6 g_loss : 3.094091
# Epoch is 1686
# Number of batches 7
# batch 0 d_loss : 0.099176
# batch 0 g_loss : 3.060704
# batch 1 d_loss : 0.091683
# batch 1 g_loss : 3.074727
# batch 2 d_loss : 0.089710
# batch 2 g_loss : 3.254474
# batch 3 d_loss : 0.094041
# batch 3 g_loss : 2.975480
# batch 4 d_loss : 0.096686
# batch 4 g_loss : 3.160285
# batch 5 d_loss : 0.086212
# batch 5 g_loss : 2.837250
# batch 6 d_loss : 0.084263
# batch 6 g_loss : 2.906199
# Epoch is 1687
# Number of batches 7
# batch 0 d_loss : 0.107139
# batch 0 g_loss : 3.001536
# batch 1 d_loss : 0.099800
# batch 1 g_loss : 3.040276
# batch 2 d_loss : 0.096253
# batch 2 g_loss : 3.060746
# batch 3 d_loss : 0.094713
# batch 3 g_loss : 2.921141
# batch 4 d_loss : 0.104774
# batch 4 g_loss : 3.133011
# batch 5 d_loss : 0.089276
# batch 5 g_loss : 2.938597
# batch 6 d_loss : 0.093724
# batch 6 g_loss : 2.850097
# Epoch is 1688
# Number of batches 7
# batch 0 d_loss : 0.096540
# batch 0 g_loss : 2.668685
# batch 1 d_loss : 0.093391
# batch 1 g_loss : 3.239219
# batch 2 d_loss : 0.083939
# batch 2 g_loss : 3.105371
# batch 3 d_loss : 0.099254
# batch 3 g_loss : 2.996847
# batch 4 d_loss : 0.090259
# batch 4 g_loss : 3.120341
# batch 5 d_loss : 0.106012
# batch 5 g_loss : 3.083197
# batch 6 d_loss : 0.089053
# batch 6 g_loss : 3.119607
# Epoch is 1689
# Number of batches 7
# batch 0 d_loss : 0.106389
# batch 0 g_loss : 2.941483
# batch 1 d_loss : 0.093674
# batch 1 g_loss : 2.914976
# batch 2 d_loss : 0.089331
# batch 2 g_loss : 3.128515
# batch 3 d_loss : 0.104604
# batch 3 g_loss : 3.054913
# batch 4 d_loss : 0.094412
# batch 4 g_loss : 3.011272
# batch 5 d_loss : 0.101052
# batch 5 g_loss : 3.151275
# batch 6 d_loss : 0.099302
# batch 6 g_loss : 2.930067
# Epoch is 1690
# Number of batches 7
# batch 0 d_loss : 0.103121
# batch 0 g_loss : 2.936098
# batch 1 d_loss : 0.104544
# batch 1 g_loss : 3.159410
# batch 2 d_loss : 0.083161
# batch 2 g_loss : 3.078901
# batch 3 d_loss : 0.111487
# batch 3 g_loss : 2.753520
# batch 4 d_loss : 0.091205
# batch 4 g_loss : 3.107995
# batch 5 d_loss : 0.098404
# batch 5 g_loss : 2.820662
# batch 6 d_loss : 0.091729
# batch 6 g_loss : 3.026514
# Epoch is 1691
# Number of batches 7
# batch 0 d_loss : 0.098528
# batch 0 g_loss : 2.861606
# batch 1 d_loss : 0.091076
# batch 1 g_loss : 3.176667
# batch 2 d_loss : 0.091044
# batch 2 g_loss : 3.151604
# batch 3 d_loss : 0.098995
# batch 3 g_loss : 3.129383
# batch 4 d_loss : 0.094176
# batch 4 g_loss : 2.971589
# batch 5 d_loss : 0.085611
# batch 5 g_loss : 2.800531
# batch 6 d_loss : 0.096481
# batch 6 g_loss : 2.979838
# Epoch is 1692
# Number of batches 7
# batch 0 d_loss : 0.102224
# batch 0 g_loss : 2.831217
# batch 1 d_loss : 0.090487
# batch 1 g_loss : 2.981041
# batch 2 d_loss : 0.090720
# batch 2 g_loss : 2.986568
# batch 3 d_loss : 0.092216
# batch 3 g_loss : 3.192028
# batch 4 d_loss : 0.090958
# batch 4 g_loss : 3.058050
# batch 5 d_loss : 0.098073
# batch 5 g_loss : 3.097955
# batch 6 d_loss : 0.085948
# batch 6 g_loss : 2.841918
# Epoch is 1693
# Number of batches 7
# batch 0 d_loss : 0.102315
# batch 0 g_loss : 3.042009
# batch 1 d_loss : 0.104467
# batch 1 g_loss : 2.991926
# batch 2 d_loss : 0.093109
# batch 2 g_loss : 3.144690
# batch 3 d_loss : 0.105348
# batch 3 g_loss : 3.204134
# batch 4 d_loss : 0.097258
# batch 4 g_loss : 3.084308
# batch 5 d_loss : 0.088240
# batch 5 g_loss : 3.161892
# batch 6 d_loss : 0.112271
# batch 6 g_loss : 3.135008
# Epoch is 1694
# Number of batches 7
# batch 0 d_loss : 0.095615
# batch 0 g_loss : 2.864097
# batch 1 d_loss : 0.095784
# batch 1 g_loss : 3.019578
# batch 2 d_loss : 0.080103
# batch 2 g_loss : 3.161479
# batch 3 d_loss : 0.103043
# batch 3 g_loss : 2.949103
# batch 4 d_loss : 0.086207
# batch 4 g_loss : 3.128118
# batch 5 d_loss : 0.091647
# batch 5 g_loss : 2.901070
# batch 6 d_loss : 0.094767
# batch 6 g_loss : 2.915021
# Epoch is 1695
# Number of batches 7
# batch 0 d_loss : 0.112362
# batch 0 g_loss : 2.842476
# batch 1 d_loss : 0.080983
# batch 1 g_loss : 3.297286
# batch 2 d_loss : 0.086843
# batch 2 g_loss : 3.071762
# batch 3 d_loss : 0.105371
# batch 3 g_loss : 3.122928
# batch 4 d_loss : 0.088287
# batch 4 g_loss : 3.017430
# batch 5 d_loss : 0.099738
# batch 5 g_loss : 2.954542
# batch 6 d_loss : 0.095520
# batch 6 g_loss : 2.990189
# Epoch is 1696
# Number of batches 7
# batch 0 d_loss : 0.115118
# batch 0 g_loss : 2.820507
# batch 1 d_loss : 0.094611
# batch 1 g_loss : 3.039314
# batch 2 d_loss : 0.091370
# batch 2 g_loss : 3.215805
# batch 3 d_loss : 0.090341
# batch 3 g_loss : 3.053383
# batch 4 d_loss : 0.085562
# batch 4 g_loss : 3.275846
# batch 5 d_loss : 0.093372
# batch 5 g_loss : 3.109584
# batch 6 d_loss : 0.094433
# batch 6 g_loss : 3.068633
# Epoch is 1697
# Number of batches 7
# batch 0 d_loss : 0.105682
# batch 0 g_loss : 3.171590
# batch 1 d_loss : 0.102992
# batch 1 g_loss : 3.134243
# batch 2 d_loss : 0.086733
# batch 2 g_loss : 3.425183
# batch 3 d_loss : 0.106990
# batch 3 g_loss : 3.022954
# batch 4 d_loss : 0.111423
# batch 4 g_loss : 2.990855
# batch 5 d_loss : 0.094721
# batch 5 g_loss : 3.193892
# batch 6 d_loss : 0.112543
# batch 6 g_loss : 3.101563
# Epoch is 1698
# Number of batches 7
# batch 0 d_loss : 0.092259
# batch 0 g_loss : 3.157677
# batch 1 d_loss : 0.089473
# batch 1 g_loss : 3.050235
# batch 2 d_loss : 0.077764
# batch 2 g_loss : 3.074065
# batch 3 d_loss : 0.091862
# batch 3 g_loss : 3.334773
# batch 4 d_loss : 0.097314
# batch 4 g_loss : 3.300117
# batch 5 d_loss : 0.092154
# batch 5 g_loss : 3.132213
# batch 6 d_loss : 0.098434
# batch 6 g_loss : 3.094739
# Epoch is 1699
# Number of batches 7
# batch 0 d_loss : 0.093055
# batch 0 g_loss : 3.044364
# batch 1 d_loss : 0.092894
# batch 1 g_loss : 3.062063
# batch 2 d_loss : 0.088281
# batch 2 g_loss : 3.211129
# batch 3 d_loss : 0.083020
# batch 3 g_loss : 3.350785
# batch 4 d_loss : 0.079500
# batch 4 g_loss : 3.195391
# batch 5 d_loss : 0.103429
# batch 5 g_loss : 2.899174
# batch 6 d_loss : 0.112642
# batch 6 g_loss : 3.122275

# %%
generate(1)
# Out:
# 1/1 [==============================] - 0s
# (1, 1, 128, 128)
